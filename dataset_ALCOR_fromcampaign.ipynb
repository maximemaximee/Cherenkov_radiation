# %%
## connessione al google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy  as np
import math

#from ape_dataset import *

import os

# cartella output per i csv di noise
OUTDIR = "csv_reco"
os.makedirs(OUTDIR, exist_ok=True)

# %%
## DATASET GENERATION ###

##Defines
c_x = 175  #center of sector division (local coords)
c_y = 189

c1 = 680   #line interception with y axis
c2 = 320

grid_size = 8 #grid resolution (preprocessing step)

num_noise_ROOT_files = 100 #number of input files
num_signal_ROOT_files = 100 #number of input files
num_events = 1000 #number of events for each file

num_sectors = 6 #number of sectors of dRICH

# %%
def noise_probability_gaussian(freq_kHz=100,time_window_ns=10):
    p = freq_kHz*1000 *time_window_ns/1000000000
    sigma_p = p * 0.01
    single_ph_emission_p = np.random.normal(0, 1) * sigma_p + p
    if single_ph_emission_p < 0:
        single_ph_emission_p = 0

    return single_ph_emission_p


def neq_radius(neq_radius_params,radius):
    neq = np.zeros(radius.size)
    for i,par in enumerate(neq_radius_params):
        neq+=neq_radius_params[i]*pow(radius,i)
    return neq


def noise_probability_radial(luminosity_fbi=100,time_window_ns=10,radius=[]):
    baseline_dcr = 3000*np.ones(radius.size)
    neq_radius_params = [-3.27029e+09, 1.26055e+08, -1.88568e+06, 13929.1, -50.9931, 0.0741068]
    dcr_increase = 300/1000000
    neq = neq_radius(neq_radius_params,radius) * luminosity_fbi;
    dcr = baseline_dcr + dcr_increase * neq
    pro = dcr * time_window_ns/1000000000;

    return pro



def pseudorapidity(px, py, pz):
    """
    Compute pseudorapidity (eta) from 3-momentum components.

    Parameters:
        px, py, pz : float or array-like

    Returns:
        eta : float or numpy array
    """
    px = np.asarray(px)
    py = np.asarray(py)
    pz = np.asarray(pz)

    pT = np.sqrt(px**2 + py**2)

    # Use asinh form for numerical stability
    eta = np.arcsinh(pz / pT)

    return eta

# %%
import time
from time import perf_counter


def noise_probability_gaussian(freq_kHz=100,time_window_ns=10):
    p = freq_kHz*1000 *time_window_ns/1000000000
    sigma_p = p * 0.01
    single_ph_emission_p = np.random.normal(0, 1) * sigma_p + p
    if single_ph_emission_p < 0:
        single_ph_emission_p = 0

    return single_ph_emission_p

def noise_generation(df_str="../csv/cellmap.csv", freq_kHz=100, time_window_ns=10, event=99999):
    df = pd.read_csv(df_str,  sep = ',')
    hitlist = []
    for index, row in df.iterrows():
        hit_prob = noise_probability_gaussian(freq_kHz,time_window_ns)
        limit = np.random.uniform(0,1)
        #print("p=%f, limit=%f", hit_prob,limit)
        if hit_prob > limit:
            row = row.copy()
            row["event"] = event
            row["time"] = 1
            row["charge"] = 280
            row["pindex"] = 0
            hitlist.append(row)
                        #print(d4)
    return pd.DataFrame(hitlist)

def noiseOnly_dataset(nevents=10, freq_kHz=100, time_window_ns=10):
    start = time.perf_counter()
    df_all = []
    for ev in range(nevents):
        print(f"Evento di rumore #{ev}")
        df_new = noise_generation("../csv/cellmap.csv", freq_kHz, time_window_ns, event=ev)
        if not df_new.empty:
            df_all.append(df_new)

    if df_all:
        df_final = pd.concat(df_all, ignore_index=True)
        df_final = df_final[['event', 'cell_id', 'sector', 'time', 'charge', 'pindex',
                                  'gx', 'gy', 'gz', 'lx', 'ly', 'pdu', 'sipm', 'xi', 'yi']]
    else:
        df_final = pd.DataFrame()  # Nessun evento generato



    end = time.perf_counter()

    print(f"Tempo totale {end - start:.4f} secondi ==> {(end - start)/nevents:.4f}")

    return df_final


def noise_generation_optimized(cellmap, freq_kHz=100, time_window_ns=10, event=99999):
    p = freq_kHz * 1000 * time_window_ns / 1_000_000_000
    sigma_p = p * 0.01

    size = len(cellmap)

    # Genera probabilità gaussiane per tutte le righe
    emission_probs = np.random.normal(loc=p, scale=sigma_p, size=size)

    # Genera probabilità radiali
    #radii = np.sqrt(cellmap["gx"]*cellmap["gx"]+cellmap["gy"]*cellmap["gy"])
    #emission_probs = noise_probability_radial(luminosity_fbi=freq_kHz,time_window_ns=time_window_ns,radius=radii)

    emission_probs = np.clip(emission_probs, 0, None)

    # Genera limiti casuali uniformi
    thresholds = np.random.uniform(0, 1, size)

    # Filtra solo i "veri hit"
    mask = emission_probs > thresholds
    hits = cellmap[mask].copy()

    # Aggiungi colonne
    hits["event"] = event
    hits["time"] = np.random.uniform(0,10000) #added timing
    hits["charge"] = 280
    hits["pindex"] = 0

    return hits


def noiseOnly_dataset_optimized(cellmap, nevents=10, freq_kHz=100, time_window_ns=10):
    start = time.perf_counter()
    all_hits = []

    for ev in range(nevents):
        hits = noise_generation_optimized(cellmap, freq_kHz, time_window_ns, event=ev)
        all_hits.append(hits)

    df_final = pd.concat(all_hits, ignore_index=True)
    df_final = df_final[['event', 'cell_id', 'sector', 'time', 'charge', 'pindex',
                                  'gx', 'gy', 'gz', 'lx', 'ly', 'pdu', 'sipm', 'xi', 'yi']]
    end = time.perf_counter()

    print(f"Tempo totale: {end - start:.4f}s → {(end - start)/nevents:.4f}s per evento")
    return df_final

# %%
import time

def grid_ALCOR_optimized(size, df):
    grid_matrix = np.zeros((1000, 6, 5, size), dtype=int)

    # Filtra il DataFrame per eventi, settori, subsezioni e pdu validi
    df = df[df["event"] < 1000]
    df = df[df["sector"] < 6]
    df["subsec"] = df["pdu"] // 42
    df = df[df["subsec"] < 5]
    df["subpdu"] = df["pdu"] % 42

    # Raggruppa per indici rilevanti
    grouped = df.groupby(["event", "sector", "subsec", "subpdu"]).size()

    # Assegna i conteggi alla matrice
    for (ev, sec, subsec, subpdu), count in grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    return grid_matrix

def grid_ALCOR_optimized_timingaware(size, df, binwidth):
    grid_matrix = np.zeros((1000, 6, 5, size, int(10.16/binwidth)), dtype=int)

    # Filtra il DataFrame per eventi, settori, subsezioni e pdu validi
    df = df[df["event"] < 1000]
    df = df[df["sector"] < 6]
    df["subsec"] = df["pdu"] // 42
    df = df[df["subsec"] < 5]
    df["subpdu"] = df["pdu"] % 42
    df["time"] = df["time"].astype(np.float32)
    timing_col = pd.DataFrame({'time': np.random.uniform(0, 10, len(df["time"]))}, dtype=np.float32)
    df.update(timing_col)
    df["coarse_time"] = df["time"] // binwidth #+ 1

    # Raggruppa per indici rilevanti
    grouped = df.groupby(["event", "sector", "subsec", "subpdu","coarse_time"]).size()

    #Trova il coarse_time più frequente per ogni cella
    #idx = grouped.groupby(level=[0,1,2,3]).idxmax()

    # Assegna i TEMPI alla matrice
    for (ev, sec, subsec, subpdu, coarse_time), count in grouped.items():
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)] = count #* 2.54
        #print(coarse_time)
        #grid_matrix[ev, sec, subsec, subpdu] =  np.bincount(coarse_time).argmax() * 2.54
    return grid_matrix


def grid_ALCOR_optimized_signalonly(size, signal_frame):
    grid_matrix = np.zeros((1000, 6, 5, size), dtype=int)

    # Filtra il DataFrame per eventi, settori, subsezioni e ogni 42 pdu
    sf = signal_frame[signal_frame["event"] < 1000]
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #print(sf)

    # Raggruppa per indici rilevanti
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    # Assegna i conteggi alla matrice (segnale)
    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    return grid_matrix




def grid_ALCOR_optimized_signalplusnoise(size, noise_frame, signal_frame):
    grid_matrix = np.zeros((1000, 6, 5, size), dtype=int)

    # Filtra il DataFrame per eventi, settori, subsezioni e ogni 42 pdu
    nf = noise_frame[noise_frame["event"] < 1000]
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42

    sf = signal_frame[signal_frame["event"] < 1000]
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #print(sf)

    # Raggruppa per indici rilevanti
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    # Assegna i conteggi alla matrice (segnale)
    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count



    # Colonne da confrontare
    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm",  "xi", "yi"]

    # 1. Subset dei DataFrame
    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    # 2. Converti le righe di signal in un set di tuple per confronto efficiente
    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    # 3. Crea una maschera: True se la riga di noise NON è in signal
    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)

    # 4. Applica la maschera a noise per ottenere il risultato filtrato
    filtered_nf = nf[mask]

    # Raggruppa per indici rilevanti
    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu"]).size()



    # Assegna i conteggi alla matrice (noise SE non c'è già segnale)
    for (ev, sec, subsec, subpdu), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] += count

    return grid_matrix


def grid_ALCOR_optimized_signalplusnoise_NOZEROS(size, noise_frame, signal_frame):

    grid_matrix = np.zeros((1000, 6, 5, size), dtype=int)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42

    # --- Preprocessing SIGNAL ---
    sf = signal_frame[signal_frame["event"] < 1000].copy()
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] += count

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix


def grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware(size, noise_frame, signal_frame, binwidth):

    grid_matrix = np.zeros((1000, 6, 5, size, int(10.16/binwidth)), dtype=int)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42
    nf["time"] = nf["time"].astype(np.float32)
    timing_col = pd.DataFrame({'time': np.random.uniform(0, 10.16, len(nf["time"]))}, dtype=np.float32)
    nf.update(timing_col)
    nf["coarse_time"] = (nf["time"] // binwidth)# + 1

    # --- Preprocessing SIGNAL ---

    for ev in range(max(signal_frame["event"])):
        ev=ev+1
        #print(ev)
        #start = perf_counter()
        df = signal_frame[signal_frame["event"]==ev]
        min_time = min(df["time"])
        time_col = ((df["time"].astype(np.float32)-min_time)/16)%10.32
        #time_col = (df["time"]/16)%20.32
        if (ev==1):
            sig_times = time_col
        else:
            df_previous = sig_times
            sig_times =  pd.concat([df_previous.astype(np.float32), time_col.astype(np.float32)])
        end = perf_counter()
        #if(ev%100 == 0):
            #print(f"Tempo totale per eventp: {end - start:.4f}s")

    sf = signal_frame[signal_frame["event"] < 1000].copy()
    #sf = sf[sf["time"] < 10000]
    sf["time"] = sf["time"].astype(np.float32)
    sf.update(sig_times)
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42


    #sf["coarse_time"] = (((sf["time"]*16)-((sf["time"]*16)//10.16)*10.16) // binwidth)
    sf["coarse_time"] = sf["time"] // binwidth

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu","coarse_time"]).size()

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu", "coarse_time"]).size()
    for (ev, sec, subsec, subpdu, coarse_time), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54

    #all_grouped = pd.concat([signal_grouped, noise_grouped], axis=0)
    #idx = all_grouped.groupby(level=[0,1,2,3]).idxmax()

    #for (ev, sec, subsec, subpdu, coarse_time), count in all_grouped.items():
        #grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54
    for (ev, sec, subsec, subpdu, coarse_time), count in signal_grouped.items():
        #min_df = sf[sf["event"]==ev]
        #min_time = min(min_df["time"])
        #time_col = ((df["time"]-min_time)/16)%20.32
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] += count #* 2.54

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix

# %%
def grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_acceptancefiltered(size, noise_frame, rec_signal_frame, sim_signal_frame, binwidth):

    grid_matrix = np.zeros((1000, 6, 5, size, int(10.16/binwidth)), dtype=int)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42
    nf["time"] = nf["time"].astype(np.float32)
    timing_col = pd.DataFrame({'time': np.random.uniform(0, 10.16, len(nf["time"]))}, dtype=np.float32)
    nf.update(timing_col)
    nf["coarse_time"] = (nf["time"] // binwidth)# + 1

    # --- Preprocessing SIGNAL ---

    for ev in range(max(rec_signal_frame["event"])):
        ev=ev+1
        #print(ev)
        #start = perf_counter()
        df = rec_signal_frame[rec_signal_frame["event"]==ev]
        min_time = min(df["time"])
        time_col = ((df["time"].astype(np.float32)-min_time)/16)%10.32
        #time_col = (df["time"]/16)%20.32
        if (ev==1):
            sig_times = time_col
        else:
            df_previous = sig_times
            sig_times =  pd.concat([df_previous.astype(np.float32), time_col.astype(np.float32)])
        end = perf_counter()
        #if(ev%100 == 0):
            #print(f"Tempo totale per eventp: {end - start:.4f}s")

    sf = rec_signal_frame[rec_signal_frame["event"] < 1000].copy()
    #sf = sf[sf["time"] < 10000]
    sf["time"] = sf["time"].astype(np.float32)
    sf.update(sig_times)
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #acceptance filter
    sim_sf = sim_signal_frame[sim_signal_frame["event"] < 1000].copy()
    eta = pseudorapidity(sim_sf["px"], sim_sf["py"], sim_sf["pz"])
    eta_mask = (eta >= 1.5) & (eta<=3.5)
    sim_sf = sim_sf[eta_mask]
    #sf = sf[sf["pindex"].isin(sim_sf["pindex"])]
    sf = sf.merge(sim_sf[["event", "pindex"]], on=["event", "pindex"],how="inner")

    #sf["coarse_time"] = (((sf["time"]*16)-((sf["time"]*16)//10.16)*10.16) // binwidth)
    sf["coarse_time"] = sf["time"] // binwidth

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu","coarse_time"]).size()

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu", "coarse_time"]).size()
    for (ev, sec, subsec, subpdu, coarse_time), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54

    #all_grouped = pd.concat([signal_grouped, noise_grouped], axis=0)
    #idx = all_grouped.groupby(level=[0,1,2,3]).idxmax()

    #for (ev, sec, subsec, subpdu, coarse_time), count in all_grouped.items():
        #grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54
    for (ev, sec, subsec, subpdu, coarse_time), count in signal_grouped.items():
        #min_df = sf[sf["event"]==ev]
        #min_time = min(min_df["time"])
        #time_col = ((df["time"]-min_time)/16)%20.32
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] += count #* 2.54

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix


def grid_ALCOR_optimized_signalplusnoise_NOZEROS_acceptancefiltered(size, noise_frame, rec_signal_frame,sim_signal_frame):

    grid_matrix = np.zeros((1000, 6, 5, size), dtype=int)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42

    # --- Preprocessing SIGNAL ---
    sf = rec_signal_frame[rec_signal_frame["event"] < 1000].copy()
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #acceptance filter
    sim_sf = sim_signal_frame[sim_signal_frame["event"] < 1000].copy()
    eta = pseudorapidity(sim_sf["px"], sim_sf["py"], sim_sf["pz"])
    eta_mask = (eta >= 1.5) & (eta<=3.5)
    sim_sf = sim_sf[eta_mask]
    #sf = sf[sf["pindex"].isin(sim_sf["pindex"])]
    sf = sf.merge(sim_sf[["event", "pindex"]], on=["event", "pindex"],how="inner")

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] += count

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix

# %%
def grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_nparticles(size, noise_frame, rec_signal_frame, sim_signal_frame, binwidth):

    grid_matrix = np.zeros((1000, 6, 5, size, int(10.16/binwidth)), dtype=int)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42
    nf["time"] = nf["time"].astype(np.float32)
    timing_col = pd.DataFrame({'time': np.random.uniform(0, 10.16, len(nf["time"]))}, dtype=np.float32)
    nf.update(timing_col)
    nf["coarse_time"] = (nf["time"] // binwidth)# + 1

    # --- Preprocessing SIGNAL ---

    for ev in range(max(rec_signal_frame["event"])):
        ev=ev+1
        #print(ev)
        #start = perf_counter()
        df = rec_signal_frame[rec_signal_frame["event"]==ev]
        min_time = min(df["time"])
        time_col = ((df["time"].astype(np.float32)-min_time)/16)%10.32
        #time_col = (df["time"]/16)%20.32
        if (ev==1):
            sig_times = time_col
        else:
            df_previous = sig_times
            sig_times =  pd.concat([df_previous.astype(np.float32), time_col.astype(np.float32)])
        end = perf_counter()
        #if(ev%100 == 0):
            #print(f"Tempo totale per eventp: {end - start:.4f}s")

    sf = rec_signal_frame[rec_signal_frame["event"] < 1000].copy()
    #sf = sf[sf["time"] < 10000]
    sf["time"] = sf["time"].astype(np.float32)
    sf.update(sig_times)
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #nparticles
    sim_sf = sim_signal_frame[sim_signal_frame["event"] < 1000].copy()
    nparticles_count = sim_sf.groupby("event")["pindex"].nunique().clip(upper=3)
    nparticles_capped = nparticles_count.values
    y_onehot = pd.get_dummies(nparticles_capped)
    y_onehot = y_onehot.reindex(columns=[0, 1, 2, 3], fill_value=0).astype(int)
    y_onehot = y_onehot.to_numpy().astype(int)

    #sf["coarse_time"] = (((sf["time"]*16)-((sf["time"]*16)//10.16)*10.16) // binwidth)
    sf["coarse_time"] = sf["time"] // binwidth

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu","coarse_time"]).size()

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu", "coarse_time"]).size()
    for (ev, sec, subsec, subpdu, coarse_time), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54

    #all_grouped = pd.concat([signal_grouped, noise_grouped], axis=0)
    #idx = all_grouped.groupby(level=[0,1,2,3]).idxmax()

    #for (ev, sec, subsec, subpdu, coarse_time), count in all_grouped.items():
        #grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54
    for (ev, sec, subsec, subpdu, coarse_time), count in signal_grouped.items():
        #min_df = sf[sf["event"]==ev]
        #min_time = min(min_df["time"])
        #time_col = ((df["time"]-min_time)/16)%20.32
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] += count #* 2.54

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix, y_onehot


def grid_ALCOR_optimized_signalplusnoise_NOZEROS_nparticles(size, noise_frame, rec_signal_frame,sim_signal_frame):

    #grid_matrix = np.zeros((1000, 6, 5, size), dtype=int)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42

    # --- Preprocessing SIGNAL ---
    sf = rec_signal_frame[rec_signal_frame["event"] < 1000].copy()
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    grid_matrix = np.zeros((len(sf["event"].unique()), 6, 5, size), dtype=int)
    nparticles_y_array = np.zeros((len(sf["event"].unique()),4), dtype=int)


    #nparticles
    sim_sf = sim_signal_frame[sim_signal_frame["event"] < 1000].copy()
    print(len(sim_sf["event"].unique()))
    nparticles_count = sim_sf.groupby("event")["pindex"].nunique().clip(upper=3)
    nparticles_capped = nparticles_count.values
    y_onehot = pd.get_dummies(nparticles_capped)
    y_onehot = y_onehot.reindex(columns=[0, 1, 2, 3], fill_value=0).astype(int)
    y_onehot = y_onehot.to_numpy().astype(int)

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] += count

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix, y_onehot

# %%
n_reco_files = 100
nevents = 1000

#cellmap = pd.read_csv("/tmp/cellmap.csv",  sep = ',')
cellmap = pd.read_csv("/content/drive/MyDrive/project_files/cellmap.csv", sep=',')


FREQ = 150
frequences =  [FREQ]   # [3, 5, 10, 25, 50, 75, 100, 150, 200, 250, 300]
##_________________________________________________________________________#
# per generare i file di rumore va impostato su True
GEN = True
##______________________________________________________________________#
binwidth = 2.54

# %%
if(GEN):
    for f in frequences:
        #print(f)
        for nfile in range(n_reco_files):
            print(f"\n--- Generazione file ricostruito {nfile} ==> noise rate = {f} kHz ---")
            df_noise = noiseOnly_dataset_optimized(cellmap,nevents=nevents, freq_kHz=f,time_window_ns=10)
            #time info added
            df_noise["time"] = df_noise["time"].astype(np.float32)
            timing_col = pd.DataFrame({'time': np.random.uniform(0, 10.16, len(df_noise["time"]))}, dtype=np.float32)
            df_noise.update(timing_col)

            # Definiamo la cartella Google Drive
            cartella_destinazione = "/content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/"
            # Questo comando crea la cartella su Drive se non esiste ancora
            os.makedirs(cartella_destinazione, exist_ok=True)

            output_filename = os.path.join(cartella_destinazione, f"noise_reco_{nfile}_{f}kHz_10ns.csv")
            df_noise.to_csv(output_filename, index=False)
            print(f"Salvato in {output_filename}")
# Out:
# --- Generazione file ricostruito 0 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3683s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_0_150kHz_10ns.csv
#
# --- Generazione file ricostruito 1 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5482s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_1_150kHz_10ns.csv
#
# --- Generazione file ricostruito 2 ==> noise rate = 150 kHz ---
# Tempo totale: 14.8167s → 0.0148s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_2_150kHz_10ns.csv
#
# --- Generazione file ricostruito 3 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4765s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_3_150kHz_10ns.csv
#
# --- Generazione file ricostruito 4 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4162s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_4_150kHz_10ns.csv
#
# --- Generazione file ricostruito 5 ==> noise rate = 150 kHz ---
# Tempo totale: 14.9175s → 0.0149s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_5_150kHz_10ns.csv
#
# --- Generazione file ricostruito 6 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4351s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_6_150kHz_10ns.csv
#
# --- Generazione file ricostruito 7 ==> noise rate = 150 kHz ---
# Tempo totale: 16.5417s → 0.0165s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_7_150kHz_10ns.csv
#
# --- Generazione file ricostruito 8 ==> noise rate = 150 kHz ---
# Tempo totale: 14.8296s → 0.0148s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_8_150kHz_10ns.csv
#
# --- Generazione file ricostruito 9 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3232s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_9_150kHz_10ns.csv
#
# --- Generazione file ricostruito 10 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4087s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_10_150kHz_10ns.csv
#
# --- Generazione file ricostruito 11 ==> noise rate = 150 kHz ---
# Tempo totale: 15.0560s → 0.0151s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_11_150kHz_10ns.csv
#
# --- Generazione file ricostruito 12 ==> noise rate = 150 kHz ---
# Tempo totale: 14.2904s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_12_150kHz_10ns.csv
#
# --- Generazione file ricostruito 13 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4003s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_13_150kHz_10ns.csv
#
# --- Generazione file ricostruito 14 ==> noise rate = 150 kHz ---
# Tempo totale: 14.6263s → 0.0146s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_14_150kHz_10ns.csv
#
# --- Generazione file ricostruito 15 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3373s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_15_150kHz_10ns.csv
#
# --- Generazione file ricostruito 16 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3717s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_16_150kHz_10ns.csv
#
# --- Generazione file ricostruito 17 ==> noise rate = 150 kHz ---
# Tempo totale: 14.6349s → 0.0146s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_17_150kHz_10ns.csv
#
# --- Generazione file ricostruito 18 ==> noise rate = 150 kHz ---
# Tempo totale: 14.6134s → 0.0146s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_18_150kHz_10ns.csv
#
# --- Generazione file ricostruito 19 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4342s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_19_150kHz_10ns.csv
#
# --- Generazione file ricostruito 20 ==> noise rate = 150 kHz ---
# Tempo totale: 14.7814s → 0.0148s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_20_150kHz_10ns.csv
#
# --- Generazione file ricostruito 21 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3407s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_21_150kHz_10ns.csv
#
# --- Generazione file ricostruito 22 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4393s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_22_150kHz_10ns.csv
#
# --- Generazione file ricostruito 23 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5496s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_23_150kHz_10ns.csv
#
# --- Generazione file ricostruito 24 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4539s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_24_150kHz_10ns.csv
#
# --- Generazione file ricostruito 25 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4942s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_25_150kHz_10ns.csv
#
# --- Generazione file ricostruito 26 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5494s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_26_150kHz_10ns.csv
#
# --- Generazione file ricostruito 27 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5093s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_27_150kHz_10ns.csv
#
# --- Generazione file ricostruito 28 ==> noise rate = 150 kHz ---
# Tempo totale: 18.4350s → 0.0184s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_28_150kHz_10ns.csv
#
# --- Generazione file ricostruito 29 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3616s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_29_150kHz_10ns.csv
#
# --- Generazione file ricostruito 30 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4089s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_30_150kHz_10ns.csv
#
# --- Generazione file ricostruito 31 ==> noise rate = 150 kHz ---
# Tempo totale: 14.7712s → 0.0148s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_31_150kHz_10ns.csv
#
# --- Generazione file ricostruito 32 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3050s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_32_150kHz_10ns.csv
#
# --- Generazione file ricostruito 33 ==> noise rate = 150 kHz ---
# Tempo totale: 14.7272s → 0.0147s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_33_150kHz_10ns.csv
#
# --- Generazione file ricostruito 34 ==> noise rate = 150 kHz ---
# Tempo totale: 15.1394s → 0.0151s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_34_150kHz_10ns.csv
#
# --- Generazione file ricostruito 35 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5222s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_35_150kHz_10ns.csv
#
# --- Generazione file ricostruito 36 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4813s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_36_150kHz_10ns.csv
#
# --- Generazione file ricostruito 37 ==> noise rate = 150 kHz ---
# Tempo totale: 18.4782s → 0.0185s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_37_150kHz_10ns.csv
#
# --- Generazione file ricostruito 38 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4207s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_38_150kHz_10ns.csv
#
# --- Generazione file ricostruito 39 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4476s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_39_150kHz_10ns.csv
#
# --- Generazione file ricostruito 40 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5435s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_40_150kHz_10ns.csv
#
# --- Generazione file ricostruito 41 ==> noise rate = 150 kHz ---
# Tempo totale: 14.2775s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_41_150kHz_10ns.csv
#
# --- Generazione file ricostruito 42 ==> noise rate = 150 kHz ---
# Tempo totale: 14.6240s → 0.0146s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_42_150kHz_10ns.csv
#
# --- Generazione file ricostruito 43 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3524s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_43_150kHz_10ns.csv
#
# --- Generazione file ricostruito 44 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4311s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_44_150kHz_10ns.csv
#
# --- Generazione file ricostruito 45 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3790s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_45_150kHz_10ns.csv
#
# --- Generazione file ricostruito 46 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5029s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_46_150kHz_10ns.csv
#
# --- Generazione file ricostruito 47 ==> noise rate = 150 kHz ---
# Tempo totale: 14.2847s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_47_150kHz_10ns.csv
#
# --- Generazione file ricostruito 48 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3335s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_48_150kHz_10ns.csv
#
# --- Generazione file ricostruito 49 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5167s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_49_150kHz_10ns.csv
#
# --- Generazione file ricostruito 50 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3294s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_50_150kHz_10ns.csv
#
# --- Generazione file ricostruito 51 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3098s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_51_150kHz_10ns.csv
#
# --- Generazione file ricostruito 52 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3266s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_52_150kHz_10ns.csv
#
# --- Generazione file ricostruito 53 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3548s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_53_150kHz_10ns.csv
#
# --- Generazione file ricostruito 54 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5094s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_54_150kHz_10ns.csv
#
# --- Generazione file ricostruito 55 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5045s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_55_150kHz_10ns.csv
#
# --- Generazione file ricostruito 56 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3761s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_56_150kHz_10ns.csv
#
# --- Generazione file ricostruito 57 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3213s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_57_150kHz_10ns.csv
#
# --- Generazione file ricostruito 58 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3184s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_58_150kHz_10ns.csv
#
# --- Generazione file ricostruito 59 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5145s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_59_150kHz_10ns.csv
#
# --- Generazione file ricostruito 60 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3629s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_60_150kHz_10ns.csv
#
# --- Generazione file ricostruito 61 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3707s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_61_150kHz_10ns.csv
#
# --- Generazione file ricostruito 62 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4248s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_62_150kHz_10ns.csv
#
# --- Generazione file ricostruito 63 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3228s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_63_150kHz_10ns.csv
#
# --- Generazione file ricostruito 64 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4020s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_64_150kHz_10ns.csv
#
# --- Generazione file ricostruito 65 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3624s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_65_150kHz_10ns.csv
#
# --- Generazione file ricostruito 66 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4087s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_66_150kHz_10ns.csv
#
# --- Generazione file ricostruito 67 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3484s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_67_150kHz_10ns.csv
#
# --- Generazione file ricostruito 68 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3145s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_68_150kHz_10ns.csv
#
# --- Generazione file ricostruito 69 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5102s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_69_150kHz_10ns.csv
#
# --- Generazione file ricostruito 70 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5033s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_70_150kHz_10ns.csv
#
# --- Generazione file ricostruito 71 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4644s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_71_150kHz_10ns.csv
#
# --- Generazione file ricostruito 72 ==> noise rate = 150 kHz ---
# Tempo totale: 14.7606s → 0.0148s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_72_150kHz_10ns.csv
#
# --- Generazione file ricostruito 73 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3902s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_73_150kHz_10ns.csv
#
# --- Generazione file ricostruito 74 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3769s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_74_150kHz_10ns.csv
#
# --- Generazione file ricostruito 75 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5075s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_75_150kHz_10ns.csv
#
# --- Generazione file ricostruito 76 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3986s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_76_150kHz_10ns.csv
#
# --- Generazione file ricostruito 77 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3752s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_77_150kHz_10ns.csv
#
# --- Generazione file ricostruito 78 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4923s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_78_150kHz_10ns.csv
#
# --- Generazione file ricostruito 79 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5291s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_79_150kHz_10ns.csv
#
# --- Generazione file ricostruito 80 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3494s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_80_150kHz_10ns.csv
#
# --- Generazione file ricostruito 81 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3381s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_81_150kHz_10ns.csv
#
# --- Generazione file ricostruito 82 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4943s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_82_150kHz_10ns.csv
#
# --- Generazione file ricostruito 83 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4824s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_83_150kHz_10ns.csv
#
# --- Generazione file ricostruito 84 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4630s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_84_150kHz_10ns.csv
#
# --- Generazione file ricostruito 85 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5931s → 0.0146s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_85_150kHz_10ns.csv
#
# --- Generazione file ricostruito 86 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4173s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_86_150kHz_10ns.csv
#
# --- Generazione file ricostruito 87 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4589s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_87_150kHz_10ns.csv
#
# --- Generazione file ricostruito 88 ==> noise rate = 150 kHz ---
# Tempo totale: 14.6006s → 0.0146s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_88_150kHz_10ns.csv
#
# --- Generazione file ricostruito 89 ==> noise rate = 150 kHz ---
# Tempo totale: 14.7105s → 0.0147s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_89_150kHz_10ns.csv
#
# --- Generazione file ricostruito 90 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5592s → 0.0146s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_90_150kHz_10ns.csv
#
# --- Generazione file ricostruito 91 ==> noise rate = 150 kHz ---
# Tempo totale: 15.9183s → 0.0159s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_91_150kHz_10ns.csv
#
# --- Generazione file ricostruito 92 ==> noise rate = 150 kHz ---
# Tempo totale: 16.0506s → 0.0161s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_92_150kHz_10ns.csv
#
# --- Generazione file ricostruito 93 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5994s → 0.0146s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_93_150kHz_10ns.csv
#
# --- Generazione file ricostruito 94 ==> noise rate = 150 kHz ---
# Tempo totale: 14.5164s → 0.0145s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_94_150kHz_10ns.csv
#
# --- Generazione file ricostruito 95 ==> noise rate = 150 kHz ---
# Tempo totale: 14.7341s → 0.0147s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_95_150kHz_10ns.csv
#
# --- Generazione file ricostruito 96 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3111s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_96_150kHz_10ns.csv
#
# --- Generazione file ricostruito 97 ==> noise rate = 150 kHz ---
# Tempo totale: 14.3077s → 0.0143s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_97_150kHz_10ns.csv
#
# --- Generazione file ricostruito 98 ==> noise rate = 150 kHz ---
# Tempo totale: 14.8701s → 0.0149s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_98_150kHz_10ns.csv
#
# --- Generazione file ricostruito 99 ==> noise rate = 150 kHz ---
# Tempo totale: 14.4181s → 0.0144s per evento
# Salvato in /content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_99_150kHz_10ns.csv

# %%
import os
import pandas as pd
import numpy as np
import time

nfiles = 582
df_rec_signal_list = []
df_index = 0
new_file_init = True

start = time.perf_counter()
print(f"RECONSTRUCTION DATASET")
for f in range(nfiles):
    print(f"SIGNAL FILE n.{f}")

    file_string = f"/content/drive/MyDrive/project_files/Bkg_new/rec_hits_{f+1:04d}.csv"
    if not os.path.exists(file_string):
        print(file_string + " skipped!")
        continue

    # Leggi CSV
    df_rec_signal = pd.read_csv(file_string, sep=',')

    # Salta DataFrame vuoti o senza colonna "event"
    if df_rec_signal.empty or "event" not in df_rec_signal.columns:
        continue

    # Riallinea eventi locali partendo da 0
    df_rec_signal["event"] = df_rec_signal.groupby("event", sort=False).ngroup()

    # Converte a intero per sicurezza
    df_rec_signal["event"] = df_rec_signal["event"].astype(int)

    nevents = df_rec_signal["event"].max()

    if new_file_init:
        # Split se supera 999
        if nevents > 999:
            df1 = df_rec_signal[df_rec_signal["event"] <= 999].copy()
            df2 = df_rec_signal[df_rec_signal["event"] > 999].copy()

            if not df2.empty:
                df2["event"] = (df2["event"] - df2["event"].min()) % 1000
                df2["event"] = df2["event"].astype(int)

            df_rec_signal_list.append(df1)
            df_index += 1
            df_rec_signal_list.append(df2)
        else:
            df_rec_signal_list.append(df_rec_signal)
        new_file_init = False
    else:
        # Offset globale rispetto al precedente, modulo 1000 per wrap
        df_previous = df_rec_signal_list[df_index]
        prev_max = df_previous["event"].max() if not df_previous.empty else -1
        df_rec_signal["event"] = (df_rec_signal["event"] + prev_max + 1)# % 1000
        df_rec_signal["event"] = df_rec_signal["event"].astype(int)

        # Concatenate temporanea
        df_conc = pd.concat([df_previous, df_rec_signal], ignore_index=True)
        nev = df_conc["event"].max()

        if nev > 999:
            df1 = df_conc[df_conc["event"] <= 999].copy()
            df2 = df_conc[df_conc["event"] > 999].copy()

            if not df2.empty:
                df2["event"] = (df2["event"] - df2["event"].min()) % 1000
                df2["event"] = df2["event"].astype(int)

            df_rec_signal_list[df_index] = df1
            df_index += 1
            df_rec_signal_list.append(df2)
            new_file_init = False
        else:
            df_rec_signal_list[df_index] = df_conc
            if nev == 999:
                new_file_init = True

end = time.perf_counter()
print(f"Tempo totale conversione file csv in stringa: {end - start:.4f}s")
# Out:
# RECONSTRUCTION DATASET
# SIGNAL FILE n.0
# SIGNAL FILE n.1
# SIGNAL FILE n.2
# SIGNAL FILE n.3
# SIGNAL FILE n.4
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0523.csv skipped!
# SIGNAL FILE n.523
# SIGNAL FILE n.524
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0525.csv skipped!
# SIGNAL FILE n.525
# SIGNAL FILE n.526
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0527.csv skipped!
# SIGNAL FILE n.527
# SIGNAL FILE n.528
# SIGNAL FILE n.529
# SIGNAL FILE n.530
# SIGNAL FILE n.531
# SIGNAL FILE n.532
# SIGNAL FILE n.533
# SIGNAL FILE n.534
# SIGNAL FILE n.535
# SIGNAL FILE n.536
# SIGNAL FILE n.537
# SIGNAL FILE n.538
# SIGNAL FILE n.539
# SIGNAL FILE n.540
# SIGNAL FILE n.541
# SIGNAL FILE n.542
# SIGNAL FILE n.543
# SIGNAL FILE n.544
# SIGNAL FILE n.545
# SIGNAL FILE n.546
# SIGNAL FILE n.547
# SIGNAL FILE n.548
# SIGNAL FILE n.549
# SIGNAL FILE n.550
# SIGNAL FILE n.551
# SIGNAL FILE n.552
# SIGNAL FILE n.553
# SIGNAL FILE n.554
# SIGNAL FILE n.555
# SIGNAL FILE n.556
# SIGNAL FILE n.557
# SIGNAL FILE n.558
# SIGNAL FILE n.559
# SIGNAL FILE n.560
# SIGNAL FILE n.561
# SIGNAL FILE n.562
# SIGNAL FILE n.563
# SIGNAL FILE n.564
# SIGNAL FILE n.565
# SIGNAL FILE n.566
# SIGNAL FILE n.567
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0568.csv skipped!
# SIGNAL FILE n.568
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0569.csv skipped!
# SIGNAL FILE n.569
# SIGNAL FILE n.570
# SIGNAL FILE n.571
# SIGNAL FILE n.572
# SIGNAL FILE n.573
# SIGNAL FILE n.574
# SIGNAL FILE n.575
# SIGNAL FILE n.576
# SIGNAL FILE n.577
# SIGNAL FILE n.578
# SIGNAL FILE n.579
# SIGNAL FILE n.580
# SIGNAL FILE n.581
# Tempo totale merging SIG+NOISE: 439.4828s

# %%
import os
import pandas as pd
import numpy as np
import time

nfiles = 582
df_sim_signal_list = []
df_index = 0
new_file_init = True

start = time.perf_counter()
print(f"SIMULATION DATASET")
for f in range(nfiles):
    print(f"SIGNAL FILE n.{f}")

    file_string = f"/content/drive/MyDrive/project_files/Bkg_1SignalPer2usframe_2601/sim_parts_{f+1:04d}.csv"

    if not os.path.exists(file_string):
        print(file_string + " skipped!")
        continue

    # Leggi CSV
    df_sim_signal = pd.read_csv(file_string, sep=',')

    # Salta DataFrame vuoti o senza colonna "event"
    if df_sim_signal.empty or "event" not in df_sim_signal.columns:
        continue

    # Riallinea eventi locali partendo da 0
    df_sim_signal["event"] = df_sim_signal.groupby("event", sort=False).ngroup()

    # Converte a intero per sicurezza
    df_sim_signal["event"] = df_sim_signal["event"].astype(int)

    nevents = df_sim_signal["event"].max()

    if new_file_init:
        # Split se supera 999
        if nevents > 999:
            df1 = df_sim_signal[df_sim_signal["event"] <= 999].copy()
            df2 = df_sim_signal[df_sim_signal["event"] > 999].copy()

            if not df2.empty:
                df2["event"] = (df2["event"] - df2["event"].min()) % 1000
                df2["event"] = df2["event"].astype(int)

            df_sim_signal_list.append(df1)
            df_index += 1
            df_sim_signal_list.append(df2)
        else:
            df_sim_signal_list.append(df_rec_signal)
        new_file_init = False
    else:
        # Offset globale rispetto al precedente, modulo 1000 per wrap
        df_previous = df_sim_signal_list[df_index]
        prev_max = df_previous["event"].max() if not df_previous.empty else -1
        df_sim_signal["event"] = (df_sim_signal["event"] + prev_max + 1)# % 1000
        df_sim_signal["event"] = df_sim_signal["event"].astype(int)

        # Concatenate temporanea
        df_conc = pd.concat([df_previous, df_sim_signal], ignore_index=True)
        nev = df_conc["event"].max()

        if nev > 999:
            df1 = df_conc[df_conc["event"] <= 999].copy()
            df2 = df_conc[df_conc["event"] > 999].copy()

            if not df2.empty:
                df2["event"] = (df2["event"] - df2["event"].min()) % 1000
                df2["event"] = df2["event"].astype(int)

            df_sim_signal_list[df_index] = df1
            df_index += 1
            df_sim_signal_list.append(df2)
            new_file_init = False
        else:
            df_sim_signal_list[df_index] = df_conc
            if nev == 999:
                new_file_init = True

end = time.perf_counter()
print(f"Tempo totale merging SIG+NOISE: {end - start:.4f}s")

# %%
input_signal_matrices = []
input_nparticles_array = []


for f in range(1,len(df_rec_signal_list)-1):
    print("SIGNAL FILE n.%d" % (f))
    start = time.perf_counter()
    #df_rec_signal     = pd.read_csv("/apotto/home1/aliens/apepic/work/rossi/drich_eic/csv/no_noise_events_Bkg_realistic_25_05/rec_hits.csv.%04d.csv" % (f+1), sep = ',')
    df_rec_signal    = df_rec_signal_list[f]
    #df_sim_signal    = df_sim_signal_list[f]
    df_rec_noise     = pd.read_csv(f"/content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_{f}_{FREQ}kHz_10ns.csv")

    #ALCOR_gridmatrix_total, nparticles_array = grid_ALCOR_optimized_signalplusnoise_NOZEROS_nparticles(42, df_rec_noise, df_rec_signal, df_sim_signal)
    #ALCOR_gridmatrix_total, nparticles_array = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_nparticles(42, df_rec_noise, df_rec_signal, df_sim_signal, binwidth,)
    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_acceptancefiltered(42, df_rec_noise, df_rec_signal, df_sim_signal)
    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_acceptancefiltered(42, df_rec_noise, df_rec_signal, df_sim_signal, binwidth,)
    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware(42, df_rec_noise, df_rec_signal,binwidth)
    ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS(42, df_rec_noise, df_rec_signal)
    print(ALCOR_gridmatrix_total.shape)
    #print(nparticles_array.shape)
    #ALCOR_gridmatrix_total = ALCOR_gridmatrix_total.reshape(ALCOR_gridmatrix_total.shape[0],6,5,42*int(10.16/binwidth))
    ALCOR_gridmatrix_total = ALCOR_gridmatrix_total.reshape(ALCOR_gridmatrix_total.shape[0],6,5,42)

    input_signal_matrices.append(ALCOR_gridmatrix_total)

    #input_nparticles_array.append(nparticles_array)


    end = time.perf_counter()
    print(f"Tempo totale: {end - start:.4f}s")
# Out:
# SIGNAL FILE n.1
# (1000, 6, 5, 42)
# Tempo totale: 8.9137s
# SIGNAL FILE n.2
# (1000, 6, 5, 42)
# Tempo totale: 6.0030s
# SIGNAL FILE n.3
# (1000, 6, 5, 42)
# Tempo totale: 7.5418s
# SIGNAL FILE n.4
# (1000, 6, 5, 42)
# Tempo totale: 5.7453s
# SIGNAL FILE n.5
# (1000, 6, 5, 42)
# Tempo totale: 5.8560s
# SIGNAL FILE n.6
# (1000, 6, 5, 42)
# Tempo totale: 5.0530s
# SIGNAL FILE n.7
# (1000, 6, 5, 42)
# Tempo totale: 5.4910s
# SIGNAL FILE n.8
# (1000, 6, 5, 42)
# Tempo totale: 6.4849s
# SIGNAL FILE n.9
# (1000, 6, 5, 42)
# Tempo totale: 5.6194s
# SIGNAL FILE n.10
# (1000, 6, 5, 42)
# Tempo totale: 7.0789s
# SIGNAL FILE n.11
# (1000, 6, 5, 42)
# Tempo totale: 4.9523s
# SIGNAL FILE n.12
# (1000, 6, 5, 42)
# Tempo totale: 5.7455s
# SIGNAL FILE n.13
# (1000, 6, 5, 42)
# Tempo totale: 5.0722s
# SIGNAL FILE n.14
# (1000, 6, 5, 42)
# Tempo totale: 5.0103s
# SIGNAL FILE n.15
# (1000, 6, 5, 42)
# Tempo totale: 7.2426s
# SIGNAL FILE n.16
# (1000, 6, 5, 42)
# Tempo totale: 5.1082s
# SIGNAL FILE n.17
# (1000, 6, 5, 42)
# Tempo totale: 5.4888s
# SIGNAL FILE n.18
# (1000, 6, 5, 42)
# Tempo totale: 5.0950s
# SIGNAL FILE n.19
# (1000, 6, 5, 42)
# Tempo totale: 5.1344s
# SIGNAL FILE n.20
# (1000, 6, 5, 42)
# Tempo totale: 6.7167s
# SIGNAL FILE n.21
# (1000, 6, 5, 42)
# Tempo totale: 4.8822s
# SIGNAL FILE n.22
# (1000, 6, 5, 42)
# Tempo totale: 5.5630s
# SIGNAL FILE n.23
# (1000, 6, 5, 42)
# Tempo totale: 5.7587s
# SIGNAL FILE n.24
# (1000, 6, 5, 42)
# Tempo totale: 5.0474s
# SIGNAL FILE n.25
# (1000, 6, 5, 42)
# Tempo totale: 6.4202s
# SIGNAL FILE n.26
# (1000, 6, 5, 42)
# Tempo totale: 5.3573s
# SIGNAL FILE n.27
# (1000, 6, 5, 42)
# Tempo totale: 6.9534s
# SIGNAL FILE n.28
# (1000, 6, 5, 42)
# Tempo totale: 5.6844s
# SIGNAL FILE n.29
# (1000, 6, 5, 42)
# Tempo totale: 7.6275s
# SIGNAL FILE n.30
# (1000, 6, 5, 42)
# Tempo totale: 5.5663s
# SIGNAL FILE n.31
# (1000, 6, 5, 42)
# Tempo totale: 5.7573s
# SIGNAL FILE n.32
# (1000, 6, 5, 42)
# Tempo totale: 5.2006s
# SIGNAL FILE n.33
# (1000, 6, 5, 42)
# Tempo totale: 5.8473s
# SIGNAL FILE n.34
# (1000, 6, 5, 42)
# Tempo totale: 6.6193s
# SIGNAL FILE n.35
# (1000, 6, 5, 42)
# Tempo totale: 5.1219s
# SIGNAL FILE n.36
# (1000, 6, 5, 42)
# Tempo totale: 7.2281s
# SIGNAL FILE n.37
# (1000, 6, 5, 42)
# Tempo totale: 5.7398s
# SIGNAL FILE n.38
# (1000, 6, 5, 42)
# Tempo totale: 4.9512s
# SIGNAL FILE n.39
# (1000, 6, 5, 42)
# Tempo totale: 5.2106s
# SIGNAL FILE n.40
# (1000, 6, 5, 42)
# Tempo totale: 5.2317s
# SIGNAL FILE n.41
# (1000, 6, 5, 42)
# Tempo totale: 7.3800s
# SIGNAL FILE n.42
# (1000, 6, 5, 42)
# Tempo totale: 4.9128s
# SIGNAL FILE n.43
# (1000, 6, 5, 42)
# Tempo totale: 7.0519s
# SIGNAL FILE n.44
# (1000, 6, 5, 42)
# Tempo totale: 5.8603s
# SIGNAL FILE n.45
# (1000, 6, 5, 42)
# Tempo totale: 5.8926s
# SIGNAL FILE n.46
# (1000, 6, 5, 42)
# Tempo totale: 5.0770s
# SIGNAL FILE n.47
# (1000, 6, 5, 42)
# Tempo totale: 5.3125s
# SIGNAL FILE n.48
# (1000, 6, 5, 42)
# Tempo totale: 6.5096s
# SIGNAL FILE n.49
# (1000, 6, 5, 42)
# Tempo totale: 4.9807s
# SIGNAL FILE n.50
# (1000, 6, 5, 42)
# Tempo totale: 7.2312s
# SIGNAL FILE n.51
# (1000, 6, 5, 42)
# Tempo totale: 5.0967s
# SIGNAL FILE n.52
# (1000, 6, 5, 42)
# Tempo totale: 7.9516s
# SIGNAL FILE n.53
# (1000, 6, 5, 42)
# Tempo totale: 5.5450s
# SIGNAL FILE n.54
# (1000, 6, 5, 42)
# Tempo totale: 5.2525s
# SIGNAL FILE n.55
# (1000, 6, 5, 42)
# Tempo totale: 5.5560s
# SIGNAL FILE n.56
# (1000, 6, 5, 42)
# Tempo totale: 5.4671s
# SIGNAL FILE n.57
# (1000, 6, 5, 42)
# Tempo totale: 7.4173s
# SIGNAL FILE n.58
# (1000, 6, 5, 42)
# Tempo totale: 5.1180s
# SIGNAL FILE n.59
# (1000, 6, 5, 42)
# Tempo totale: 6.6234s
# SIGNAL FILE n.60
# (1000, 6, 5, 42)
# Tempo totale: 5.1663s
# SIGNAL FILE n.61
# (1000, 6, 5, 42)
# Tempo totale: 5.0735s
# SIGNAL FILE n.62
# (1000, 6, 5, 42)
# Tempo totale: 6.0492s
# SIGNAL FILE n.63
# (1000, 6, 5, 42)
# Tempo totale: 5.3740s
# SIGNAL FILE n.64
# (1000, 6, 5, 42)
# Tempo totale: 6.0194s
# SIGNAL FILE n.65
# (1000, 6, 5, 42)
# Tempo totale: 5.4143s
# SIGNAL FILE n.66
# (1000, 6, 5, 42)
# Tempo totale: 5.3349s
# SIGNAL FILE n.67
# (1000, 6, 5, 42)
# Tempo totale: 5.5067s
# SIGNAL FILE n.68
# (1000, 6, 5, 42)
# Tempo totale: 5.2046s
# SIGNAL FILE n.69
# (1000, 6, 5, 42)
# Tempo totale: 6.9904s
# SIGNAL FILE n.70
# (1000, 6, 5, 42)
# Tempo totale: 5.1476s
# SIGNAL FILE n.71
# (1000, 6, 5, 42)
# Tempo totale: 6.1737s
# SIGNAL FILE n.72
# (1000, 6, 5, 42)
# Tempo totale: 5.2881s
# SIGNAL FILE n.73
# (1000, 6, 5, 42)
# Tempo totale: 7.5204s
# SIGNAL FILE n.74
# (1000, 6, 5, 42)
# Tempo totale: 4.7897s
# SIGNAL FILE n.75
# (1000, 6, 5, 42)
# Tempo totale: 5.3642s
# SIGNAL FILE n.76
# (1000, 6, 5, 42)
# Tempo totale: 6.7921s
# SIGNAL FILE n.77
# (1000, 6, 5, 42)
# Tempo totale: 5.3234s
# SIGNAL FILE n.78
# (1000, 6, 5, 42)
# Tempo totale: 6.6408s
# SIGNAL FILE n.79
# (1000, 6, 5, 42)
# Tempo totale: 5.2699s

# %%
nevents=1000
if(GEN):
    for f in frequences:
        for nfile in range(n_reco_files):
            print(f"\n--- Generazione file ricostruito {nfile} ==> noise rate = {f} kHz ---")
            df_noise = noiseOnly_dataset_optimized(cellmap,nevents=nevents, freq_kHz=f,time_window_ns=10)

            #time info added
            df_noise["time"] = df_noise["time"].astype(np.float32)
            timing_col = pd.DataFrame({'time': np.random.uniform(0, 10.16, len(df_noise["time"]))}, dtype=np.float32)
            df_noise.update(timing_col)

            output_filename = f"csv_reco/only_noise_reco_{nfile}_{f}kHz_10ns.csv"
            df_noise.to_csv(output_filename, index=False)
            print(f"Salvato in {output_filename}")

# %%
#input_signal_matrices = []
#input_nparticles_array = []
#
#
#for f in range(1,num_signal_ROOT_files-1):
#    print("SIGNAL FILE n.%d" % (f))
#    start = time.perf_counter()
#    #df_rec_signal     = pd.read_csv("/apotto/home1/aliens/apepic/work/rossi/drich_eic/csv/no_noise_events_Bkg_realistic_25_05/rec_hits.csv.%04d.csv" % (f+1), sep = ',')
#    df_rec_signal    = df_rec_signal_list[f]
#    df_sim_signal    = df_sim_signal_list[f]
#    df_rec_noise     = pd.read_csv(f"csv_reco/noise_reco_{f}_{FREQ}kHz_10ns.csv")
#
#    #ALCOR_gridmatrix_total, nparticles_array = grid_ALCOR_optimized_signalplusnoise_NOZEROS_nparticles(42, df_rec_noise, df_rec_signal, df_sim_signal)
#    #ALCOR_gridmatrix_total, nparticles_array = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_nparticles(42, df_rec_noise, df_rec_signal, df_sim_signal, binwidth,)
#    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_acceptancefiltered(42, df_rec_noise, df_rec_signal, df_sim_signal)
#    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_acceptancefiltered(42, df_rec_noise, df_rec_signal, df_sim_signal, binwidth,)
#    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware(42, df_rec_noise, df_rec_signal,binwidth)
#    ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS(42, df_rec_noise, df_rec_signal)
#    print(ALCOR_gridmatrix_total.shape)
#    #print(nparticles_array.shape)
#    #ALCOR_gridmatrix_total = ALCOR_gridmatrix_total.reshape(ALCOR_gridmatrix_total.shape[0],6,5,42*int(10.16/binwidth))
#    ALCOR_gridmatrix_total = ALCOR_gridmatrix_total.reshape(ALCOR_gridmatrix_total.shape[0],6,5,42)
#
#    input_signal_matrices.append(ALCOR_gridmatrix_total)
#
#    #input_nparticles_array.append(nparticles_array)
#
#
#    end = time.perf_counter()
#    print(f"Tempo totale: {end - start:.4f}s")

# %%
input_noise_matrices = []
y_noise_training = []
FREQ =150
for f in range(0,num_noise_ROOT_files):
    print("NOISE FILE n.%d" % (f))
    start = time.perf_counter()
    df_rec_noise = pd.read_csv(f"/content/drive/MyDrive/project_files/Noise_files/no_time/csv_reco/noise_reco_{f}_{FREQ}kHz_10ns.csv", sep=',')
    #df_rec_noise     = pd.read_csv("../csv/2501_noise_events_300kHz_10ns/rec_hits.csv_%01d.csv" % (f+1), sep = ',')
    #ALCOR_gridmatrix = grid_ALCOR_optimized_timingaware(42, df_rec_noise)
    ALCOR_gridmatrix = grid_ALCOR_optimized(42, df_rec_noise)
    ALCOR_gridmatrix = ALCOR_gridmatrix.reshape(1000,6,5,42)
    #ALCOR_gridmatrix = ALCOR_gridmatrix.reshape(1000,6,5,42*20)

    input_noise_matrices.append(ALCOR_gridmatrix)
    end = time.perf_counter()
    print(f"Tempo totale: {end - start:.4f}s")
# Out:
# NOISE FILE n.0
# Tempo totale: 2.9156s
# NOISE FILE n.1
# Tempo totale: 1.0527s
# NOISE FILE n.2
# Tempo totale: 1.0569s
# NOISE FILE n.3
# Tempo totale: 1.0798s
# NOISE FILE n.4
# Tempo totale: 1.0567s
# NOISE FILE n.5
# Tempo totale: 1.0905s
# NOISE FILE n.6
# Tempo totale: 1.4462s
# NOISE FILE n.7
# Tempo totale: 1.7453s
# NOISE FILE n.8
# Tempo totale: 1.5320s
# NOISE FILE n.9
# Tempo totale: 1.0297s
# NOISE FILE n.10
# Tempo totale: 1.0497s
# NOISE FILE n.11
# Tempo totale: 1.0617s
# NOISE FILE n.12
# Tempo totale: 1.0159s
# NOISE FILE n.13
# Tempo totale: 1.0388s
# NOISE FILE n.14
# Tempo totale: 1.0299s
# NOISE FILE n.15
# Tempo totale: 1.0112s
# NOISE FILE n.16
# Tempo totale: 1.0513s
# NOISE FILE n.17
# Tempo totale: 1.0555s
# NOISE FILE n.18
# Tempo totale: 1.3558s
# NOISE FILE n.19
# Tempo totale: 1.6814s
# NOISE FILE n.20
# Tempo totale: 1.6562s
# NOISE FILE n.21
# Tempo totale: 1.0319s
# NOISE FILE n.22
# Tempo totale: 1.0458s
# NOISE FILE n.23
# Tempo totale: 1.0534s
# NOISE FILE n.24
# Tempo totale: 1.0388s
# NOISE FILE n.25
# Tempo totale: 1.0303s
# NOISE FILE n.26
# Tempo totale: 1.0150s
# NOISE FILE n.27
# Tempo totale: 0.9976s
# NOISE FILE n.28
# Tempo totale: 0.9935s
# NOISE FILE n.29
# Tempo totale: 1.0333s
# NOISE FILE n.30
# Tempo totale: 1.2350s
# NOISE FILE n.31
# Tempo totale: 1.6238s
# NOISE FILE n.32
# Tempo totale: 1.6228s
# NOISE FILE n.33
# Tempo totale: 1.1073s
# NOISE FILE n.34
# Tempo totale: 1.0464s
# NOISE FILE n.35
# Tempo totale: 1.0519s
# NOISE FILE n.36
# Tempo totale: 1.0028s
# NOISE FILE n.37
# Tempo totale: 1.0275s
# NOISE FILE n.38
# Tempo totale: 1.0469s
# NOISE FILE n.39
# Tempo totale: 1.0140s
# NOISE FILE n.40
# Tempo totale: 1.0168s
# NOISE FILE n.41
# Tempo totale: 1.0415s
# NOISE FILE n.42
# Tempo totale: 1.1089s
# NOISE FILE n.43
# Tempo totale: 1.6310s
# NOISE FILE n.44
# Tempo totale: 1.7037s
# NOISE FILE n.45
# Tempo totale: 1.1808s
# NOISE FILE n.46
# Tempo totale: 1.0594s
# NOISE FILE n.47
# Tempo totale: 1.0644s
# NOISE FILE n.48
# Tempo totale: 1.0469s
# NOISE FILE n.49
# Tempo totale: 1.0405s
# NOISE FILE n.50
# Tempo totale: 1.0609s
# NOISE FILE n.51
# Tempo totale: 1.0570s
# NOISE FILE n.52
# Tempo totale: 1.0178s
# NOISE FILE n.53
# Tempo totale: 1.0437s
# NOISE FILE n.54
# Tempo totale: 1.1918s
# NOISE FILE n.55
# Tempo totale: 1.7301s
# NOISE FILE n.56
# Tempo totale: 1.6567s
# NOISE FILE n.57
# Tempo totale: 1.1563s
# NOISE FILE n.58
# Tempo totale: 1.0582s
# NOISE FILE n.59
# Tempo totale: 1.0749s
# NOISE FILE n.60
# Tempo totale: 1.0260s
# NOISE FILE n.61
# Tempo totale: 1.0804s
# NOISE FILE n.62
# Tempo totale: 1.0568s
# NOISE FILE n.63
# Tempo totale: 1.0081s
# NOISE FILE n.64
# Tempo totale: 1.0096s
# NOISE FILE n.65
# Tempo totale: 1.0455s
# NOISE FILE n.66
# Tempo totale: 1.2372s
# NOISE FILE n.67
# Tempo totale: 1.6594s
# NOISE FILE n.68
# Tempo totale: 1.6621s
# NOISE FILE n.69
# Tempo totale: 1.0891s
# NOISE FILE n.70
# Tempo totale: 1.0326s
# NOISE FILE n.71
# Tempo totale: 1.0668s
# NOISE FILE n.72
# Tempo totale: 1.0204s
# NOISE FILE n.73
# Tempo totale: 1.0256s
# NOISE FILE n.74
# Tempo totale: 1.0802s
# NOISE FILE n.75
# Tempo totale: 1.0193s
# NOISE FILE n.76
# Tempo totale: 1.0541s
# NOISE FILE n.77
# Tempo totale: 1.0237s
# NOISE FILE n.78
# Tempo totale: 1.2261s
# NOISE FILE n.79
# Tempo totale: 1.6750s
# NOISE FILE n.80
# Tempo totale: 2.2351s
# NOISE FILE n.81
# Tempo totale: 3.0174s
# NOISE FILE n.82
# Tempo totale: 2.9790s
# NOISE FILE n.83
# Tempo totale: 2.5851s
# NOISE FILE n.84
# Tempo totale: 3.1520s
# NOISE FILE n.85
# Tempo totale: 2.5879s
# NOISE FILE n.86
# Tempo totale: 2.9191s
# NOISE FILE n.87
# Tempo totale: 3.3248s
# NOISE FILE n.88
# Tempo totale: 2.1497s
# NOISE FILE n.89
# Tempo totale: 3.1097s
# NOISE FILE n.90
# Tempo totale: 2.5251s
# NOISE FILE n.91
# Tempo totale: 2.7131s
# NOISE FILE n.92
# Tempo totale: 2.0390s
# NOISE FILE n.93
# Tempo totale: 3.8120s
# NOISE FILE n.94
# Tempo totale: 3.4951s
# NOISE FILE n.95
# Tempo totale: 2.1361s
# NOISE FILE n.96
# Tempo totale: 2.6665s
# NOISE FILE n.97
# Tempo totale: 2.6778s
# NOISE FILE n.98
# Tempo totale: 5.3717s
# NOISE FILE n.99
# Tempo totale: 3.0010s

# %%
NO=False
if NO==True:
  for f in range(0,num_signal_ROOT_files-1):
    expected = set(range(1000))
    present = set(df_rec_signal_list[f]["event"])

    missing = expected - present

    if len(missing) == 0:
        print("Tutti gli eventi da 0 a 999 sono presenti")
    else:
        print(f"Mancano {len(missing)} eventi:", sorted(missing))

# %%
X_signal = np.array(input_signal_matrices)
print(X_signal.shape)
#X_signal = X_signal.reshape(X_signal.shape[0]*X_signal.shape[1],30, 42*int(10.16/binwidth))
#reshape del tensore 5D in un tensore 3D
X_signal = X_signal.reshape(X_signal.shape[0]*X_signal.shape[1],30,42)
print(X_signal.shape)
# Out:
# (79, 1000, 6, 5, 42)
# (79000, 30, 42)

# %%
X_noise = np.array(input_noise_matrices)
print(X_noise.shape)
#X_signal = X_signal.reshape(X_signal.shape[0]*X_signal.shape[1],30, 42*int(10.16/binwidth))
X_noise = X_noise.reshape(X_noise.shape[0]*X_noise.shape[1],30,42)
print(X_noise.shape)
# Out:
# (100, 1000, 6, 5, 42)
# (100000, 30, 42)

# %%
# Supponiamo che il padding sia 0
mask_not_empty = np.any(X_signal != 0, axis=(1,2))  # True se l'evento ha almeno un valore non zero

# Filtriamo solo gli eventi non vuoti
X_signal_not_empty = X_signal[mask_not_empty]

print(X_signal_not_empty.shape)
# Out:
# (79000, 30, 42)

# %%
import os

#directory di destinazione
target_dir = "/content/drive/MyDrive/project_files/input_no_time/"

# Verifichimo che la cartella esista, altrimenti la creiamo
os.makedirs(target_dir, exist_ok=True)

# 3. Salvataggio dei file
with open(f"{target_dir}signal_data_{FREQ}kHz.npy", "wb") as f:
    np.save(f, X_signal)

with open(f"{target_dir}noise_data_{FREQ}kHz.npy", "wb") as f:
    np.save(f, X_noise)

# %%
with open(f'signal_data_{FREQ}kHz.npy', 'wb') as f:
    np.save(f, X_signal)

with open(f'noise_data_{FREQ}kHz.npy', 'wb') as f:
    #np.save(f, X_signal_not_empty)
    np.save(f, X_noise)
