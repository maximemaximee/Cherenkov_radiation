# %%
## connessione al google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy  as np
import math

#from ape_dataset import *

import os

# cartella output per i csv di noise
OUTDIR = "csv_reco"
os.makedirs(OUTDIR, exist_ok=True)

# %%
## DATASET GENERATION ###

##Defines
c_x = 175  #center of sector division (local coords)
c_y = 189

c1 = 680   #line interception with y axis
c2 = 320

grid_size = 8 #grid resolution (preprocessing step)

num_noise_ROOT_files = 100 #number of input files
num_signal_ROOT_files = 100 #number of input files
num_events = 1000 #number of events for each file

num_sectors = 6 #number of sectors of dRICH

# %%
binwidth=10.16/4
ten=10.16
nbins=int(ten/binwidth)

# %%
def noise_probability_gaussian(freq_kHz=100,time_window_ns=10):
    p = freq_kHz*1000 *time_window_ns/1000000000
    sigma_p = p * 0.01
    single_ph_emission_p = np.random.normal(0, 1) * sigma_p + p
    if single_ph_emission_p < 0:
        single_ph_emission_p = 0

    return single_ph_emission_p


def neq_radius(neq_radius_params,radius):
    neq = np.zeros(radius.size)
    for i,par in enumerate(neq_radius_params):
        neq+=neq_radius_params[i]*pow(radius,i)
    return neq


def noise_probability_radial(luminosity_fbi=100,time_window_ns=10,radius=[]):
    baseline_dcr = 3000*np.ones(radius.size)
    neq_radius_params = [-3.27029e+09, 1.26055e+08, -1.88568e+06, 13929.1, -50.9931, 0.0741068]
    dcr_increase = 300/1000000
    neq = neq_radius(neq_radius_params,radius) * luminosity_fbi;
    dcr = baseline_dcr + dcr_increase * neq
    pro = dcr * time_window_ns/1000000000;

    return pro



def pseudorapidity(px, py, pz):
    """
    Compute pseudorapidity (eta) from 3-momentum components.

    Parameters:
        px, py, pz : float or array-like

    Returns:
        eta : float or numpy array
    """
    px = np.asarray(px)
    py = np.asarray(py)
    pz = np.asarray(pz)

    pT = np.sqrt(px**2 + py**2)

    # Use asinh form for numerical stability
    eta = np.arcsinh(pz / pT)

    return eta

# %%
import time
from time import perf_counter


def noise_probability_gaussian(freq_kHz=100,time_window_ns=10):
    p = freq_kHz*1000 *time_window_ns/1000000000
    sigma_p = p * 0.01
    single_ph_emission_p = np.random.normal(0, 1) * sigma_p + p
    if single_ph_emission_p < 0:
        single_ph_emission_p = 0

    return single_ph_emission_p

def noise_generation(df_str="../csv/cellmap.csv", freq_kHz=100, time_window_ns=10, event=99999):
    df = pd.read_csv(df_str,  sep = ',')
    hitlist = []
    for index, row in df.iterrows():
        hit_prob = noise_probability_gaussian(freq_kHz,time_window_ns)
        limit = np.random.uniform(0,1)
        #print("p=%f, limit=%f", hit_prob,limit)
        if hit_prob > limit:
            row = row.copy()
            row["event"] = event
            row["time"] = 1
            row["charge"] = 280
            row["pindex"] = 0
            hitlist.append(row)
                        #print(d4)
    return pd.DataFrame(hitlist)

def noiseOnly_dataset(nevents=10, freq_kHz=100, time_window_ns=10):
    start = time.perf_counter()
    df_all = []
    for ev in range(nevents):
        print(f"Evento di rumore #{ev}")
        df_new = noise_generation("../csv/cellmap.csv", freq_kHz, time_window_ns, event=ev)
        if not df_new.empty:
            df_all.append(df_new)

    if df_all:
        df_final = pd.concat(df_all, ignore_index=True)
        df_final = df_final[['event', 'cell_id', 'sector', 'time', 'charge', 'pindex',
                                  'gx', 'gy', 'gz', 'lx', 'ly', 'pdu', 'sipm', 'xi', 'yi']]
    else:
        df_final = pd.DataFrame()  # Nessun evento generato



    end = time.perf_counter()

    print(f"Tempo totale {end - start:.4f} secondi ==> {(end - start)/nevents:.4f}")

    return df_final


def noise_generation_optimized(cellmap, freq_kHz=100, time_window_ns=10, event=99999):
    p = freq_kHz * 1000 * time_window_ns / 1_000_000_000
    sigma_p = p * 0.01

    size = len(cellmap)

    # Genera probabilità gaussiane per tutte le righe
    emission_probs = np.random.normal(loc=p, scale=sigma_p, size=size)

    # Genera probabilità radiali
    #radii = np.sqrt(cellmap["gx"]*cellmap["gx"]+cellmap["gy"]*cellmap["gy"])
    #emission_probs = noise_probability_radial(luminosity_fbi=freq_kHz,time_window_ns=time_window_ns,radius=radii)

    emission_probs = np.clip(emission_probs, 0, None)

    # Genera limiti casuali uniformi
    thresholds = np.random.uniform(0, 1, size)

    # Filtra solo i "veri hit"
    mask = emission_probs > thresholds
    hits = cellmap[mask].copy()

    # Aggiungi colonne
    hits["event"] = event
    hits["time"] = np.random.uniform(0,10000) #added timing
    hits["charge"] = 280
    hits["pindex"] = 0

    return hits


def noiseOnly_dataset_optimized(cellmap, nevents=10, freq_kHz=100, time_window_ns=10):
    start = time.perf_counter()
    all_hits = []

    for ev in range(nevents):
        hits = noise_generation_optimized(cellmap, freq_kHz, time_window_ns, event=ev)
        all_hits.append(hits)

    df_final = pd.concat(all_hits, ignore_index=True)
    df_final = df_final[['event', 'cell_id', 'sector', 'time', 'charge', 'pindex',
                                  'gx', 'gy', 'gz', 'lx', 'ly', 'pdu', 'sipm', 'xi', 'yi']]
    end = time.perf_counter()

    print(f"Tempo totale: {end - start:.4f}s → {(end - start)/nevents:.4f}s per evento")
    return df_final

# %%
import time

def grid_ALCOR_optimized(size, df):
    grid_matrix = np.zeros((1000, 6, 5, size), dtype=np.int16)

    # Filtra il DataFrame per eventi, settori, subsezioni e pdu validi
    df = df[df["event"] < 1000]
    df = df[df["sector"] < 6]
    df["subsec"] = df["pdu"] // 42
    df = df[df["subsec"] < 5]
    df["subpdu"] = df["pdu"] % 42

    # Raggruppa per indici rilevanti
    grouped = df.groupby(["event", "sector", "subsec", "subpdu"]).size()

    # Assegna i conteggi alla matrice
    for (ev, sec, subsec, subpdu), count in grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    return grid_matrix

def grid_ALCOR_optimized_timingaware(size, df, binwidth):
    grid_matrix = np.zeros((1000, 6, 5, size, int(ten/binwidth)), dtype=np.int16)

    # Filtra il DataFrame per eventi, settori, subsezioni e pdu validi
    df = df[df["event"] < 1000]
    df = df[df["sector"] < 6]
    df["subsec"] = df["pdu"] // 42
    df = df[df["subsec"] < 5]
    df["subpdu"] = df["pdu"] % 42
    df["time"] = df["time"].astype(np.float32)
    timing_col = pd.DataFrame({'time': np.random.uniform(0, ten, len(df["time"]))}, dtype=np.float32) #badile
    df.update(timing_col)
    df["coarse_time"] = np.clip(df["time"] // binwidth, 0, nbins-1).astype(int)  # + 1 # badile
    #df["coarse_time"] = (df["time"] // binwidth) #.astype(int)
    # Raggruppa per indici rilevanti
    grouped = df.groupby(["event", "sector", "subsec", "subpdu","coarse_time"]).size()

    #Trova il coarse_time più frequente per ogni cella
    #idx = grouped.groupby(level=[0,1,2,3]).idxmax()

    # Assegna i TEMPI alla matrice
    for (ev, sec, subsec, subpdu, coarse_time), count in grouped.items():
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)] = count #* 2.54
        #print(coarse_time)
        #grid_matrix[ev, sec, subsec, subpdu] =  np.bincount(coarse_time).argmax() * 2.54
    return grid_matrix


def grid_ALCOR_optimized_signalonly(size, signal_frame):
    grid_matrix = np.zeros((1000, 6, 5, size), dtype=np.int16)

    # Filtra il DataFrame per eventi, settori, subsezioni e ogni 42 pdu
    sf = signal_frame[signal_frame["event"] < 1000]
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #print(sf)

    # Raggruppa per indici rilevanti
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    # Assegna i conteggi alla matrice (segnale)
    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    return grid_matrix




def grid_ALCOR_optimized_signalplusnoise(size, noise_frame, signal_frame):
    grid_matrix = np.zeros((1000, 6, 5, size), dtype=np.int16)

    # Filtra il DataFrame per eventi, settori, subsezioni e ogni 42 pdu
    nf = noise_frame[noise_frame["event"] < 1000]
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42

    sf = signal_frame[signal_frame["event"] < 1000]
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #print(sf)

    # Raggruppa per indici rilevanti
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    # Assegna i conteggi alla matrice (segnale)
    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count



    # Colonne da confrontare
    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm",  "xi", "yi"]

    # 1. Subset dei DataFrame
    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    # 2. Converti le righe di signal in un set di tuple per confronto efficiente
    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    # 3. Crea una maschera: True se la riga di noise NON è in signal
    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)

    # 4. Applica la maschera a noise per ottenere il risultato filtrato
    filtered_nf = nf[mask]

    # Raggruppa per indici rilevanti
    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu"]).size()



    # Assegna i conteggi alla matrice (noise SE non c'è già segnale)
    for (ev, sec, subsec, subpdu), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] += count

    return grid_matrix


def grid_ALCOR_optimized_signalplusnoise_NOZEROS(size, noise_frame, signal_frame):

    grid_matrix = np.zeros((1000, 6, 5, size), dtype=np.int16)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42

    # --- Preprocessing SIGNAL ---
    sf = signal_frame[signal_frame["event"] < 1000].copy()
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] += count

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix


def grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware(size, noise_frame, signal_frame, binwidth):

    grid_matrix = np.zeros((1000, 6, 5, size, int(ten/binwidth)), dtype=np.int16)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42
    nf["time"] = nf["time"].astype(np.float32)
    timing_col = pd.DataFrame({'time': np.random.uniform(0, ten, len(nf["time"]))}, dtype=np.float32)
    nf.update(timing_col)
    nf["coarse_time"] = np.clip((nf["time"] // binwidth), 0, int(ten/binwidth) - 1).astype(int)

    # --- Preprocessing SIGNAL ---

    for ev in range(max(signal_frame["event"])):
        ev=ev+1
        #print(ev)
        #start = perf_counter()
        df = signal_frame[signal_frame["event"]==ev]
        min_time = min(df["time"])
        #time_col = ((df["time"].astype(np.float32)-min_time)/16)%10.16 #badile era fratto /16
        time_col = ((df["time"].astype(np.float32)-min_time))%10.16
        #time_col = (df["time"]/16)%20.32
        if (ev==1):
            sig_times = time_col
        else:
            df_previous = sig_times
            sig_times =  pd.concat([df_previous.astype(np.float32), time_col.astype(np.float32)])
        end = perf_counter()
        #if(ev%100 == 0):
            #print(f"Tempo totale per eventp: {end - start:.4f}s")

    sf = signal_frame[signal_frame["event"] < 1000].copy()
    #sf = sf[sf["time"] < 10000]
    sf["time"] = sf["time"].astype(np.float32)
    sf.update(sig_times)
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42


    #sf["coarse_time"] = (((sf["time"]*16)-((sf["time"]*16)//10.16)*10.16) // binwidth)
    sf["coarse_time"] = np.clip((sf["time"] // binwidth), 0, int(ten/binwidth) - 1).astype(int)

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu","coarse_time"]).size()

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu", "coarse_time"]).size()
    for (ev, sec, subsec, subpdu, coarse_time), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%nbins] = count #* 2.54

    #all_grouped = pd.concat([signal_grouped, noise_grouped], axis=0)
    #idx = all_grouped.groupby(level=[0,1,2,3]).idxmax()

    #for (ev, sec, subsec, subpdu, coarse_time), count in all_grouped.items():
        #grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54
    for (ev, sec, subsec, subpdu, coarse_time), count in signal_grouped.items():
        #min_df = sf[sf["event"]==ev]
        #min_time = min(min_df["time"])
        #time_col = ((df["time"]-min_time)/16)%20.32
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%nbins] += count #* 2.54

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix

# %%
def grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_acceptancefiltered(size, noise_frame, rec_signal_frame, sim_signal_frame, binwidth):

    grid_matrix = np.zeros((1000, 6, 5, size, int(ten/binwidth)), dtype=np.int16)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42
    nf["time"] = nf["time"].astype(np.float32)
    timing_col = pd.DataFrame({'time': np.random.uniform(0, ten, len(nf["time"]))}, dtype=np.float32)
    nf.update(timing_col)
    nf["coarse_time"] = (nf["time"] // binwidth)# + 1

    # --- Preprocessing SIGNAL ---

    for ev in range(max(rec_signal_frame["event"])):
        ev=ev+1
        #print(ev)
        #start = perf_counter()
        df = rec_signal_frame[rec_signal_frame["event"]==ev]
        min_time = min(df["time"])
        time_col = ((df["time"].astype(np.float32)-min_time)/16)%10.16
        #time_col = (df["time"]/16)%20.32
        if (ev==1):
            sig_times = time_col
        else:
            df_previous = sig_times
            sig_times =  pd.concat([df_previous.astype(np.float32), time_col.astype(np.float32)])
        end = perf_counter()
        #if(ev%100 == 0):
            #print(f"Tempo totale per eventp: {end - start:.4f}s")

    sf = rec_signal_frame[rec_signal_frame["event"] < 1000].copy()
    #sf = sf[sf["time"] < 10000]
    sf["time"] = sf["time"].astype(np.float32)
    sf.update(sig_times)
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #acceptance filter
    sim_sf = sim_signal_frame[sim_signal_frame["event"] < 1000].copy()
    eta = pseudorapidity(sim_sf["px"], sim_sf["py"], sim_sf["pz"])
    eta_mask = (eta >= 1.5) & (eta<=3.5)
    sim_sf = sim_sf[eta_mask]
    #sf = sf[sf["pindex"].isin(sim_sf["pindex"])]
    sf = sf.merge(sim_sf[["event", "pindex"]], on=["event", "pindex"],how="inner")

    #sf["coarse_time"] = (((sf["time"]*16)-((sf["time"]*16)//10.16)*10.16) // binwidth)
    sf["coarse_time"] = sf["time"] // binwidth

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu","coarse_time"]).size()

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu", "coarse_time"]).size()
    for (ev, sec, subsec, subpdu, coarse_time), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54

    #all_grouped = pd.concat([signal_grouped, noise_grouped], axis=0)
    #idx = all_grouped.groupby(level=[0,1,2,3]).idxmax()

    #for (ev, sec, subsec, subpdu, coarse_time), count in all_grouped.items():
        #grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54
    for (ev, sec, subsec, subpdu, coarse_time), count in signal_grouped.items():
        #min_df = sf[sf["event"]==ev]
        #min_time = min(min_df["time"])
        #time_col = ((df["time"]-min_time)/16)%20.32
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] += count #* 2.54

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix


def grid_ALCOR_optimized_signalplusnoise_NOZEROS_acceptancefiltered(size, noise_frame, rec_signal_frame,sim_signal_frame):

    grid_matrix = np.zeros((1000, 6, 5, size), dtype=np.int16)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42

    # --- Preprocessing SIGNAL ---
    sf = rec_signal_frame[rec_signal_frame["event"] < 1000].copy()
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #acceptance filter
    sim_sf = sim_signal_frame[sim_signal_frame["event"] < 1000].copy()
    eta = pseudorapidity(sim_sf["px"], sim_sf["py"], sim_sf["pz"])
    eta_mask = (eta >= 1.5) & (eta<=3.5)
    sim_sf = sim_sf[eta_mask]
    #sf = sf[sf["pindex"].isin(sim_sf["pindex"])]
    sf = sf.merge(sim_sf[["event", "pindex"]], on=["event", "pindex"],how="inner")

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] += count

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix

# %%
def grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_nparticles(size, noise_frame, rec_signal_frame, sim_signal_frame, binwidth):

    grid_matrix = np.zeros((1000, 6, 5, size, int(ten/binwidth)), dtype=np.int16)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42
    nf["time"] = nf["time"].astype(np.float32)
    timing_col = pd.DataFrame({'time': np.random.uniform(0, ten, len(nf["time"]))}, dtype=np.float32)
    nf.update(timing_col)
    nf["coarse_time"] = (nf["time"] // binwidth)# + 1

    # --- Preprocessing SIGNAL ---

    for ev in range(max(rec_signal_frame["event"])):
        ev=ev+1
        #print(ev)
        #start = perf_counter()
        df = rec_signal_frame[rec_signal_frame["event"]==ev]
        min_time = min(df["time"])
        time_col = ((df["time"].astype(np.float32)-min_time)/16)%10.16
        #time_col = (df["time"]/16)%20.32
        if (ev==1):
            sig_times = time_col
        else:
            df_previous = sig_times
            sig_times =  pd.concat([df_previous.astype(np.float32), time_col.astype(np.float32)])
        end = perf_counter()
        #if(ev%100 == 0):
            #print(f"Tempo totale per eventp: {end - start:.4f}s")

    sf = rec_signal_frame[rec_signal_frame["event"] < 1000].copy()
    #sf = sf[sf["time"] < 10000]
    sf["time"] = sf["time"].astype(np.float32)
    sf.update(sig_times)
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    #nparticles
    sim_sf = sim_signal_frame[sim_signal_frame["event"] < 1000].copy()
    nparticles_count = sim_sf.groupby("event")["pindex"].nunique().clip(upper=3)
    nparticles_capped = nparticles_count.values
    y_onehot = pd.get_dummies(nparticles_capped)
    y_onehot = y_onehot.reindex(columns=[0, 1, 2, 3], fill_value=0).astype(int)
    y_onehot = y_onehot.to_numpy().astype(int)

    #sf["coarse_time"] = (((sf["time"]*16)-((sf["time"]*16)//10.16)*10.16) // binwidth)
    sf["coarse_time"] = sf["time"] // binwidth

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu","coarse_time"]).size()

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu", "coarse_time"]).size()
    for (ev, sec, subsec, subpdu, coarse_time), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54

    #all_grouped = pd.concat([signal_grouped, noise_grouped], axis=0)
    #idx = all_grouped.groupby(level=[0,1,2,3]).idxmax()

    #for (ev, sec, subsec, subpdu, coarse_time), count in all_grouped.items():
        #grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] = count #* 2.54
    for (ev, sec, subsec, subpdu, coarse_time), count in signal_grouped.items():
        #min_df = sf[sf["event"]==ev]
        #min_time = min(min_df["time"])
        #time_col = ((df["time"]-min_time)/16)%20.32
        grid_matrix[ev, sec, subsec, subpdu, int(coarse_time)%4] += count #* 2.54

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix, y_onehot


def grid_ALCOR_optimized_signalplusnoise_NOZEROS_nparticles(size, noise_frame, rec_signal_frame,sim_signal_frame):

    #grid_matrix = np.zeros((1000, 6, 5, size), dtype=np.int16)

    # --- Preprocessing NOISE ---
    nf = noise_frame[noise_frame["event"] < 1000].copy()
    nf = nf[nf["sector"] < 6]
    nf["subsec"] = nf["pdu"] // 42
    nf = nf[nf["subsec"] < 5]
    nf["subpdu"] = nf["pdu"] % 42

    # --- Preprocessing SIGNAL ---
    sf = rec_signal_frame[rec_signal_frame["event"] < 1000].copy()
    sf = sf[sf["pindex"] > 0]
    sf = sf[sf["sector"] < 6]
    sf["subsec"] = sf["pdu"] // 42
    sf = sf[sf["subsec"] < 5]
    sf["subpdu"] = sf["pdu"] % 42

    grid_matrix = np.zeros((len(sf["event"].unique()), 6, 5, size), dtype=int)
    nparticles_y_array = np.zeros((len(sf["event"].unique()),4), dtype=int)


    #nparticles
    sim_sf = sim_signal_frame[sim_signal_frame["event"] < 1000].copy()
    print(len(sim_sf["event"].unique()))
    nparticles_count = sim_sf.groupby("event")["pindex"].nunique().clip(upper=3)
    nparticles_capped = nparticles_count.values
    y_onehot = pd.get_dummies(nparticles_capped)
    y_onehot = y_onehot.reindex(columns=[0, 1, 2, 3], fill_value=0).astype(int)
    y_onehot = y_onehot.to_numpy().astype(int)

    # --- ⛔ Mantieni solo gli eventi che hanno segnale ---
    eventi_con_segnale = sf["event"].unique()
    nf = nf[nf["event"].isin(eventi_con_segnale)]

    # --- Signal grouping ---
    signal_grouped = sf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in signal_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] = count

    # --- Noise minus signal (stessa posizione SiPM) ---

    colonne_da_confrontare = ["event", "sector", "subsec", "subpdu", "sipm", "xi", "yi"]

    signal_subset = sf[colonne_da_confrontare]
    noise_subset = nf[colonne_da_confrontare]

    signal_tuples = set(map(tuple, signal_subset.to_numpy()))

    mask = noise_subset.apply(lambda row: tuple(row) not in signal_tuples, axis=1)
    filtered_nf = nf[mask]

    noise_grouped = filtered_nf.groupby(["event", "sector", "subsec", "subpdu"]).size()

    for (ev, sec, subsec, subpdu), count in noise_grouped.items():
        grid_matrix[ev, sec, subsec, subpdu] += count

    # --- ⛔ Mantieni solo gli eventi che hanno segnale --- ===> PADDING (solved, la rete lo impara da sola)
    #ev_finali = np.sort(eventi_con_segnale)
    #grid_matrix = grid_matrix[ev_finali]

    return grid_matrix, y_onehot

# %%
n_reco_files = 100
nevents = 1000

#cellmap = pd.read_csv("/tmp/cellmap.csv",  sep = ',')
cellmap = pd.read_csv("/content/drive/MyDrive/project_files/cellmap.csv", sep=',')



FREQ=150
frequences = [FREQ]
GEN =   False

# %%
if(GEN):
    for f in frequences:
        #print(f)
        for nfile in range(n_reco_files):
            print(f"\n--- Generazione file ricostruito {nfile} ==> noise rate = {f} kHz ---")
            df_noise = noiseOnly_dataset_optimized(cellmap,nevents=nevents, freq_kHz=f,time_window_ns=10)
            #time info added
            df_noise["time"] = df_noise["time"].astype(np.float32)
            timing_col = pd.DataFrame({'time': np.random.uniform(0, ten, len(df_noise["time"]))}, dtype=np.float32)
            df_noise.update(timing_col)
              # Definiamo la cartella Google Drive
            cartella_destinazione = "/content/drive/MyDrive/project_files/Noise_files/with_time/csv_reco/"
            # Questo comando crea la cartella su Drive se non esiste ancora
            os.makedirs(cartella_destinazione, exist_ok=True)

            output_filename = os.path.join(cartella_destinazione, f"noise_reco_{nfile}_{f}kHz_10ns.csv")
            df_noise.to_csv(output_filename, index=False)
            print(f"Salvato in {output_filename}")

# %%
import os
import pandas as pd
import numpy as np
import time

nfiles = 582
df_rec_signal_list = []
df_index = 0
new_file_init = True

start = time.perf_counter()
print(f"RECONSTRUCTION DATASET")
for f in range(nfiles):
    print(f"SIGNAL FILE n.{f}")

    file_string = f"/content/drive/MyDrive/project_files/Bkg_new/rec_hits_{f+1:04d}.csv"

    if not os.path.exists(file_string):
        print(file_string + " skipped!")
        continue

    # Leggi CSV
    df_rec_signal = pd.read_csv(file_string, sep=',')

    # Salta DataFrame vuoti o senza colonna "event"
    if df_rec_signal.empty or "event" not in df_rec_signal.columns:
        continue

    # Riallinea eventi locali partendo da 0
    df_rec_signal["event"] = df_rec_signal.groupby("event", sort=False).ngroup()

    # Converte a intero per sicurezza
    df_rec_signal["event"] = df_rec_signal["event"].astype(int)

    nevents = df_rec_signal["event"].max()

    if new_file_init:
        # Split se supera 999
        if nevents > 999:
            df1 = df_rec_signal[df_rec_signal["event"] <= 999].copy()
            df2 = df_rec_signal[df_rec_signal["event"] > 999].copy()

            if not df2.empty:
                df2["event"] = (df2["event"] - df2["event"].min()) % 1000
                df2["event"] = df2["event"].astype(int)

            df_rec_signal_list.append(df1)
            df_index += 1
            df_rec_signal_list.append(df2)
        else:
            df_rec_signal_list.append(df_rec_signal)
        new_file_init = False
    else:
        # Offset globale rispetto al precedente, modulo 1000 per wrap
        df_previous = df_rec_signal_list[df_index]
        prev_max = df_previous["event"].max() if not df_previous.empty else -1
        df_rec_signal["event"] = (df_rec_signal["event"] + prev_max + 1)# % 1000
        df_rec_signal["event"] = df_rec_signal["event"].astype(int)

        # Concatenate temporanea
        df_conc = pd.concat([df_previous, df_rec_signal], ignore_index=True)
        nev = df_conc["event"].max()

        if nev > 999:
            df1 = df_conc[df_conc["event"] <= 999].copy()
            df2 = df_conc[df_conc["event"] > 999].copy()

            if not df2.empty:
                df2["event"] = (df2["event"] - df2["event"].min()) % 1000
                df2["event"] = df2["event"].astype(int)

            df_rec_signal_list[df_index] = df1
            df_index += 1
            df_rec_signal_list.append(df2)
            new_file_init = False
        else:
            df_rec_signal_list[df_index] = df_conc
            if nev == 999:
                new_file_init = True

end = time.perf_counter()
print(f"Tempo totale: {end - start:.4f}s")
# Out:
# RECONSTRUCTION DATASET
# SIGNAL FILE n.0
# SIGNAL FILE n.1
# SIGNAL FILE n.2
# SIGNAL FILE n.3
# SIGNAL FILE n.4
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0005.csv skipped!
# SIGNAL FILE n.5
# SIGNAL FILE n.6
# SIGNAL FILE n.7
# SIGNAL FILE n.8
# SIGNAL FILE n.9
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0010.csv skipped!
# SIGNAL FILE n.10
# SIGNAL FILE n.11
# SIGNAL FILE n.12
# SIGNAL FILE n.13
# SIGNAL FILE n.14
# SIGNAL FILE n.15
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0016.csv skipped!
# SIGNAL FILE n.16
# SIGNAL FILE n.17
# SIGNAL FILE n.18
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0019.csv skipped!
# SIGNAL FILE n.19
# SIGNAL FILE n.20
# SIGNAL FILE n.21
# SIGNAL FILE n.22
# SIGNAL FILE n.23
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0024.csv skipped!
# SIGNAL FILE n.24
# SIGNAL FILE n.25
# SIGNAL FILE n.26
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0027.csv skipped!
# SIGNAL FILE n.27
# SIGNAL FILE n.28
# SIGNAL FILE n.29
# SIGNAL FILE n.30
# SIGNAL FILE n.31
# SIGNAL FILE n.32
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0033.csv skipped!
# SIGNAL FILE n.33
# SIGNAL FILE n.34
# SIGNAL FILE n.35
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0036.csv skipped!
# SIGNAL FILE n.36
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0037.csv skipped!
# SIGNAL FILE n.37
# SIGNAL FILE n.38
# SIGNAL FILE n.39
# SIGNAL FILE n.40
# SIGNAL FILE n.41
# SIGNAL FILE n.42
# SIGNAL FILE n.43
# SIGNAL FILE n.44
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0045.csv skipped!
# SIGNAL FILE n.45
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0046.csv skipped!
# SIGNAL FILE n.46
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0047.csv skipped!
# SIGNAL FILE n.47
# SIGNAL FILE n.48
# SIGNAL FILE n.49
# SIGNAL FILE n.50
# SIGNAL FILE n.51
# SIGNAL FILE n.52
# SIGNAL FILE n.53
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0054.csv skipped!
# SIGNAL FILE n.54
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0055.csv skipped!
# SIGNAL FILE n.55
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0056.csv skipped!
# SIGNAL FILE n.56
# SIGNAL FILE n.57
# SIGNAL FILE n.58
# SIGNAL FILE n.59
# SIGNAL FILE n.60
# SIGNAL FILE n.61
# SIGNAL FILE n.62
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0063.csv skipped!
# SIGNAL FILE n.63
# SIGNAL FILE n.64
# SIGNAL FILE n.65
# SIGNAL FILE n.66
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0067.csv skipped!
# SIGNAL FILE n.67
# SIGNAL FILE n.68
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0069.csv skipped!
# SIGNAL FILE n.69
# SIGNAL FILE n.70
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0071.csv skipped!
# SIGNAL FILE n.71
# SIGNAL FILE n.72
# SIGNAL FILE n.73
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0074.csv skipped!
# SIGNAL FILE n.74
# SIGNAL FILE n.75
# SIGNAL FILE n.76
# SIGNAL FILE n.77
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0078.csv skipped!
# SIGNAL FILE n.78
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0079.csv skipped!
# SIGNAL FILE n.79
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0080.csv skipped!
# SIGNAL FILE n.80
# SIGNAL FILE n.81
# SIGNAL FILE n.82
# SIGNAL FILE n.83
# SIGNAL FILE n.84
# SIGNAL FILE n.85
# SIGNAL FILE n.86
# SIGNAL FILE n.87
# SIGNAL FILE n.88
# SIGNAL FILE n.89
# SIGNAL FILE n.90
# SIGNAL FILE n.91
# SIGNAL FILE n.92
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0093.csv skipped!
# SIGNAL FILE n.93
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0094.csv skipped!
# SIGNAL FILE n.94
# SIGNAL FILE n.95
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0096.csv skipped!
# SIGNAL FILE n.96
# SIGNAL FILE n.97
# SIGNAL FILE n.98
# SIGNAL FILE n.99
# SIGNAL FILE n.100
# SIGNAL FILE n.101
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0102.csv skipped!
# SIGNAL FILE n.102
# SIGNAL FILE n.103
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0104.csv skipped!
# SIGNAL FILE n.104
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0105.csv skipped!
# SIGNAL FILE n.105
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0106.csv skipped!
# SIGNAL FILE n.106
# SIGNAL FILE n.107
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0108.csv skipped!
# SIGNAL FILE n.108
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0109.csv skipped!
# SIGNAL FILE n.109
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0110.csv skipped!
# SIGNAL FILE n.110
# SIGNAL FILE n.111
# SIGNAL FILE n.112
# SIGNAL FILE n.113
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0114.csv skipped!
# SIGNAL FILE n.114
# SIGNAL FILE n.115
# SIGNAL FILE n.116
# SIGNAL FILE n.117
# SIGNAL FILE n.118
# SIGNAL FILE n.119
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0120.csv skipped!
# SIGNAL FILE n.120
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0121.csv skipped!
# SIGNAL FILE n.121
# SIGNAL FILE n.122
# SIGNAL FILE n.123
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0124.csv skipped!
# SIGNAL FILE n.124
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0125.csv skipped!
# SIGNAL FILE n.125
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0126.csv skipped!
# SIGNAL FILE n.126
# SIGNAL FILE n.127
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0128.csv skipped!
# SIGNAL FILE n.128
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0129.csv skipped!
# SIGNAL FILE n.129
# SIGNAL FILE n.130
# SIGNAL FILE n.131
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0132.csv skipped!
# SIGNAL FILE n.132
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0133.csv skipped!
# SIGNAL FILE n.133
# SIGNAL FILE n.134
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0135.csv skipped!
# SIGNAL FILE n.135
# SIGNAL FILE n.136
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0137.csv skipped!
# SIGNAL FILE n.137
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0138.csv skipped!
# SIGNAL FILE n.138
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0139.csv skipped!
# SIGNAL FILE n.139
# SIGNAL FILE n.140
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0141.csv skipped!
# SIGNAL FILE n.141
# SIGNAL FILE n.142
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0143.csv skipped!
# SIGNAL FILE n.143
# SIGNAL FILE n.144
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0145.csv skipped!
# SIGNAL FILE n.145
# SIGNAL FILE n.146
# SIGNAL FILE n.147
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0148.csv skipped!
# SIGNAL FILE n.148
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0149.csv skipped!
# SIGNAL FILE n.149
# SIGNAL FILE n.150
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0151.csv skipped!
# SIGNAL FILE n.151
# SIGNAL FILE n.152
# SIGNAL FILE n.153
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0154.csv skipped!
# SIGNAL FILE n.154
# SIGNAL FILE n.155
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0156.csv skipped!
# SIGNAL FILE n.156
# SIGNAL FILE n.157
# SIGNAL FILE n.158
# SIGNAL FILE n.159
# SIGNAL FILE n.160
# SIGNAL FILE n.161
# SIGNAL FILE n.162
# SIGNAL FILE n.163
# SIGNAL FILE n.164
# SIGNAL FILE n.165
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0166.csv skipped!
# SIGNAL FILE n.166
# SIGNAL FILE n.167
# SIGNAL FILE n.168
# SIGNAL FILE n.169
# SIGNAL FILE n.170
# SIGNAL FILE n.171
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0172.csv skipped!
# SIGNAL FILE n.172
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0173.csv skipped!
# SIGNAL FILE n.173
# SIGNAL FILE n.174
# SIGNAL FILE n.175
# SIGNAL FILE n.176
# SIGNAL FILE n.177
# SIGNAL FILE n.178
# SIGNAL FILE n.179
# SIGNAL FILE n.180
# SIGNAL FILE n.181
# SIGNAL FILE n.182
# SIGNAL FILE n.183
# SIGNAL FILE n.184
# SIGNAL FILE n.185
# SIGNAL FILE n.186
# SIGNAL FILE n.187
# SIGNAL FILE n.188
# SIGNAL FILE n.189
# SIGNAL FILE n.190
# SIGNAL FILE n.191
# SIGNAL FILE n.192
# SIGNAL FILE n.193
# SIGNAL FILE n.194
# SIGNAL FILE n.195
# SIGNAL FILE n.196
# SIGNAL FILE n.197
# SIGNAL FILE n.198
# SIGNAL FILE n.199
# SIGNAL FILE n.200
# SIGNAL FILE n.201
# SIGNAL FILE n.202
# SIGNAL FILE n.203
# SIGNAL FILE n.204
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0205.csv skipped!
# SIGNAL FILE n.205
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0206.csv skipped!
# SIGNAL FILE n.206
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0207.csv skipped!
# SIGNAL FILE n.207
# SIGNAL FILE n.208
# SIGNAL FILE n.209
# SIGNAL FILE n.210
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0211.csv skipped!
# SIGNAL FILE n.211
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0212.csv skipped!
# SIGNAL FILE n.212
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0213.csv skipped!
# SIGNAL FILE n.213
# SIGNAL FILE n.214
# SIGNAL FILE n.215
# SIGNAL FILE n.216
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0217.csv skipped!
# SIGNAL FILE n.217
# SIGNAL FILE n.218
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0219.csv skipped!
# SIGNAL FILE n.219
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0220.csv skipped!
# SIGNAL FILE n.220
# SIGNAL FILE n.221
# SIGNAL FILE n.222
# SIGNAL FILE n.223
# SIGNAL FILE n.224
# SIGNAL FILE n.225
# SIGNAL FILE n.226
# SIGNAL FILE n.227
# SIGNAL FILE n.228
# SIGNAL FILE n.229
# SIGNAL FILE n.230
# SIGNAL FILE n.231
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0232.csv skipped!
# SIGNAL FILE n.232
# SIGNAL FILE n.233
# SIGNAL FILE n.234
# SIGNAL FILE n.235
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0236.csv skipped!
# SIGNAL FILE n.236
# SIGNAL FILE n.237
# SIGNAL FILE n.238
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0239.csv skipped!
# SIGNAL FILE n.239
# SIGNAL FILE n.240
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0241.csv skipped!
# SIGNAL FILE n.241
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0242.csv skipped!
# SIGNAL FILE n.242
# SIGNAL FILE n.243
# SIGNAL FILE n.244
# SIGNAL FILE n.245
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0246.csv skipped!
# SIGNAL FILE n.246
# SIGNAL FILE n.247
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0248.csv skipped!
# SIGNAL FILE n.248
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0249.csv skipped!
# SIGNAL FILE n.249
# SIGNAL FILE n.250
# SIGNAL FILE n.251
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0252.csv skipped!
# SIGNAL FILE n.252
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0253.csv skipped!
# SIGNAL FILE n.253
# SIGNAL FILE n.254
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0255.csv skipped!
# SIGNAL FILE n.255
# SIGNAL FILE n.256
# SIGNAL FILE n.257
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0258.csv skipped!
# SIGNAL FILE n.258
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0259.csv skipped!
# SIGNAL FILE n.259
# SIGNAL FILE n.260
# SIGNAL FILE n.261
# SIGNAL FILE n.262
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0263.csv skipped!
# SIGNAL FILE n.263
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0264.csv skipped!
# SIGNAL FILE n.264
# SIGNAL FILE n.265
# SIGNAL FILE n.266
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0267.csv skipped!
# SIGNAL FILE n.267
# SIGNAL FILE n.268
# SIGNAL FILE n.269
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0270.csv skipped!
# SIGNAL FILE n.270
# SIGNAL FILE n.271
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0272.csv skipped!
# SIGNAL FILE n.272
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0273.csv skipped!
# SIGNAL FILE n.273
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0274.csv skipped!
# SIGNAL FILE n.274
# SIGNAL FILE n.275
# SIGNAL FILE n.276
# SIGNAL FILE n.277
# SIGNAL FILE n.278
# SIGNAL FILE n.279
# SIGNAL FILE n.280
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0281.csv skipped!
# SIGNAL FILE n.281
# SIGNAL FILE n.282
# SIGNAL FILE n.283
# SIGNAL FILE n.284
# SIGNAL FILE n.285
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0286.csv skipped!
# SIGNAL FILE n.286
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0287.csv skipped!
# SIGNAL FILE n.287
# SIGNAL FILE n.288
# SIGNAL FILE n.289
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0290.csv skipped!
# SIGNAL FILE n.290
# SIGNAL FILE n.291
# SIGNAL FILE n.292
# SIGNAL FILE n.293
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0294.csv skipped!
# SIGNAL FILE n.294
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0295.csv skipped!
# SIGNAL FILE n.295
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0296.csv skipped!
# SIGNAL FILE n.296
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0297.csv skipped!
# SIGNAL FILE n.297
# SIGNAL FILE n.298
# SIGNAL FILE n.299
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0300.csv skipped!
# SIGNAL FILE n.300
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0301.csv skipped!
# SIGNAL FILE n.301
# SIGNAL FILE n.302
# SIGNAL FILE n.303
# SIGNAL FILE n.304
# SIGNAL FILE n.305
# SIGNAL FILE n.306
# SIGNAL FILE n.307
# SIGNAL FILE n.308
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0309.csv skipped!
# SIGNAL FILE n.309
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0310.csv skipped!
# SIGNAL FILE n.310
# SIGNAL FILE n.311
# SIGNAL FILE n.312
# SIGNAL FILE n.313
# SIGNAL FILE n.314
# SIGNAL FILE n.315
# SIGNAL FILE n.316
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0317.csv skipped!
# SIGNAL FILE n.317
# SIGNAL FILE n.318
# SIGNAL FILE n.319
# SIGNAL FILE n.320
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0321.csv skipped!
# SIGNAL FILE n.321
# SIGNAL FILE n.322
# SIGNAL FILE n.323
# SIGNAL FILE n.324
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0325.csv skipped!
# SIGNAL FILE n.325
# SIGNAL FILE n.326
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0327.csv skipped!
# SIGNAL FILE n.327
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0328.csv skipped!
# SIGNAL FILE n.328
# SIGNAL FILE n.329
# SIGNAL FILE n.330
# SIGNAL FILE n.331
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0332.csv skipped!
# SIGNAL FILE n.332
# SIGNAL FILE n.333
# SIGNAL FILE n.334
# SIGNAL FILE n.335
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0336.csv skipped!
# SIGNAL FILE n.336
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0337.csv skipped!
# SIGNAL FILE n.337
# SIGNAL FILE n.338
# SIGNAL FILE n.339
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0340.csv skipped!
# SIGNAL FILE n.340
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0341.csv skipped!
# SIGNAL FILE n.341
# SIGNAL FILE n.342
# SIGNAL FILE n.343
# SIGNAL FILE n.344
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0345.csv skipped!
# SIGNAL FILE n.345
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0346.csv skipped!
# SIGNAL FILE n.346
# SIGNAL FILE n.347
# SIGNAL FILE n.348
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0349.csv skipped!
# SIGNAL FILE n.349
# SIGNAL FILE n.350
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0351.csv skipped!
# SIGNAL FILE n.351
# SIGNAL FILE n.352
# SIGNAL FILE n.353
# SIGNAL FILE n.354
# SIGNAL FILE n.355
# SIGNAL FILE n.356
# SIGNAL FILE n.357
# SIGNAL FILE n.358
# SIGNAL FILE n.359
# SIGNAL FILE n.360
# SIGNAL FILE n.361
# SIGNAL FILE n.362
# SIGNAL FILE n.363
# SIGNAL FILE n.364
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0365.csv skipped!
# SIGNAL FILE n.365
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0366.csv skipped!
# SIGNAL FILE n.366
# SIGNAL FILE n.367
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0368.csv skipped!
# SIGNAL FILE n.368
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0369.csv skipped!
# SIGNAL FILE n.369
# SIGNAL FILE n.370
# SIGNAL FILE n.371
# SIGNAL FILE n.372
# SIGNAL FILE n.373
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0374.csv skipped!
# SIGNAL FILE n.374
# SIGNAL FILE n.375
# SIGNAL FILE n.376
# SIGNAL FILE n.377
# SIGNAL FILE n.378
# SIGNAL FILE n.379
# SIGNAL FILE n.380
# SIGNAL FILE n.381
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0382.csv skipped!
# SIGNAL FILE n.382
# SIGNAL FILE n.383
# SIGNAL FILE n.384
# SIGNAL FILE n.385
# SIGNAL FILE n.386
# SIGNAL FILE n.387
# SIGNAL FILE n.388
# SIGNAL FILE n.389
# SIGNAL FILE n.390
# SIGNAL FILE n.391
# SIGNAL FILE n.392
# SIGNAL FILE n.393
# SIGNAL FILE n.394
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0395.csv skipped!
# SIGNAL FILE n.395
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0396.csv skipped!
# SIGNAL FILE n.396
# SIGNAL FILE n.397
# SIGNAL FILE n.398
# SIGNAL FILE n.399
# SIGNAL FILE n.400
# SIGNAL FILE n.401
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0402.csv skipped!
# SIGNAL FILE n.402
# SIGNAL FILE n.403
# SIGNAL FILE n.404
# SIGNAL FILE n.405
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0406.csv skipped!
# SIGNAL FILE n.406
# SIGNAL FILE n.407
# SIGNAL FILE n.408
# SIGNAL FILE n.409
# SIGNAL FILE n.410
# SIGNAL FILE n.411
# SIGNAL FILE n.412
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0413.csv skipped!
# SIGNAL FILE n.413
# SIGNAL FILE n.414
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0415.csv skipped!
# SIGNAL FILE n.415
# SIGNAL FILE n.416
# SIGNAL FILE n.417
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0418.csv skipped!
# SIGNAL FILE n.418
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0419.csv skipped!
# SIGNAL FILE n.419
# SIGNAL FILE n.420
# SIGNAL FILE n.421
# SIGNAL FILE n.422
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0423.csv skipped!
# SIGNAL FILE n.423
# SIGNAL FILE n.424
# SIGNAL FILE n.425
# SIGNAL FILE n.426
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0427.csv skipped!
# SIGNAL FILE n.427
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0428.csv skipped!
# SIGNAL FILE n.428
# SIGNAL FILE n.429
# SIGNAL FILE n.430
# SIGNAL FILE n.431
# SIGNAL FILE n.432
# SIGNAL FILE n.433
# SIGNAL FILE n.434
# SIGNAL FILE n.435
# SIGNAL FILE n.436
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0437.csv skipped!
# SIGNAL FILE n.437
# SIGNAL FILE n.438
# SIGNAL FILE n.439
# SIGNAL FILE n.440
# SIGNAL FILE n.441
# SIGNAL FILE n.442
# SIGNAL FILE n.443
# SIGNAL FILE n.444
# SIGNAL FILE n.445
# SIGNAL FILE n.446
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0447.csv skipped!
# SIGNAL FILE n.447
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0448.csv skipped!
# SIGNAL FILE n.448
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0449.csv skipped!
# SIGNAL FILE n.449
# SIGNAL FILE n.450
# SIGNAL FILE n.451
# SIGNAL FILE n.452
# SIGNAL FILE n.453
# SIGNAL FILE n.454
# SIGNAL FILE n.455
# SIGNAL FILE n.456
# SIGNAL FILE n.457
# SIGNAL FILE n.458
# SIGNAL FILE n.459
# SIGNAL FILE n.460
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0461.csv skipped!
# SIGNAL FILE n.461
# SIGNAL FILE n.462
# SIGNAL FILE n.463
# SIGNAL FILE n.464
# SIGNAL FILE n.465
# SIGNAL FILE n.466
# SIGNAL FILE n.467
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0468.csv skipped!
# SIGNAL FILE n.468
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0469.csv skipped!
# SIGNAL FILE n.469
# SIGNAL FILE n.470
# SIGNAL FILE n.471
# SIGNAL FILE n.472
# SIGNAL FILE n.473
# SIGNAL FILE n.474
# SIGNAL FILE n.475
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0476.csv skipped!
# SIGNAL FILE n.476
# SIGNAL FILE n.477
# SIGNAL FILE n.478
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0479.csv skipped!
# SIGNAL FILE n.479
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0480.csv skipped!
# SIGNAL FILE n.480
# SIGNAL FILE n.481
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0482.csv skipped!
# SIGNAL FILE n.482
# SIGNAL FILE n.483
# SIGNAL FILE n.484
# SIGNAL FILE n.485
# SIGNAL FILE n.486
# SIGNAL FILE n.487
# SIGNAL FILE n.488
# SIGNAL FILE n.489
# SIGNAL FILE n.490
# SIGNAL FILE n.491
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0492.csv skipped!
# SIGNAL FILE n.492
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0493.csv skipped!
# SIGNAL FILE n.493
# SIGNAL FILE n.494
# SIGNAL FILE n.495
# SIGNAL FILE n.496
# SIGNAL FILE n.497
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0498.csv skipped!
# SIGNAL FILE n.498
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0499.csv skipped!
# SIGNAL FILE n.499
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0500.csv skipped!
# SIGNAL FILE n.500
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0501.csv skipped!
# SIGNAL FILE n.501
# SIGNAL FILE n.502
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0503.csv skipped!
# SIGNAL FILE n.503
# SIGNAL FILE n.504
# SIGNAL FILE n.505
# SIGNAL FILE n.506
# SIGNAL FILE n.507
# SIGNAL FILE n.508
# SIGNAL FILE n.509
# SIGNAL FILE n.510
# SIGNAL FILE n.511
# SIGNAL FILE n.512
# SIGNAL FILE n.513
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0514.csv skipped!
# SIGNAL FILE n.514
# SIGNAL FILE n.515
# SIGNAL FILE n.516
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0517.csv skipped!
# SIGNAL FILE n.517
# SIGNAL FILE n.518
# SIGNAL FILE n.519
# SIGNAL FILE n.520
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0521.csv skipped!
# SIGNAL FILE n.521
# SIGNAL FILE n.522
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0523.csv skipped!
# SIGNAL FILE n.523
# SIGNAL FILE n.524
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0525.csv skipped!
# SIGNAL FILE n.525
# SIGNAL FILE n.526
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0527.csv skipped!
# SIGNAL FILE n.527
# SIGNAL FILE n.528
# SIGNAL FILE n.529
# SIGNAL FILE n.530
# SIGNAL FILE n.531
# SIGNAL FILE n.532
# SIGNAL FILE n.533
# SIGNAL FILE n.534
# SIGNAL FILE n.535
# SIGNAL FILE n.536
# SIGNAL FILE n.537
# SIGNAL FILE n.538
# SIGNAL FILE n.539
# SIGNAL FILE n.540
# SIGNAL FILE n.541
# SIGNAL FILE n.542
# SIGNAL FILE n.543
# SIGNAL FILE n.544
# SIGNAL FILE n.545
# SIGNAL FILE n.546
# SIGNAL FILE n.547
# SIGNAL FILE n.548
# SIGNAL FILE n.549
# SIGNAL FILE n.550
# SIGNAL FILE n.551
# SIGNAL FILE n.552
# SIGNAL FILE n.553
# SIGNAL FILE n.554
# SIGNAL FILE n.555
# SIGNAL FILE n.556
# SIGNAL FILE n.557
# SIGNAL FILE n.558
# SIGNAL FILE n.559
# SIGNAL FILE n.560
# SIGNAL FILE n.561
# SIGNAL FILE n.562
# SIGNAL FILE n.563
# SIGNAL FILE n.564
# SIGNAL FILE n.565
# SIGNAL FILE n.566
# SIGNAL FILE n.567
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0568.csv skipped!
# SIGNAL FILE n.568
# /content/drive/MyDrive/project_files/Bkg_new/rec_hits_0569.csv skipped!
# SIGNAL FILE n.569
# SIGNAL FILE n.570
# SIGNAL FILE n.571
# SIGNAL FILE n.572
# SIGNAL FILE n.573
# SIGNAL FILE n.574
# SIGNAL FILE n.575
# SIGNAL FILE n.576
# SIGNAL FILE n.577
# SIGNAL FILE n.578
# SIGNAL FILE n.579
# SIGNAL FILE n.580
# SIGNAL FILE n.581
# Tempo totale: 19.4577s

# %%
import os
import pandas as pd
import numpy as np
import time

nfiles = 582
df_sim_signal_list = []
df_index = 0
new_file_init = True

start = time.perf_counter()
print(f"SIMULATION DATASET")
for f in range(nfiles):
    print(f"SIGNAL FILE n.{f}")

    file_string = f"Bkg_1SignalPer2usframe_2601/sim_parts_{f+1:04d}.csv"

    if not os.path.exists(file_string):
        print(file_string + " skipped!")
        continue

    # Leggi CSV
    df_sim_signal = pd.read_csv(file_string, sep=',')

    # Salta DataFrame vuoti o senza colonna "event"
    if df_sim_signal.empty or "event" not in df_sim_signal.columns:
        continue

    # Riallinea eventi locali partendo da 0
    df_sim_signal["event"] = df_sim_signal.groupby("event", sort=False).ngroup()

    # Converte a intero per sicurezza
    df_sim_signal["event"] = df_sim_signal["event"].astype(int)

    nevents = df_sim_signal["event"].max()

    if new_file_init:
        # Split se supera 999
        if nevents > 999:
            df1 = df_sim_signal[df_sim_signal["event"] <= 999].copy()
            df2 = df_sim_signal[df_sim_signal["event"] > 999].copy()

            if not df2.empty:
                df2["event"] = (df2["event"] - df2["event"].min()) % 1000
                df2["event"] = df2["event"].astype(int)

            df_sim_signal_list.append(df1)
            df_index += 1
            df_sim_signal_list.append(df2)
        else:
            df_sim_signal_list.append(df_rec_signal)
        new_file_init = False
    else:
        # Offset globale rispetto al precedente, modulo 1000 per wrap
        df_previous = df_sim_signal_list[df_index]
        prev_max = df_previous["event"].max() if not df_previous.empty else -1
        df_sim_signal["event"] = (df_sim_signal["event"] + prev_max + 1)# % 1000
        df_sim_signal["event"] = df_sim_signal["event"].astype(int)

        # Concatenate temporanea
        df_conc = pd.concat([df_previous, df_sim_signal], ignore_index=True)
        nev = df_conc["event"].max()

        if nev > 999:
            df1 = df_conc[df_conc["event"] <= 999].copy()
            df2 = df_conc[df_conc["event"] > 999].copy()

            if not df2.empty:
                df2["event"] = (df2["event"] - df2["event"].min()) % 1000
                df2["event"] = df2["event"].astype(int)

            df_sim_signal_list[df_index] = df1
            df_index += 1
            df_sim_signal_list.append(df2)
            new_file_init = False
        else:
            df_sim_signal_list[df_index] = df_conc
            if nev == 999:
                new_file_init = True

end = time.perf_counter()
print(f"Tempo totale merging SIG+NOISE: {end - start:.4f}s")
# Out:
# SIMULATION DATASET
# SIGNAL FILE n.0
# Bkg_1SignalPer2usframe_2601/sim_parts_0001.csv skipped!
# SIGNAL FILE n.1
# Bkg_1SignalPer2usframe_2601/sim_parts_0002.csv skipped!
# SIGNAL FILE n.2
# Bkg_1SignalPer2usframe_2601/sim_parts_0003.csv skipped!
# SIGNAL FILE n.3
# Bkg_1SignalPer2usframe_2601/sim_parts_0004.csv skipped!
# SIGNAL FILE n.4
# Bkg_1SignalPer2usframe_2601/sim_parts_0005.csv skipped!
# SIGNAL FILE n.5
# Bkg_1SignalPer2usframe_2601/sim_parts_0006.csv skipped!
# SIGNAL FILE n.6
# Bkg_1SignalPer2usframe_2601/sim_parts_0007.csv skipped!
# SIGNAL FILE n.7
# Bkg_1SignalPer2usframe_2601/sim_parts_0008.csv skipped!
# SIGNAL FILE n.8
# Bkg_1SignalPer2usframe_2601/sim_parts_0009.csv skipped!
# SIGNAL FILE n.9
# Bkg_1SignalPer2usframe_2601/sim_parts_0010.csv skipped!
# SIGNAL FILE n.10
# Bkg_1SignalPer2usframe_2601/sim_parts_0011.csv skipped!
# SIGNAL FILE n.11
# Bkg_1SignalPer2usframe_2601/sim_parts_0012.csv skipped!
# SIGNAL FILE n.12
# Bkg_1SignalPer2usframe_2601/sim_parts_0013.csv skipped!
# SIGNAL FILE n.13
# Bkg_1SignalPer2usframe_2601/sim_parts_0014.csv skipped!
# SIGNAL FILE n.14
# Bkg_1SignalPer2usframe_2601/sim_parts_0015.csv skipped!
# SIGNAL FILE n.15
# Bkg_1SignalPer2usframe_2601/sim_parts_0016.csv skipped!
# SIGNAL FILE n.16
# Bkg_1SignalPer2usframe_2601/sim_parts_0017.csv skipped!
# SIGNAL FILE n.17
# Bkg_1SignalPer2usframe_2601/sim_parts_0018.csv skipped!
# SIGNAL FILE n.18
# Bkg_1SignalPer2usframe_2601/sim_parts_0019.csv skipped!
# SIGNAL FILE n.19
# Bkg_1SignalPer2usframe_2601/sim_parts_0020.csv skipped!
# SIGNAL FILE n.20
# Bkg_1SignalPer2usframe_2601/sim_parts_0021.csv skipped!
# SIGNAL FILE n.21
# Bkg_1SignalPer2usframe_2601/sim_parts_0022.csv skipped!
# SIGNAL FILE n.22
# Bkg_1SignalPer2usframe_2601/sim_parts_0023.csv skipped!
# SIGNAL FILE n.23
# Bkg_1SignalPer2usframe_2601/sim_parts_0024.csv skipped!
# SIGNAL FILE n.24
# Bkg_1SignalPer2usframe_2601/sim_parts_0025.csv skipped!
# SIGNAL FILE n.25
# Bkg_1SignalPer2usframe_2601/sim_parts_0026.csv skipped!
# SIGNAL FILE n.26
# Bkg_1SignalPer2usframe_2601/sim_parts_0027.csv skipped!
# SIGNAL FILE n.27
# Bkg_1SignalPer2usframe_2601/sim_parts_0028.csv skipped!
# SIGNAL FILE n.28
# Bkg_1SignalPer2usframe_2601/sim_parts_0029.csv skipped!
# SIGNAL FILE n.29
# Bkg_1SignalPer2usframe_2601/sim_parts_0030.csv skipped!
# SIGNAL FILE n.30
# Bkg_1SignalPer2usframe_2601/sim_parts_0031.csv skipped!
# SIGNAL FILE n.31
# Bkg_1SignalPer2usframe_2601/sim_parts_0032.csv skipped!
# SIGNAL FILE n.32
# Bkg_1SignalPer2usframe_2601/sim_parts_0033.csv skipped!
# SIGNAL FILE n.33
# Bkg_1SignalPer2usframe_2601/sim_parts_0034.csv skipped!
# SIGNAL FILE n.34
# Bkg_1SignalPer2usframe_2601/sim_parts_0035.csv skipped!
# SIGNAL FILE n.35
# Bkg_1SignalPer2usframe_2601/sim_parts_0036.csv skipped!
# SIGNAL FILE n.36
# Bkg_1SignalPer2usframe_2601/sim_parts_0037.csv skipped!
# SIGNAL FILE n.37
# Bkg_1SignalPer2usframe_2601/sim_parts_0038.csv skipped!
# SIGNAL FILE n.38
# Bkg_1SignalPer2usframe_2601/sim_parts_0039.csv skipped!
# SIGNAL FILE n.39
# Bkg_1SignalPer2usframe_2601/sim_parts_0040.csv skipped!
# SIGNAL FILE n.40
# Bkg_1SignalPer2usframe_2601/sim_parts_0041.csv skipped!
# SIGNAL FILE n.41
# Bkg_1SignalPer2usframe_2601/sim_parts_0042.csv skipped!
# SIGNAL FILE n.42
# Bkg_1SignalPer2usframe_2601/sim_parts_0043.csv skipped!
# SIGNAL FILE n.43
# Bkg_1SignalPer2usframe_2601/sim_parts_0044.csv skipped!
# SIGNAL FILE n.44
# Bkg_1SignalPer2usframe_2601/sim_parts_0045.csv skipped!
# SIGNAL FILE n.45
# Bkg_1SignalPer2usframe_2601/sim_parts_0046.csv skipped!
# SIGNAL FILE n.46
# Bkg_1SignalPer2usframe_2601/sim_parts_0047.csv skipped!
# SIGNAL FILE n.47
# Bkg_1SignalPer2usframe_2601/sim_parts_0048.csv skipped!
# SIGNAL FILE n.48
# Bkg_1SignalPer2usframe_2601/sim_parts_0049.csv skipped!
# SIGNAL FILE n.49
# Bkg_1SignalPer2usframe_2601/sim_parts_0050.csv skipped!
# SIGNAL FILE n.50
# Bkg_1SignalPer2usframe_2601/sim_parts_0051.csv skipped!
# SIGNAL FILE n.51
# Bkg_1SignalPer2usframe_2601/sim_parts_0052.csv skipped!
# SIGNAL FILE n.52
# Bkg_1SignalPer2usframe_2601/sim_parts_0053.csv skipped!
# SIGNAL FILE n.53
# Bkg_1SignalPer2usframe_2601/sim_parts_0054.csv skipped!
# SIGNAL FILE n.54
# Bkg_1SignalPer2usframe_2601/sim_parts_0055.csv skipped!
# SIGNAL FILE n.55
# Bkg_1SignalPer2usframe_2601/sim_parts_0056.csv skipped!
# SIGNAL FILE n.56
# Bkg_1SignalPer2usframe_2601/sim_parts_0057.csv skipped!
# SIGNAL FILE n.57
# Bkg_1SignalPer2usframe_2601/sim_parts_0058.csv skipped!
# SIGNAL FILE n.58
# Bkg_1SignalPer2usframe_2601/sim_parts_0059.csv skipped!
# SIGNAL FILE n.59
# Bkg_1SignalPer2usframe_2601/sim_parts_0060.csv skipped!
# SIGNAL FILE n.60
# Bkg_1SignalPer2usframe_2601/sim_parts_0061.csv skipped!
# SIGNAL FILE n.61
# Bkg_1SignalPer2usframe_2601/sim_parts_0062.csv skipped!
# SIGNAL FILE n.62
# Bkg_1SignalPer2usframe_2601/sim_parts_0063.csv skipped!
# SIGNAL FILE n.63
# Bkg_1SignalPer2usframe_2601/sim_parts_0064.csv skipped!
# SIGNAL FILE n.64
# Bkg_1SignalPer2usframe_2601/sim_parts_0065.csv skipped!
# SIGNAL FILE n.65
# Bkg_1SignalPer2usframe_2601/sim_parts_0066.csv skipped!
# SIGNAL FILE n.66
# Bkg_1SignalPer2usframe_2601/sim_parts_0067.csv skipped!
# SIGNAL FILE n.67
# Bkg_1SignalPer2usframe_2601/sim_parts_0068.csv skipped!
# SIGNAL FILE n.68
# Bkg_1SignalPer2usframe_2601/sim_parts_0069.csv skipped!
# SIGNAL FILE n.69
# Bkg_1SignalPer2usframe_2601/sim_parts_0070.csv skipped!
# SIGNAL FILE n.70
# Bkg_1SignalPer2usframe_2601/sim_parts_0071.csv skipped!
# SIGNAL FILE n.71
# Bkg_1SignalPer2usframe_2601/sim_parts_0072.csv skipped!
# SIGNAL FILE n.72
# Bkg_1SignalPer2usframe_2601/sim_parts_0073.csv skipped!
# SIGNAL FILE n.73
# Bkg_1SignalPer2usframe_2601/sim_parts_0074.csv skipped!
# SIGNAL FILE n.74
# Bkg_1SignalPer2usframe_2601/sim_parts_0075.csv skipped!
# SIGNAL FILE n.75
# Bkg_1SignalPer2usframe_2601/sim_parts_0076.csv skipped!
# SIGNAL FILE n.76
# Bkg_1SignalPer2usframe_2601/sim_parts_0077.csv skipped!
# SIGNAL FILE n.77
# Bkg_1SignalPer2usframe_2601/sim_parts_0078.csv skipped!
# SIGNAL FILE n.78
# Bkg_1SignalPer2usframe_2601/sim_parts_0079.csv skipped!
# SIGNAL FILE n.79
# Bkg_1SignalPer2usframe_2601/sim_parts_0080.csv skipped!
# SIGNAL FILE n.80
# Bkg_1SignalPer2usframe_2601/sim_parts_0081.csv skipped!
# SIGNAL FILE n.81
# Bkg_1SignalPer2usframe_2601/sim_parts_0082.csv skipped!
# SIGNAL FILE n.82
# Bkg_1SignalPer2usframe_2601/sim_parts_0083.csv skipped!
# SIGNAL FILE n.83
# Bkg_1SignalPer2usframe_2601/sim_parts_0084.csv skipped!
# SIGNAL FILE n.84
# Bkg_1SignalPer2usframe_2601/sim_parts_0085.csv skipped!
# SIGNAL FILE n.85
# Bkg_1SignalPer2usframe_2601/sim_parts_0086.csv skipped!
# SIGNAL FILE n.86
# Bkg_1SignalPer2usframe_2601/sim_parts_0087.csv skipped!
# SIGNAL FILE n.87
# Bkg_1SignalPer2usframe_2601/sim_parts_0088.csv skipped!
# SIGNAL FILE n.88
# Bkg_1SignalPer2usframe_2601/sim_parts_0089.csv skipped!
# SIGNAL FILE n.89
# Bkg_1SignalPer2usframe_2601/sim_parts_0090.csv skipped!
# SIGNAL FILE n.90
# Bkg_1SignalPer2usframe_2601/sim_parts_0091.csv skipped!
# SIGNAL FILE n.91
# Bkg_1SignalPer2usframe_2601/sim_parts_0092.csv skipped!
# SIGNAL FILE n.92
# Bkg_1SignalPer2usframe_2601/sim_parts_0093.csv skipped!
# SIGNAL FILE n.93
# Bkg_1SignalPer2usframe_2601/sim_parts_0094.csv skipped!
# SIGNAL FILE n.94
# Bkg_1SignalPer2usframe_2601/sim_parts_0095.csv skipped!
# SIGNAL FILE n.95
# Bkg_1SignalPer2usframe_2601/sim_parts_0096.csv skipped!
# SIGNAL FILE n.96
# Bkg_1SignalPer2usframe_2601/sim_parts_0097.csv skipped!
# SIGNAL FILE n.97
# Bkg_1SignalPer2usframe_2601/sim_parts_0098.csv skipped!
# SIGNAL FILE n.98
# Bkg_1SignalPer2usframe_2601/sim_parts_0099.csv skipped!
# SIGNAL FILE n.99
# Bkg_1SignalPer2usframe_2601/sim_parts_0100.csv skipped!
# SIGNAL FILE n.100
# Bkg_1SignalPer2usframe_2601/sim_parts_0101.csv skipped!
# SIGNAL FILE n.101
# Bkg_1SignalPer2usframe_2601/sim_parts_0102.csv skipped!
# SIGNAL FILE n.102
# Bkg_1SignalPer2usframe_2601/sim_parts_0103.csv skipped!
# SIGNAL FILE n.103
# Bkg_1SignalPer2usframe_2601/sim_parts_0104.csv skipped!
# SIGNAL FILE n.104
# Bkg_1SignalPer2usframe_2601/sim_parts_0105.csv skipped!
# SIGNAL FILE n.105
# Bkg_1SignalPer2usframe_2601/sim_parts_0106.csv skipped!
# SIGNAL FILE n.106
# Bkg_1SignalPer2usframe_2601/sim_parts_0107.csv skipped!
# SIGNAL FILE n.107
# Bkg_1SignalPer2usframe_2601/sim_parts_0108.csv skipped!
# SIGNAL FILE n.108
# Bkg_1SignalPer2usframe_2601/sim_parts_0109.csv skipped!
# SIGNAL FILE n.109
# Bkg_1SignalPer2usframe_2601/sim_parts_0110.csv skipped!
# SIGNAL FILE n.110
# Bkg_1SignalPer2usframe_2601/sim_parts_0111.csv skipped!
# SIGNAL FILE n.111
# Bkg_1SignalPer2usframe_2601/sim_parts_0112.csv skipped!
# SIGNAL FILE n.112
# Bkg_1SignalPer2usframe_2601/sim_parts_0113.csv skipped!
# SIGNAL FILE n.113
# Bkg_1SignalPer2usframe_2601/sim_parts_0114.csv skipped!
# SIGNAL FILE n.114
# Bkg_1SignalPer2usframe_2601/sim_parts_0115.csv skipped!
# SIGNAL FILE n.115
# Bkg_1SignalPer2usframe_2601/sim_parts_0116.csv skipped!
# SIGNAL FILE n.116
# Bkg_1SignalPer2usframe_2601/sim_parts_0117.csv skipped!
# SIGNAL FILE n.117
# Bkg_1SignalPer2usframe_2601/sim_parts_0118.csv skipped!
# SIGNAL FILE n.118
# Bkg_1SignalPer2usframe_2601/sim_parts_0119.csv skipped!
# SIGNAL FILE n.119
# Bkg_1SignalPer2usframe_2601/sim_parts_0120.csv skipped!
# SIGNAL FILE n.120
# Bkg_1SignalPer2usframe_2601/sim_parts_0121.csv skipped!
# SIGNAL FILE n.121
# Bkg_1SignalPer2usframe_2601/sim_parts_0122.csv skipped!
# SIGNAL FILE n.122
# Bkg_1SignalPer2usframe_2601/sim_parts_0123.csv skipped!
# SIGNAL FILE n.123
# Bkg_1SignalPer2usframe_2601/sim_parts_0124.csv skipped!
# SIGNAL FILE n.124
# Bkg_1SignalPer2usframe_2601/sim_parts_0125.csv skipped!
# SIGNAL FILE n.125
# Bkg_1SignalPer2usframe_2601/sim_parts_0126.csv skipped!
# SIGNAL FILE n.126
# Bkg_1SignalPer2usframe_2601/sim_parts_0127.csv skipped!
# SIGNAL FILE n.127
# Bkg_1SignalPer2usframe_2601/sim_parts_0128.csv skipped!
# SIGNAL FILE n.128
# Bkg_1SignalPer2usframe_2601/sim_parts_0129.csv skipped!
# SIGNAL FILE n.129
# Bkg_1SignalPer2usframe_2601/sim_parts_0130.csv skipped!
# SIGNAL FILE n.130
# Bkg_1SignalPer2usframe_2601/sim_parts_0131.csv skipped!
# SIGNAL FILE n.131
# Bkg_1SignalPer2usframe_2601/sim_parts_0132.csv skipped!
# SIGNAL FILE n.132
# Bkg_1SignalPer2usframe_2601/sim_parts_0133.csv skipped!
# SIGNAL FILE n.133
# Bkg_1SignalPer2usframe_2601/sim_parts_0134.csv skipped!
# SIGNAL FILE n.134
# Bkg_1SignalPer2usframe_2601/sim_parts_0135.csv skipped!
# SIGNAL FILE n.135
# Bkg_1SignalPer2usframe_2601/sim_parts_0136.csv skipped!
# SIGNAL FILE n.136
# Bkg_1SignalPer2usframe_2601/sim_parts_0137.csv skipped!
# SIGNAL FILE n.137
# Bkg_1SignalPer2usframe_2601/sim_parts_0138.csv skipped!
# SIGNAL FILE n.138
# Bkg_1SignalPer2usframe_2601/sim_parts_0139.csv skipped!
# SIGNAL FILE n.139
# Bkg_1SignalPer2usframe_2601/sim_parts_0140.csv skipped!
# SIGNAL FILE n.140
# Bkg_1SignalPer2usframe_2601/sim_parts_0141.csv skipped!
# SIGNAL FILE n.141
# Bkg_1SignalPer2usframe_2601/sim_parts_0142.csv skipped!
# SIGNAL FILE n.142
# Bkg_1SignalPer2usframe_2601/sim_parts_0143.csv skipped!
# SIGNAL FILE n.143
# Bkg_1SignalPer2usframe_2601/sim_parts_0144.csv skipped!
# SIGNAL FILE n.144
# Bkg_1SignalPer2usframe_2601/sim_parts_0145.csv skipped!
# SIGNAL FILE n.145
# Bkg_1SignalPer2usframe_2601/sim_parts_0146.csv skipped!
# SIGNAL FILE n.146
# Bkg_1SignalPer2usframe_2601/sim_parts_0147.csv skipped!
# SIGNAL FILE n.147
# Bkg_1SignalPer2usframe_2601/sim_parts_0148.csv skipped!
# SIGNAL FILE n.148
# Bkg_1SignalPer2usframe_2601/sim_parts_0149.csv skipped!
# SIGNAL FILE n.149
# Bkg_1SignalPer2usframe_2601/sim_parts_0150.csv skipped!
# SIGNAL FILE n.150
# Bkg_1SignalPer2usframe_2601/sim_parts_0151.csv skipped!
# SIGNAL FILE n.151
# Bkg_1SignalPer2usframe_2601/sim_parts_0152.csv skipped!
# SIGNAL FILE n.152
# Bkg_1SignalPer2usframe_2601/sim_parts_0153.csv skipped!
# SIGNAL FILE n.153
# Bkg_1SignalPer2usframe_2601/sim_parts_0154.csv skipped!
# SIGNAL FILE n.154
# Bkg_1SignalPer2usframe_2601/sim_parts_0155.csv skipped!
# SIGNAL FILE n.155
# Bkg_1SignalPer2usframe_2601/sim_parts_0156.csv skipped!
# SIGNAL FILE n.156
# Bkg_1SignalPer2usframe_2601/sim_parts_0157.csv skipped!
# SIGNAL FILE n.157
# Bkg_1SignalPer2usframe_2601/sim_parts_0158.csv skipped!
# SIGNAL FILE n.158
# Bkg_1SignalPer2usframe_2601/sim_parts_0159.csv skipped!
# SIGNAL FILE n.159
# Bkg_1SignalPer2usframe_2601/sim_parts_0160.csv skipped!
# SIGNAL FILE n.160
# Bkg_1SignalPer2usframe_2601/sim_parts_0161.csv skipped!
# SIGNAL FILE n.161
# Bkg_1SignalPer2usframe_2601/sim_parts_0162.csv skipped!
# SIGNAL FILE n.162
# Bkg_1SignalPer2usframe_2601/sim_parts_0163.csv skipped!
# SIGNAL FILE n.163
# Bkg_1SignalPer2usframe_2601/sim_parts_0164.csv skipped!
# SIGNAL FILE n.164
# Bkg_1SignalPer2usframe_2601/sim_parts_0165.csv skipped!
# SIGNAL FILE n.165
# Bkg_1SignalPer2usframe_2601/sim_parts_0166.csv skipped!
# SIGNAL FILE n.166
# Bkg_1SignalPer2usframe_2601/sim_parts_0167.csv skipped!
# SIGNAL FILE n.167
# Bkg_1SignalPer2usframe_2601/sim_parts_0168.csv skipped!
# SIGNAL FILE n.168
# Bkg_1SignalPer2usframe_2601/sim_parts_0169.csv skipped!
# SIGNAL FILE n.169
# Bkg_1SignalPer2usframe_2601/sim_parts_0170.csv skipped!
# SIGNAL FILE n.170
# Bkg_1SignalPer2usframe_2601/sim_parts_0171.csv skipped!
# SIGNAL FILE n.171
# Bkg_1SignalPer2usframe_2601/sim_parts_0172.csv skipped!
# SIGNAL FILE n.172
# Bkg_1SignalPer2usframe_2601/sim_parts_0173.csv skipped!
# SIGNAL FILE n.173
# Bkg_1SignalPer2usframe_2601/sim_parts_0174.csv skipped!
# SIGNAL FILE n.174
# Bkg_1SignalPer2usframe_2601/sim_parts_0175.csv skipped!
# SIGNAL FILE n.175
# Bkg_1SignalPer2usframe_2601/sim_parts_0176.csv skipped!
# SIGNAL FILE n.176
# Bkg_1SignalPer2usframe_2601/sim_parts_0177.csv skipped!
# SIGNAL FILE n.177
# Bkg_1SignalPer2usframe_2601/sim_parts_0178.csv skipped!
# SIGNAL FILE n.178
# Bkg_1SignalPer2usframe_2601/sim_parts_0179.csv skipped!
# SIGNAL FILE n.179
# Bkg_1SignalPer2usframe_2601/sim_parts_0180.csv skipped!
# SIGNAL FILE n.180
# Bkg_1SignalPer2usframe_2601/sim_parts_0181.csv skipped!
# SIGNAL FILE n.181
# Bkg_1SignalPer2usframe_2601/sim_parts_0182.csv skipped!
# SIGNAL FILE n.182
# Bkg_1SignalPer2usframe_2601/sim_parts_0183.csv skipped!
# SIGNAL FILE n.183
# Bkg_1SignalPer2usframe_2601/sim_parts_0184.csv skipped!
# SIGNAL FILE n.184
# Bkg_1SignalPer2usframe_2601/sim_parts_0185.csv skipped!
# SIGNAL FILE n.185
# Bkg_1SignalPer2usframe_2601/sim_parts_0186.csv skipped!
# SIGNAL FILE n.186
# Bkg_1SignalPer2usframe_2601/sim_parts_0187.csv skipped!
# SIGNAL FILE n.187
# Bkg_1SignalPer2usframe_2601/sim_parts_0188.csv skipped!
# SIGNAL FILE n.188
# Bkg_1SignalPer2usframe_2601/sim_parts_0189.csv skipped!
# SIGNAL FILE n.189
# Bkg_1SignalPer2usframe_2601/sim_parts_0190.csv skipped!
# SIGNAL FILE n.190
# Bkg_1SignalPer2usframe_2601/sim_parts_0191.csv skipped!
# SIGNAL FILE n.191
# Bkg_1SignalPer2usframe_2601/sim_parts_0192.csv skipped!
# SIGNAL FILE n.192
# Bkg_1SignalPer2usframe_2601/sim_parts_0193.csv skipped!
# SIGNAL FILE n.193
# Bkg_1SignalPer2usframe_2601/sim_parts_0194.csv skipped!
# SIGNAL FILE n.194
# Bkg_1SignalPer2usframe_2601/sim_parts_0195.csv skipped!
# SIGNAL FILE n.195
# Bkg_1SignalPer2usframe_2601/sim_parts_0196.csv skipped!
# SIGNAL FILE n.196
# Bkg_1SignalPer2usframe_2601/sim_parts_0197.csv skipped!
# SIGNAL FILE n.197
# Bkg_1SignalPer2usframe_2601/sim_parts_0198.csv skipped!
# SIGNAL FILE n.198
# Bkg_1SignalPer2usframe_2601/sim_parts_0199.csv skipped!
# SIGNAL FILE n.199
# Bkg_1SignalPer2usframe_2601/sim_parts_0200.csv skipped!
# SIGNAL FILE n.200
# Bkg_1SignalPer2usframe_2601/sim_parts_0201.csv skipped!
# SIGNAL FILE n.201
# Bkg_1SignalPer2usframe_2601/sim_parts_0202.csv skipped!
# SIGNAL FILE n.202
# Bkg_1SignalPer2usframe_2601/sim_parts_0203.csv skipped!
# SIGNAL FILE n.203
# Bkg_1SignalPer2usframe_2601/sim_parts_0204.csv skipped!
# SIGNAL FILE n.204
# Bkg_1SignalPer2usframe_2601/sim_parts_0205.csv skipped!
# SIGNAL FILE n.205
# Bkg_1SignalPer2usframe_2601/sim_parts_0206.csv skipped!
# SIGNAL FILE n.206
# Bkg_1SignalPer2usframe_2601/sim_parts_0207.csv skipped!
# SIGNAL FILE n.207
# Bkg_1SignalPer2usframe_2601/sim_parts_0208.csv skipped!
# SIGNAL FILE n.208
# Bkg_1SignalPer2usframe_2601/sim_parts_0209.csv skipped!
# SIGNAL FILE n.209
# Bkg_1SignalPer2usframe_2601/sim_parts_0210.csv skipped!
# SIGNAL FILE n.210
# Bkg_1SignalPer2usframe_2601/sim_parts_0211.csv skipped!
# SIGNAL FILE n.211
# Bkg_1SignalPer2usframe_2601/sim_parts_0212.csv skipped!
# SIGNAL FILE n.212
# Bkg_1SignalPer2usframe_2601/sim_parts_0213.csv skipped!
# SIGNAL FILE n.213
# Bkg_1SignalPer2usframe_2601/sim_parts_0214.csv skipped!
# SIGNAL FILE n.214
# Bkg_1SignalPer2usframe_2601/sim_parts_0215.csv skipped!
# SIGNAL FILE n.215
# Bkg_1SignalPer2usframe_2601/sim_parts_0216.csv skipped!
# SIGNAL FILE n.216
# Bkg_1SignalPer2usframe_2601/sim_parts_0217.csv skipped!
# SIGNAL FILE n.217
# Bkg_1SignalPer2usframe_2601/sim_parts_0218.csv skipped!
# SIGNAL FILE n.218
# Bkg_1SignalPer2usframe_2601/sim_parts_0219.csv skipped!
# SIGNAL FILE n.219
# Bkg_1SignalPer2usframe_2601/sim_parts_0220.csv skipped!
# SIGNAL FILE n.220
# Bkg_1SignalPer2usframe_2601/sim_parts_0221.csv skipped!
# SIGNAL FILE n.221
# Bkg_1SignalPer2usframe_2601/sim_parts_0222.csv skipped!
# SIGNAL FILE n.222
# Bkg_1SignalPer2usframe_2601/sim_parts_0223.csv skipped!
# SIGNAL FILE n.223
# Bkg_1SignalPer2usframe_2601/sim_parts_0224.csv skipped!
# SIGNAL FILE n.224
# Bkg_1SignalPer2usframe_2601/sim_parts_0225.csv skipped!
# SIGNAL FILE n.225
# Bkg_1SignalPer2usframe_2601/sim_parts_0226.csv skipped!
# SIGNAL FILE n.226
# Bkg_1SignalPer2usframe_2601/sim_parts_0227.csv skipped!
# SIGNAL FILE n.227
# Bkg_1SignalPer2usframe_2601/sim_parts_0228.csv skipped!
# SIGNAL FILE n.228
# Bkg_1SignalPer2usframe_2601/sim_parts_0229.csv skipped!
# SIGNAL FILE n.229
# Bkg_1SignalPer2usframe_2601/sim_parts_0230.csv skipped!
# SIGNAL FILE n.230
# Bkg_1SignalPer2usframe_2601/sim_parts_0231.csv skipped!
# SIGNAL FILE n.231
# Bkg_1SignalPer2usframe_2601/sim_parts_0232.csv skipped!
# SIGNAL FILE n.232
# Bkg_1SignalPer2usframe_2601/sim_parts_0233.csv skipped!
# SIGNAL FILE n.233
# Bkg_1SignalPer2usframe_2601/sim_parts_0234.csv skipped!
# SIGNAL FILE n.234
# Bkg_1SignalPer2usframe_2601/sim_parts_0235.csv skipped!
# SIGNAL FILE n.235
# Bkg_1SignalPer2usframe_2601/sim_parts_0236.csv skipped!
# SIGNAL FILE n.236
# Bkg_1SignalPer2usframe_2601/sim_parts_0237.csv skipped!
# SIGNAL FILE n.237
# Bkg_1SignalPer2usframe_2601/sim_parts_0238.csv skipped!
# SIGNAL FILE n.238
# Bkg_1SignalPer2usframe_2601/sim_parts_0239.csv skipped!
# SIGNAL FILE n.239
# Bkg_1SignalPer2usframe_2601/sim_parts_0240.csv skipped!
# SIGNAL FILE n.240
# Bkg_1SignalPer2usframe_2601/sim_parts_0241.csv skipped!
# SIGNAL FILE n.241
# Bkg_1SignalPer2usframe_2601/sim_parts_0242.csv skipped!
# SIGNAL FILE n.242
# Bkg_1SignalPer2usframe_2601/sim_parts_0243.csv skipped!
# SIGNAL FILE n.243
# Bkg_1SignalPer2usframe_2601/sim_parts_0244.csv skipped!
# SIGNAL FILE n.244
# Bkg_1SignalPer2usframe_2601/sim_parts_0245.csv skipped!
# SIGNAL FILE n.245
# Bkg_1SignalPer2usframe_2601/sim_parts_0246.csv skipped!
# SIGNAL FILE n.246
# Bkg_1SignalPer2usframe_2601/sim_parts_0247.csv skipped!
# SIGNAL FILE n.247
# Bkg_1SignalPer2usframe_2601/sim_parts_0248.csv skipped!
# SIGNAL FILE n.248
# Bkg_1SignalPer2usframe_2601/sim_parts_0249.csv skipped!
# SIGNAL FILE n.249
# Bkg_1SignalPer2usframe_2601/sim_parts_0250.csv skipped!
# SIGNAL FILE n.250
# Bkg_1SignalPer2usframe_2601/sim_parts_0251.csv skipped!
# SIGNAL FILE n.251
# Bkg_1SignalPer2usframe_2601/sim_parts_0252.csv skipped!
# SIGNAL FILE n.252
# Bkg_1SignalPer2usframe_2601/sim_parts_0253.csv skipped!
# SIGNAL FILE n.253
# Bkg_1SignalPer2usframe_2601/sim_parts_0254.csv skipped!
# SIGNAL FILE n.254
# Bkg_1SignalPer2usframe_2601/sim_parts_0255.csv skipped!
# SIGNAL FILE n.255
# Bkg_1SignalPer2usframe_2601/sim_parts_0256.csv skipped!
# SIGNAL FILE n.256
# Bkg_1SignalPer2usframe_2601/sim_parts_0257.csv skipped!
# SIGNAL FILE n.257
# Bkg_1SignalPer2usframe_2601/sim_parts_0258.csv skipped!
# SIGNAL FILE n.258
# Bkg_1SignalPer2usframe_2601/sim_parts_0259.csv skipped!
# SIGNAL FILE n.259
# Bkg_1SignalPer2usframe_2601/sim_parts_0260.csv skipped!
# SIGNAL FILE n.260
# Bkg_1SignalPer2usframe_2601/sim_parts_0261.csv skipped!
# SIGNAL FILE n.261
# Bkg_1SignalPer2usframe_2601/sim_parts_0262.csv skipped!
# SIGNAL FILE n.262
# Bkg_1SignalPer2usframe_2601/sim_parts_0263.csv skipped!
# SIGNAL FILE n.263
# Bkg_1SignalPer2usframe_2601/sim_parts_0264.csv skipped!
# SIGNAL FILE n.264
# Bkg_1SignalPer2usframe_2601/sim_parts_0265.csv skipped!
# SIGNAL FILE n.265
# Bkg_1SignalPer2usframe_2601/sim_parts_0266.csv skipped!
# SIGNAL FILE n.266
# Bkg_1SignalPer2usframe_2601/sim_parts_0267.csv skipped!
# SIGNAL FILE n.267
# Bkg_1SignalPer2usframe_2601/sim_parts_0268.csv skipped!
# SIGNAL FILE n.268
# Bkg_1SignalPer2usframe_2601/sim_parts_0269.csv skipped!
# SIGNAL FILE n.269
# Bkg_1SignalPer2usframe_2601/sim_parts_0270.csv skipped!
# SIGNAL FILE n.270
# Bkg_1SignalPer2usframe_2601/sim_parts_0271.csv skipped!
# SIGNAL FILE n.271
# Bkg_1SignalPer2usframe_2601/sim_parts_0272.csv skipped!
# SIGNAL FILE n.272
# Bkg_1SignalPer2usframe_2601/sim_parts_0273.csv skipped!
# SIGNAL FILE n.273
# Bkg_1SignalPer2usframe_2601/sim_parts_0274.csv skipped!
# SIGNAL FILE n.274
# Bkg_1SignalPer2usframe_2601/sim_parts_0275.csv skipped!
# SIGNAL FILE n.275
# Bkg_1SignalPer2usframe_2601/sim_parts_0276.csv skipped!
# SIGNAL FILE n.276
# Bkg_1SignalPer2usframe_2601/sim_parts_0277.csv skipped!
# SIGNAL FILE n.277
# Bkg_1SignalPer2usframe_2601/sim_parts_0278.csv skipped!
# SIGNAL FILE n.278
# Bkg_1SignalPer2usframe_2601/sim_parts_0279.csv skipped!
# SIGNAL FILE n.279
# Bkg_1SignalPer2usframe_2601/sim_parts_0280.csv skipped!
# SIGNAL FILE n.280
# Bkg_1SignalPer2usframe_2601/sim_parts_0281.csv skipped!
# SIGNAL FILE n.281
# Bkg_1SignalPer2usframe_2601/sim_parts_0282.csv skipped!
# SIGNAL FILE n.282
# Bkg_1SignalPer2usframe_2601/sim_parts_0283.csv skipped!
# SIGNAL FILE n.283
# Bkg_1SignalPer2usframe_2601/sim_parts_0284.csv skipped!
# SIGNAL FILE n.284
# Bkg_1SignalPer2usframe_2601/sim_parts_0285.csv skipped!
# SIGNAL FILE n.285
# Bkg_1SignalPer2usframe_2601/sim_parts_0286.csv skipped!
# SIGNAL FILE n.286
# Bkg_1SignalPer2usframe_2601/sim_parts_0287.csv skipped!
# SIGNAL FILE n.287
# Bkg_1SignalPer2usframe_2601/sim_parts_0288.csv skipped!
# SIGNAL FILE n.288
# Bkg_1SignalPer2usframe_2601/sim_parts_0289.csv skipped!
# SIGNAL FILE n.289
# Bkg_1SignalPer2usframe_2601/sim_parts_0290.csv skipped!
# SIGNAL FILE n.290
# Bkg_1SignalPer2usframe_2601/sim_parts_0291.csv skipped!
# SIGNAL FILE n.291
# Bkg_1SignalPer2usframe_2601/sim_parts_0292.csv skipped!
# SIGNAL FILE n.292
# Bkg_1SignalPer2usframe_2601/sim_parts_0293.csv skipped!
# SIGNAL FILE n.293
# Bkg_1SignalPer2usframe_2601/sim_parts_0294.csv skipped!
# SIGNAL FILE n.294
# Bkg_1SignalPer2usframe_2601/sim_parts_0295.csv skipped!
# SIGNAL FILE n.295
# Bkg_1SignalPer2usframe_2601/sim_parts_0296.csv skipped!
# SIGNAL FILE n.296
# Bkg_1SignalPer2usframe_2601/sim_parts_0297.csv skipped!
# SIGNAL FILE n.297
# Bkg_1SignalPer2usframe_2601/sim_parts_0298.csv skipped!
# SIGNAL FILE n.298
# Bkg_1SignalPer2usframe_2601/sim_parts_0299.csv skipped!
# SIGNAL FILE n.299
# Bkg_1SignalPer2usframe_2601/sim_parts_0300.csv skipped!
# SIGNAL FILE n.300
# Bkg_1SignalPer2usframe_2601/sim_parts_0301.csv skipped!
# SIGNAL FILE n.301
# Bkg_1SignalPer2usframe_2601/sim_parts_0302.csv skipped!
# SIGNAL FILE n.302
# Bkg_1SignalPer2usframe_2601/sim_parts_0303.csv skipped!
# SIGNAL FILE n.303
# Bkg_1SignalPer2usframe_2601/sim_parts_0304.csv skipped!
# SIGNAL FILE n.304
# Bkg_1SignalPer2usframe_2601/sim_parts_0305.csv skipped!
# SIGNAL FILE n.305
# Bkg_1SignalPer2usframe_2601/sim_parts_0306.csv skipped!
# SIGNAL FILE n.306
# Bkg_1SignalPer2usframe_2601/sim_parts_0307.csv skipped!
# SIGNAL FILE n.307
# Bkg_1SignalPer2usframe_2601/sim_parts_0308.csv skipped!
# SIGNAL FILE n.308
# Bkg_1SignalPer2usframe_2601/sim_parts_0309.csv skipped!
# SIGNAL FILE n.309
# Bkg_1SignalPer2usframe_2601/sim_parts_0310.csv skipped!
# SIGNAL FILE n.310
# Bkg_1SignalPer2usframe_2601/sim_parts_0311.csv skipped!
# SIGNAL FILE n.311
# Bkg_1SignalPer2usframe_2601/sim_parts_0312.csv skipped!
# SIGNAL FILE n.312
# Bkg_1SignalPer2usframe_2601/sim_parts_0313.csv skipped!
# SIGNAL FILE n.313
# Bkg_1SignalPer2usframe_2601/sim_parts_0314.csv skipped!
# SIGNAL FILE n.314
# Bkg_1SignalPer2usframe_2601/sim_parts_0315.csv skipped!
# SIGNAL FILE n.315
# Bkg_1SignalPer2usframe_2601/sim_parts_0316.csv skipped!
# SIGNAL FILE n.316
# Bkg_1SignalPer2usframe_2601/sim_parts_0317.csv skipped!
# SIGNAL FILE n.317
# Bkg_1SignalPer2usframe_2601/sim_parts_0318.csv skipped!
# SIGNAL FILE n.318
# Bkg_1SignalPer2usframe_2601/sim_parts_0319.csv skipped!
# SIGNAL FILE n.319
# Bkg_1SignalPer2usframe_2601/sim_parts_0320.csv skipped!
# SIGNAL FILE n.320
# Bkg_1SignalPer2usframe_2601/sim_parts_0321.csv skipped!
# SIGNAL FILE n.321
# Bkg_1SignalPer2usframe_2601/sim_parts_0322.csv skipped!
# SIGNAL FILE n.322
# Bkg_1SignalPer2usframe_2601/sim_parts_0323.csv skipped!
# SIGNAL FILE n.323
# Bkg_1SignalPer2usframe_2601/sim_parts_0324.csv skipped!
# SIGNAL FILE n.324
# Bkg_1SignalPer2usframe_2601/sim_parts_0325.csv skipped!
# SIGNAL FILE n.325
# Bkg_1SignalPer2usframe_2601/sim_parts_0326.csv skipped!
# SIGNAL FILE n.326
# Bkg_1SignalPer2usframe_2601/sim_parts_0327.csv skipped!
# SIGNAL FILE n.327
# Bkg_1SignalPer2usframe_2601/sim_parts_0328.csv skipped!
# SIGNAL FILE n.328
# Bkg_1SignalPer2usframe_2601/sim_parts_0329.csv skipped!
# SIGNAL FILE n.329
# Bkg_1SignalPer2usframe_2601/sim_parts_0330.csv skipped!
# SIGNAL FILE n.330
# Bkg_1SignalPer2usframe_2601/sim_parts_0331.csv skipped!
# SIGNAL FILE n.331
# Bkg_1SignalPer2usframe_2601/sim_parts_0332.csv skipped!
# SIGNAL FILE n.332
# Bkg_1SignalPer2usframe_2601/sim_parts_0333.csv skipped!
# SIGNAL FILE n.333
# Bkg_1SignalPer2usframe_2601/sim_parts_0334.csv skipped!
# SIGNAL FILE n.334
# Bkg_1SignalPer2usframe_2601/sim_parts_0335.csv skipped!
# SIGNAL FILE n.335
# Bkg_1SignalPer2usframe_2601/sim_parts_0336.csv skipped!
# SIGNAL FILE n.336
# Bkg_1SignalPer2usframe_2601/sim_parts_0337.csv skipped!
# SIGNAL FILE n.337
# Bkg_1SignalPer2usframe_2601/sim_parts_0338.csv skipped!
# SIGNAL FILE n.338
# Bkg_1SignalPer2usframe_2601/sim_parts_0339.csv skipped!
# SIGNAL FILE n.339
# Bkg_1SignalPer2usframe_2601/sim_parts_0340.csv skipped!
# SIGNAL FILE n.340
# Bkg_1SignalPer2usframe_2601/sim_parts_0341.csv skipped!
# SIGNAL FILE n.341
# Bkg_1SignalPer2usframe_2601/sim_parts_0342.csv skipped!
# SIGNAL FILE n.342
# Bkg_1SignalPer2usframe_2601/sim_parts_0343.csv skipped!
# SIGNAL FILE n.343
# Bkg_1SignalPer2usframe_2601/sim_parts_0344.csv skipped!
# SIGNAL FILE n.344
# Bkg_1SignalPer2usframe_2601/sim_parts_0345.csv skipped!
# SIGNAL FILE n.345
# Bkg_1SignalPer2usframe_2601/sim_parts_0346.csv skipped!
# SIGNAL FILE n.346
# Bkg_1SignalPer2usframe_2601/sim_parts_0347.csv skipped!
# SIGNAL FILE n.347
# Bkg_1SignalPer2usframe_2601/sim_parts_0348.csv skipped!
# SIGNAL FILE n.348
# Bkg_1SignalPer2usframe_2601/sim_parts_0349.csv skipped!
# SIGNAL FILE n.349
# Bkg_1SignalPer2usframe_2601/sim_parts_0350.csv skipped!
# SIGNAL FILE n.350
# Bkg_1SignalPer2usframe_2601/sim_parts_0351.csv skipped!
# SIGNAL FILE n.351
# Bkg_1SignalPer2usframe_2601/sim_parts_0352.csv skipped!
# SIGNAL FILE n.352
# Bkg_1SignalPer2usframe_2601/sim_parts_0353.csv skipped!
# SIGNAL FILE n.353
# Bkg_1SignalPer2usframe_2601/sim_parts_0354.csv skipped!
# SIGNAL FILE n.354
# Bkg_1SignalPer2usframe_2601/sim_parts_0355.csv skipped!
# SIGNAL FILE n.355
# Bkg_1SignalPer2usframe_2601/sim_parts_0356.csv skipped!
# SIGNAL FILE n.356
# Bkg_1SignalPer2usframe_2601/sim_parts_0357.csv skipped!
# SIGNAL FILE n.357
# Bkg_1SignalPer2usframe_2601/sim_parts_0358.csv skipped!
# SIGNAL FILE n.358
# Bkg_1SignalPer2usframe_2601/sim_parts_0359.csv skipped!
# SIGNAL FILE n.359
# Bkg_1SignalPer2usframe_2601/sim_parts_0360.csv skipped!
# SIGNAL FILE n.360
# Bkg_1SignalPer2usframe_2601/sim_parts_0361.csv skipped!
# SIGNAL FILE n.361
# Bkg_1SignalPer2usframe_2601/sim_parts_0362.csv skipped!
# SIGNAL FILE n.362
# Bkg_1SignalPer2usframe_2601/sim_parts_0363.csv skipped!
# SIGNAL FILE n.363
# Bkg_1SignalPer2usframe_2601/sim_parts_0364.csv skipped!
# SIGNAL FILE n.364
# Bkg_1SignalPer2usframe_2601/sim_parts_0365.csv skipped!
# SIGNAL FILE n.365
# Bkg_1SignalPer2usframe_2601/sim_parts_0366.csv skipped!
# SIGNAL FILE n.366
# Bkg_1SignalPer2usframe_2601/sim_parts_0367.csv skipped!
# SIGNAL FILE n.367
# Bkg_1SignalPer2usframe_2601/sim_parts_0368.csv skipped!
# SIGNAL FILE n.368
# Bkg_1SignalPer2usframe_2601/sim_parts_0369.csv skipped!
# SIGNAL FILE n.369
# Bkg_1SignalPer2usframe_2601/sim_parts_0370.csv skipped!
# SIGNAL FILE n.370
# Bkg_1SignalPer2usframe_2601/sim_parts_0371.csv skipped!
# SIGNAL FILE n.371
# Bkg_1SignalPer2usframe_2601/sim_parts_0372.csv skipped!
# SIGNAL FILE n.372
# Bkg_1SignalPer2usframe_2601/sim_parts_0373.csv skipped!
# SIGNAL FILE n.373
# Bkg_1SignalPer2usframe_2601/sim_parts_0374.csv skipped!
# SIGNAL FILE n.374
# Bkg_1SignalPer2usframe_2601/sim_parts_0375.csv skipped!
# SIGNAL FILE n.375
# Bkg_1SignalPer2usframe_2601/sim_parts_0376.csv skipped!
# SIGNAL FILE n.376
# Bkg_1SignalPer2usframe_2601/sim_parts_0377.csv skipped!
# SIGNAL FILE n.377
# Bkg_1SignalPer2usframe_2601/sim_parts_0378.csv skipped!
# SIGNAL FILE n.378
# Bkg_1SignalPer2usframe_2601/sim_parts_0379.csv skipped!
# SIGNAL FILE n.379
# Bkg_1SignalPer2usframe_2601/sim_parts_0380.csv skipped!
# SIGNAL FILE n.380
# Bkg_1SignalPer2usframe_2601/sim_parts_0381.csv skipped!
# SIGNAL FILE n.381
# Bkg_1SignalPer2usframe_2601/sim_parts_0382.csv skipped!
# SIGNAL FILE n.382
# Bkg_1SignalPer2usframe_2601/sim_parts_0383.csv skipped!
# SIGNAL FILE n.383
# Bkg_1SignalPer2usframe_2601/sim_parts_0384.csv skipped!
# SIGNAL FILE n.384
# Bkg_1SignalPer2usframe_2601/sim_parts_0385.csv skipped!
# SIGNAL FILE n.385
# Bkg_1SignalPer2usframe_2601/sim_parts_0386.csv skipped!
# SIGNAL FILE n.386
# Bkg_1SignalPer2usframe_2601/sim_parts_0387.csv skipped!
# SIGNAL FILE n.387
# Bkg_1SignalPer2usframe_2601/sim_parts_0388.csv skipped!
# SIGNAL FILE n.388
# Bkg_1SignalPer2usframe_2601/sim_parts_0389.csv skipped!
# SIGNAL FILE n.389
# Bkg_1SignalPer2usframe_2601/sim_parts_0390.csv skipped!
# SIGNAL FILE n.390
# Bkg_1SignalPer2usframe_2601/sim_parts_0391.csv skipped!
# SIGNAL FILE n.391
# Bkg_1SignalPer2usframe_2601/sim_parts_0392.csv skipped!
# SIGNAL FILE n.392
# Bkg_1SignalPer2usframe_2601/sim_parts_0393.csv skipped!
# SIGNAL FILE n.393
# Bkg_1SignalPer2usframe_2601/sim_parts_0394.csv skipped!
# SIGNAL FILE n.394
# Bkg_1SignalPer2usframe_2601/sim_parts_0395.csv skipped!
# SIGNAL FILE n.395
# Bkg_1SignalPer2usframe_2601/sim_parts_0396.csv skipped!
# SIGNAL FILE n.396
# Bkg_1SignalPer2usframe_2601/sim_parts_0397.csv skipped!
# SIGNAL FILE n.397
# Bkg_1SignalPer2usframe_2601/sim_parts_0398.csv skipped!
# SIGNAL FILE n.398
# Bkg_1SignalPer2usframe_2601/sim_parts_0399.csv skipped!
# SIGNAL FILE n.399
# Bkg_1SignalPer2usframe_2601/sim_parts_0400.csv skipped!
# SIGNAL FILE n.400
# Bkg_1SignalPer2usframe_2601/sim_parts_0401.csv skipped!
# SIGNAL FILE n.401
# Bkg_1SignalPer2usframe_2601/sim_parts_0402.csv skipped!
# SIGNAL FILE n.402
# Bkg_1SignalPer2usframe_2601/sim_parts_0403.csv skipped!
# SIGNAL FILE n.403
# Bkg_1SignalPer2usframe_2601/sim_parts_0404.csv skipped!
# SIGNAL FILE n.404
# Bkg_1SignalPer2usframe_2601/sim_parts_0405.csv skipped!
# SIGNAL FILE n.405
# Bkg_1SignalPer2usframe_2601/sim_parts_0406.csv skipped!
# SIGNAL FILE n.406
# Bkg_1SignalPer2usframe_2601/sim_parts_0407.csv skipped!
# SIGNAL FILE n.407
# Bkg_1SignalPer2usframe_2601/sim_parts_0408.csv skipped!
# SIGNAL FILE n.408
# Bkg_1SignalPer2usframe_2601/sim_parts_0409.csv skipped!
# SIGNAL FILE n.409
# Bkg_1SignalPer2usframe_2601/sim_parts_0410.csv skipped!
# SIGNAL FILE n.410
# Bkg_1SignalPer2usframe_2601/sim_parts_0411.csv skipped!
# SIGNAL FILE n.411
# Bkg_1SignalPer2usframe_2601/sim_parts_0412.csv skipped!
# SIGNAL FILE n.412
# Bkg_1SignalPer2usframe_2601/sim_parts_0413.csv skipped!
# SIGNAL FILE n.413
# Bkg_1SignalPer2usframe_2601/sim_parts_0414.csv skipped!
# SIGNAL FILE n.414
# Bkg_1SignalPer2usframe_2601/sim_parts_0415.csv skipped!
# SIGNAL FILE n.415
# Bkg_1SignalPer2usframe_2601/sim_parts_0416.csv skipped!
# SIGNAL FILE n.416
# Bkg_1SignalPer2usframe_2601/sim_parts_0417.csv skipped!
# SIGNAL FILE n.417
# Bkg_1SignalPer2usframe_2601/sim_parts_0418.csv skipped!
# SIGNAL FILE n.418
# Bkg_1SignalPer2usframe_2601/sim_parts_0419.csv skipped!
# SIGNAL FILE n.419
# Bkg_1SignalPer2usframe_2601/sim_parts_0420.csv skipped!
# SIGNAL FILE n.420
# Bkg_1SignalPer2usframe_2601/sim_parts_0421.csv skipped!
# SIGNAL FILE n.421
# Bkg_1SignalPer2usframe_2601/sim_parts_0422.csv skipped!
# SIGNAL FILE n.422
# Bkg_1SignalPer2usframe_2601/sim_parts_0423.csv skipped!
# SIGNAL FILE n.423
# Bkg_1SignalPer2usframe_2601/sim_parts_0424.csv skipped!
# SIGNAL FILE n.424
# Bkg_1SignalPer2usframe_2601/sim_parts_0425.csv skipped!
# SIGNAL FILE n.425
# Bkg_1SignalPer2usframe_2601/sim_parts_0426.csv skipped!
# SIGNAL FILE n.426
# Bkg_1SignalPer2usframe_2601/sim_parts_0427.csv skipped!
# SIGNAL FILE n.427
# Bkg_1SignalPer2usframe_2601/sim_parts_0428.csv skipped!
# SIGNAL FILE n.428
# Bkg_1SignalPer2usframe_2601/sim_parts_0429.csv skipped!
# SIGNAL FILE n.429
# Bkg_1SignalPer2usframe_2601/sim_parts_0430.csv skipped!
# SIGNAL FILE n.430
# Bkg_1SignalPer2usframe_2601/sim_parts_0431.csv skipped!
# SIGNAL FILE n.431
# Bkg_1SignalPer2usframe_2601/sim_parts_0432.csv skipped!
# SIGNAL FILE n.432
# Bkg_1SignalPer2usframe_2601/sim_parts_0433.csv skipped!
# SIGNAL FILE n.433
# Bkg_1SignalPer2usframe_2601/sim_parts_0434.csv skipped!
# SIGNAL FILE n.434
# Bkg_1SignalPer2usframe_2601/sim_parts_0435.csv skipped!
# SIGNAL FILE n.435
# Bkg_1SignalPer2usframe_2601/sim_parts_0436.csv skipped!
# SIGNAL FILE n.436
# Bkg_1SignalPer2usframe_2601/sim_parts_0437.csv skipped!
# SIGNAL FILE n.437
# Bkg_1SignalPer2usframe_2601/sim_parts_0438.csv skipped!
# SIGNAL FILE n.438
# Bkg_1SignalPer2usframe_2601/sim_parts_0439.csv skipped!
# SIGNAL FILE n.439
# Bkg_1SignalPer2usframe_2601/sim_parts_0440.csv skipped!
# SIGNAL FILE n.440
# Bkg_1SignalPer2usframe_2601/sim_parts_0441.csv skipped!
# SIGNAL FILE n.441
# Bkg_1SignalPer2usframe_2601/sim_parts_0442.csv skipped!
# SIGNAL FILE n.442
# Bkg_1SignalPer2usframe_2601/sim_parts_0443.csv skipped!
# SIGNAL FILE n.443
# Bkg_1SignalPer2usframe_2601/sim_parts_0444.csv skipped!
# SIGNAL FILE n.444
# Bkg_1SignalPer2usframe_2601/sim_parts_0445.csv skipped!
# SIGNAL FILE n.445
# Bkg_1SignalPer2usframe_2601/sim_parts_0446.csv skipped!
# SIGNAL FILE n.446
# Bkg_1SignalPer2usframe_2601/sim_parts_0447.csv skipped!
# SIGNAL FILE n.447
# Bkg_1SignalPer2usframe_2601/sim_parts_0448.csv skipped!
# SIGNAL FILE n.448
# Bkg_1SignalPer2usframe_2601/sim_parts_0449.csv skipped!
# SIGNAL FILE n.449
# Bkg_1SignalPer2usframe_2601/sim_parts_0450.csv skipped!
# SIGNAL FILE n.450
# Bkg_1SignalPer2usframe_2601/sim_parts_0451.csv skipped!
# SIGNAL FILE n.451
# Bkg_1SignalPer2usframe_2601/sim_parts_0452.csv skipped!
# SIGNAL FILE n.452
# Bkg_1SignalPer2usframe_2601/sim_parts_0453.csv skipped!
# SIGNAL FILE n.453
# Bkg_1SignalPer2usframe_2601/sim_parts_0454.csv skipped!
# SIGNAL FILE n.454
# Bkg_1SignalPer2usframe_2601/sim_parts_0455.csv skipped!
# SIGNAL FILE n.455
# Bkg_1SignalPer2usframe_2601/sim_parts_0456.csv skipped!
# SIGNAL FILE n.456
# Bkg_1SignalPer2usframe_2601/sim_parts_0457.csv skipped!
# SIGNAL FILE n.457
# Bkg_1SignalPer2usframe_2601/sim_parts_0458.csv skipped!
# SIGNAL FILE n.458
# Bkg_1SignalPer2usframe_2601/sim_parts_0459.csv skipped!
# SIGNAL FILE n.459
# Bkg_1SignalPer2usframe_2601/sim_parts_0460.csv skipped!
# SIGNAL FILE n.460
# Bkg_1SignalPer2usframe_2601/sim_parts_0461.csv skipped!
# SIGNAL FILE n.461
# Bkg_1SignalPer2usframe_2601/sim_parts_0462.csv skipped!
# SIGNAL FILE n.462
# Bkg_1SignalPer2usframe_2601/sim_parts_0463.csv skipped!
# SIGNAL FILE n.463
# Bkg_1SignalPer2usframe_2601/sim_parts_0464.csv skipped!
# SIGNAL FILE n.464
# Bkg_1SignalPer2usframe_2601/sim_parts_0465.csv skipped!
# SIGNAL FILE n.465
# Bkg_1SignalPer2usframe_2601/sim_parts_0466.csv skipped!
# SIGNAL FILE n.466
# Bkg_1SignalPer2usframe_2601/sim_parts_0467.csv skipped!
# SIGNAL FILE n.467
# Bkg_1SignalPer2usframe_2601/sim_parts_0468.csv skipped!
# SIGNAL FILE n.468
# Bkg_1SignalPer2usframe_2601/sim_parts_0469.csv skipped!
# SIGNAL FILE n.469
# Bkg_1SignalPer2usframe_2601/sim_parts_0470.csv skipped!
# SIGNAL FILE n.470
# Bkg_1SignalPer2usframe_2601/sim_parts_0471.csv skipped!
# SIGNAL FILE n.471
# Bkg_1SignalPer2usframe_2601/sim_parts_0472.csv skipped!
# SIGNAL FILE n.472
# Bkg_1SignalPer2usframe_2601/sim_parts_0473.csv skipped!
# SIGNAL FILE n.473
# Bkg_1SignalPer2usframe_2601/sim_parts_0474.csv skipped!
# SIGNAL FILE n.474
# Bkg_1SignalPer2usframe_2601/sim_parts_0475.csv skipped!
# SIGNAL FILE n.475
# Bkg_1SignalPer2usframe_2601/sim_parts_0476.csv skipped!
# SIGNAL FILE n.476
# Bkg_1SignalPer2usframe_2601/sim_parts_0477.csv skipped!
# SIGNAL FILE n.477
# Bkg_1SignalPer2usframe_2601/sim_parts_0478.csv skipped!
# SIGNAL FILE n.478
# Bkg_1SignalPer2usframe_2601/sim_parts_0479.csv skipped!
# SIGNAL FILE n.479
# Bkg_1SignalPer2usframe_2601/sim_parts_0480.csv skipped!
# SIGNAL FILE n.480
# Bkg_1SignalPer2usframe_2601/sim_parts_0481.csv skipped!
# SIGNAL FILE n.481
# Bkg_1SignalPer2usframe_2601/sim_parts_0482.csv skipped!
# SIGNAL FILE n.482
# Bkg_1SignalPer2usframe_2601/sim_parts_0483.csv skipped!
# SIGNAL FILE n.483
# Bkg_1SignalPer2usframe_2601/sim_parts_0484.csv skipped!
# SIGNAL FILE n.484
# Bkg_1SignalPer2usframe_2601/sim_parts_0485.csv skipped!
# SIGNAL FILE n.485
# Bkg_1SignalPer2usframe_2601/sim_parts_0486.csv skipped!
# SIGNAL FILE n.486
# Bkg_1SignalPer2usframe_2601/sim_parts_0487.csv skipped!
# SIGNAL FILE n.487
# Bkg_1SignalPer2usframe_2601/sim_parts_0488.csv skipped!
# SIGNAL FILE n.488
# Bkg_1SignalPer2usframe_2601/sim_parts_0489.csv skipped!
# SIGNAL FILE n.489
# Bkg_1SignalPer2usframe_2601/sim_parts_0490.csv skipped!
# SIGNAL FILE n.490
# Bkg_1SignalPer2usframe_2601/sim_parts_0491.csv skipped!
# SIGNAL FILE n.491
# Bkg_1SignalPer2usframe_2601/sim_parts_0492.csv skipped!
# SIGNAL FILE n.492
# Bkg_1SignalPer2usframe_2601/sim_parts_0493.csv skipped!
# SIGNAL FILE n.493
# Bkg_1SignalPer2usframe_2601/sim_parts_0494.csv skipped!
# SIGNAL FILE n.494
# Bkg_1SignalPer2usframe_2601/sim_parts_0495.csv skipped!
# SIGNAL FILE n.495
# Bkg_1SignalPer2usframe_2601/sim_parts_0496.csv skipped!
# SIGNAL FILE n.496
# Bkg_1SignalPer2usframe_2601/sim_parts_0497.csv skipped!
# SIGNAL FILE n.497
# Bkg_1SignalPer2usframe_2601/sim_parts_0498.csv skipped!
# SIGNAL FILE n.498
# Bkg_1SignalPer2usframe_2601/sim_parts_0499.csv skipped!
# SIGNAL FILE n.499
# Bkg_1SignalPer2usframe_2601/sim_parts_0500.csv skipped!
# SIGNAL FILE n.500
# Bkg_1SignalPer2usframe_2601/sim_parts_0501.csv skipped!
# SIGNAL FILE n.501
# Bkg_1SignalPer2usframe_2601/sim_parts_0502.csv skipped!
# SIGNAL FILE n.502
# Bkg_1SignalPer2usframe_2601/sim_parts_0503.csv skipped!
# SIGNAL FILE n.503
# Bkg_1SignalPer2usframe_2601/sim_parts_0504.csv skipped!
# SIGNAL FILE n.504
# Bkg_1SignalPer2usframe_2601/sim_parts_0505.csv skipped!
# SIGNAL FILE n.505
# Bkg_1SignalPer2usframe_2601/sim_parts_0506.csv skipped!
# SIGNAL FILE n.506
# Bkg_1SignalPer2usframe_2601/sim_parts_0507.csv skipped!
# SIGNAL FILE n.507
# Bkg_1SignalPer2usframe_2601/sim_parts_0508.csv skipped!
# SIGNAL FILE n.508
# Bkg_1SignalPer2usframe_2601/sim_parts_0509.csv skipped!
# SIGNAL FILE n.509
# Bkg_1SignalPer2usframe_2601/sim_parts_0510.csv skipped!
# SIGNAL FILE n.510
# Bkg_1SignalPer2usframe_2601/sim_parts_0511.csv skipped!
# SIGNAL FILE n.511
# Bkg_1SignalPer2usframe_2601/sim_parts_0512.csv skipped!
# SIGNAL FILE n.512
# Bkg_1SignalPer2usframe_2601/sim_parts_0513.csv skipped!
# SIGNAL FILE n.513
# Bkg_1SignalPer2usframe_2601/sim_parts_0514.csv skipped!
# SIGNAL FILE n.514
# Bkg_1SignalPer2usframe_2601/sim_parts_0515.csv skipped!
# SIGNAL FILE n.515
# Bkg_1SignalPer2usframe_2601/sim_parts_0516.csv skipped!
# SIGNAL FILE n.516
# Bkg_1SignalPer2usframe_2601/sim_parts_0517.csv skipped!
# SIGNAL FILE n.517
# Bkg_1SignalPer2usframe_2601/sim_parts_0518.csv skipped!
# SIGNAL FILE n.518
# Bkg_1SignalPer2usframe_2601/sim_parts_0519.csv skipped!
# SIGNAL FILE n.519
# Bkg_1SignalPer2usframe_2601/sim_parts_0520.csv skipped!
# SIGNAL FILE n.520
# Bkg_1SignalPer2usframe_2601/sim_parts_0521.csv skipped!
# SIGNAL FILE n.521
# Bkg_1SignalPer2usframe_2601/sim_parts_0522.csv skipped!
# SIGNAL FILE n.522
# Bkg_1SignalPer2usframe_2601/sim_parts_0523.csv skipped!
# SIGNAL FILE n.523
# Bkg_1SignalPer2usframe_2601/sim_parts_0524.csv skipped!
# SIGNAL FILE n.524
# Bkg_1SignalPer2usframe_2601/sim_parts_0525.csv skipped!
# SIGNAL FILE n.525
# Bkg_1SignalPer2usframe_2601/sim_parts_0526.csv skipped!
# SIGNAL FILE n.526
# Bkg_1SignalPer2usframe_2601/sim_parts_0527.csv skipped!
# SIGNAL FILE n.527
# Bkg_1SignalPer2usframe_2601/sim_parts_0528.csv skipped!
# SIGNAL FILE n.528
# Bkg_1SignalPer2usframe_2601/sim_parts_0529.csv skipped!
# SIGNAL FILE n.529
# Bkg_1SignalPer2usframe_2601/sim_parts_0530.csv skipped!
# SIGNAL FILE n.530
# Bkg_1SignalPer2usframe_2601/sim_parts_0531.csv skipped!
# SIGNAL FILE n.531
# Bkg_1SignalPer2usframe_2601/sim_parts_0532.csv skipped!
# SIGNAL FILE n.532
# Bkg_1SignalPer2usframe_2601/sim_parts_0533.csv skipped!
# SIGNAL FILE n.533
# Bkg_1SignalPer2usframe_2601/sim_parts_0534.csv skipped!
# SIGNAL FILE n.534
# Bkg_1SignalPer2usframe_2601/sim_parts_0535.csv skipped!
# SIGNAL FILE n.535
# Bkg_1SignalPer2usframe_2601/sim_parts_0536.csv skipped!
# SIGNAL FILE n.536
# Bkg_1SignalPer2usframe_2601/sim_parts_0537.csv skipped!
# SIGNAL FILE n.537
# Bkg_1SignalPer2usframe_2601/sim_parts_0538.csv skipped!
# SIGNAL FILE n.538
# Bkg_1SignalPer2usframe_2601/sim_parts_0539.csv skipped!
# SIGNAL FILE n.539
# Bkg_1SignalPer2usframe_2601/sim_parts_0540.csv skipped!
# SIGNAL FILE n.540
# Bkg_1SignalPer2usframe_2601/sim_parts_0541.csv skipped!
# SIGNAL FILE n.541
# Bkg_1SignalPer2usframe_2601/sim_parts_0542.csv skipped!
# SIGNAL FILE n.542
# Bkg_1SignalPer2usframe_2601/sim_parts_0543.csv skipped!
# SIGNAL FILE n.543
# Bkg_1SignalPer2usframe_2601/sim_parts_0544.csv skipped!
# SIGNAL FILE n.544
# Bkg_1SignalPer2usframe_2601/sim_parts_0545.csv skipped!
# SIGNAL FILE n.545
# Bkg_1SignalPer2usframe_2601/sim_parts_0546.csv skipped!
# SIGNAL FILE n.546
# Bkg_1SignalPer2usframe_2601/sim_parts_0547.csv skipped!
# SIGNAL FILE n.547
# Bkg_1SignalPer2usframe_2601/sim_parts_0548.csv skipped!
# SIGNAL FILE n.548
# Bkg_1SignalPer2usframe_2601/sim_parts_0549.csv skipped!
# SIGNAL FILE n.549
# Bkg_1SignalPer2usframe_2601/sim_parts_0550.csv skipped!
# SIGNAL FILE n.550
# Bkg_1SignalPer2usframe_2601/sim_parts_0551.csv skipped!
# SIGNAL FILE n.551
# Bkg_1SignalPer2usframe_2601/sim_parts_0552.csv skipped!
# SIGNAL FILE n.552
# Bkg_1SignalPer2usframe_2601/sim_parts_0553.csv skipped!
# SIGNAL FILE n.553
# Bkg_1SignalPer2usframe_2601/sim_parts_0554.csv skipped!
# SIGNAL FILE n.554
# Bkg_1SignalPer2usframe_2601/sim_parts_0555.csv skipped!
# SIGNAL FILE n.555
# Bkg_1SignalPer2usframe_2601/sim_parts_0556.csv skipped!
# SIGNAL FILE n.556
# Bkg_1SignalPer2usframe_2601/sim_parts_0557.csv skipped!
# SIGNAL FILE n.557
# Bkg_1SignalPer2usframe_2601/sim_parts_0558.csv skipped!
# SIGNAL FILE n.558
# Bkg_1SignalPer2usframe_2601/sim_parts_0559.csv skipped!
# SIGNAL FILE n.559
# Bkg_1SignalPer2usframe_2601/sim_parts_0560.csv skipped!
# SIGNAL FILE n.560
# Bkg_1SignalPer2usframe_2601/sim_parts_0561.csv skipped!
# SIGNAL FILE n.561
# Bkg_1SignalPer2usframe_2601/sim_parts_0562.csv skipped!
# SIGNAL FILE n.562
# Bkg_1SignalPer2usframe_2601/sim_parts_0563.csv skipped!
# SIGNAL FILE n.563
# Bkg_1SignalPer2usframe_2601/sim_parts_0564.csv skipped!
# SIGNAL FILE n.564
# Bkg_1SignalPer2usframe_2601/sim_parts_0565.csv skipped!
# SIGNAL FILE n.565
# Bkg_1SignalPer2usframe_2601/sim_parts_0566.csv skipped!
# SIGNAL FILE n.566
# Bkg_1SignalPer2usframe_2601/sim_parts_0567.csv skipped!
# SIGNAL FILE n.567
# Bkg_1SignalPer2usframe_2601/sim_parts_0568.csv skipped!
# SIGNAL FILE n.568
# Bkg_1SignalPer2usframe_2601/sim_parts_0569.csv skipped!
# SIGNAL FILE n.569
# Bkg_1SignalPer2usframe_2601/sim_parts_0570.csv skipped!
# SIGNAL FILE n.570
# Bkg_1SignalPer2usframe_2601/sim_parts_0571.csv skipped!
# SIGNAL FILE n.571
# Bkg_1SignalPer2usframe_2601/sim_parts_0572.csv skipped!
# SIGNAL FILE n.572
# Bkg_1SignalPer2usframe_2601/sim_parts_0573.csv skipped!
# SIGNAL FILE n.573
# Bkg_1SignalPer2usframe_2601/sim_parts_0574.csv skipped!
# SIGNAL FILE n.574
# Bkg_1SignalPer2usframe_2601/sim_parts_0575.csv skipped!
# SIGNAL FILE n.575
# Bkg_1SignalPer2usframe_2601/sim_parts_0576.csv skipped!
# SIGNAL FILE n.576
# Bkg_1SignalPer2usframe_2601/sim_parts_0577.csv skipped!
# SIGNAL FILE n.577
# Bkg_1SignalPer2usframe_2601/sim_parts_0578.csv skipped!
# SIGNAL FILE n.578
# Bkg_1SignalPer2usframe_2601/sim_parts_0579.csv skipped!
# SIGNAL FILE n.579
# Bkg_1SignalPer2usframe_2601/sim_parts_0580.csv skipped!
# SIGNAL FILE n.580
# Bkg_1SignalPer2usframe_2601/sim_parts_0581.csv skipped!
# SIGNAL FILE n.581
# Bkg_1SignalPer2usframe_2601/sim_parts_0582.csv skipped!
# Tempo totale merging SIG+NOISE: 0.0111s

# %%
input_signal_matrices = []
input_nparticles_array = []


for f in range(1,len(df_rec_signal_list)-1):
    print("SIGNAL FILE n.%d" % (f))
    start = time.perf_counter()
    #df_rec_signal     = pd.read_csv("/apotto/home1/aliens/apepic/work/rossi/drich_eic/csv/no_noise_events_Bkg_realistic_25_05/rec_hits.csv.%04d.csv" % (f+1), sep = ',')
    df_rec_signal    = df_rec_signal_list[f]
    #df_sim_signal    = df_sim_signal_list[f]
    df_rec_noise     = pd.read_csv(f"/content/drive/MyDrive/project_files/Noise_files/with_time/csv_reco/noise_reco_{f}_{FREQ}kHz_10ns.csv")
    #ALCOR_gridmatrix_total, nparticles_array = grid_ALCOR_optimized_signalplusnoise_NOZEROS_nparticles(42, df_rec_noise, df_rec_signal, df_sim_signal)
    #ALCOR_gridmatrix_total, nparticles_array = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_nparticles(42, df_rec_noise, df_rec_signal, df_sim_signal, binwidth,)
    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_acceptancefiltered(42, df_rec_noise, df_rec_signal, df_sim_signal)
    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_acceptancefiltered(42, df_rec_noise, df_rec_signal, df_sim_signal, binwidth,)
    ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware(42, df_rec_noise, df_rec_signal,binwidth)
    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS(42, df_rec_noise, df_rec_signal)
    print(ALCOR_gridmatrix_total.shape)
    #print(nparticles_array.shape)
    ALCOR_gridmatrix_total = ALCOR_gridmatrix_total.reshape(ALCOR_gridmatrix_total.shape[0],6,5,42*int(ten/binwidth))
    #ALCOR_gridmatrix_total = ALCOR_gridmatrix_total.reshape(ALCOR_gridmatrix_total.shape[0],6,5,42)

    input_signal_matrices.append(ALCOR_gridmatrix_total)

    #input_nparticles_array.append(nparticles_array)


    end = time.perf_counter()
    print(f"Tempo totale: {end - start:.4f}s")
# Out:
# SIGNAL FILE n.1
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.6207s
# SIGNAL FILE n.2
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.3987s
# SIGNAL FILE n.3
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5429s
# SIGNAL FILE n.4
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4573s
# SIGNAL FILE n.5
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.9850s
# SIGNAL FILE n.6
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.8487s
# SIGNAL FILE n.7
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.9266s
# SIGNAL FILE n.8
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.3814s
# SIGNAL FILE n.9
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4444s
# SIGNAL FILE n.10
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.6982s
# SIGNAL FILE n.11
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.9881s
# SIGNAL FILE n.12
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4892s
# SIGNAL FILE n.13
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.1979s
# SIGNAL FILE n.14
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4231s
# SIGNAL FILE n.15
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4881s
# SIGNAL FILE n.16
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.0431s
# SIGNAL FILE n.17
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4543s
# SIGNAL FILE n.18
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.3878s
# SIGNAL FILE n.19
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.9897s
# SIGNAL FILE n.20
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4261s
# SIGNAL FILE n.21
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.3651s
# SIGNAL FILE n.22
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.2468s
# SIGNAL FILE n.23
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4698s
# SIGNAL FILE n.24
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.1020s
# SIGNAL FILE n.25
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.7106s
# SIGNAL FILE n.26
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4772s
# SIGNAL FILE n.27
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.2488s
# SIGNAL FILE n.28
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4585s
# SIGNAL FILE n.29
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5113s
# SIGNAL FILE n.30
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.1169s
# SIGNAL FILE n.31
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4121s
# SIGNAL FILE n.32
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.8902s
# SIGNAL FILE n.33
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.6024s
# SIGNAL FILE n.34
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4240s
# SIGNAL FILE n.35
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.4748s
# SIGNAL FILE n.36
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.1334s
# SIGNAL FILE n.37
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4228s
# SIGNAL FILE n.38
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.0669s
# SIGNAL FILE n.39
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.6897s
# SIGNAL FILE n.40
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5754s
# SIGNAL FILE n.41
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.2678s
# SIGNAL FILE n.42
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.7209s
# SIGNAL FILE n.43
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.7985s
# SIGNAL FILE n.44
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.8919s
# SIGNAL FILE n.45
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.6105s
# SIGNAL FILE n.46
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.6714s
# SIGNAL FILE n.47
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.2611s
# SIGNAL FILE n.48
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.4918s
# SIGNAL FILE n.49
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.4386s
# SIGNAL FILE n.50
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5820s
# SIGNAL FILE n.51
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5443s
# SIGNAL FILE n.52
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.2986s
# SIGNAL FILE n.53
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.7476s
# SIGNAL FILE n.54
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.2955s
# SIGNAL FILE n.55
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.6308s
# SIGNAL FILE n.56
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5983s
# SIGNAL FILE n.57
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.9860s
# SIGNAL FILE n.58
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.9174s
# SIGNAL FILE n.59
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5417s
# SIGNAL FILE n.60
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.2682s
# SIGNAL FILE n.61
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5040s
# SIGNAL FILE n.62
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5418s
# SIGNAL FILE n.63
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.9800s
# SIGNAL FILE n.64
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5577s
# SIGNAL FILE n.65
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.2044s
# SIGNAL FILE n.66
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.5218s
# SIGNAL FILE n.67
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.6170s
# SIGNAL FILE n.68
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.1523s
# SIGNAL FILE n.69
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.8384s
# SIGNAL FILE n.70
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5964s
# SIGNAL FILE n.71
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.1894s
# SIGNAL FILE n.72
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5535s
# SIGNAL FILE n.73
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.6052s
# SIGNAL FILE n.74
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.9898s
# SIGNAL FILE n.75
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5174s
# SIGNAL FILE n.76
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.4256s
# SIGNAL FILE n.77
# (1000, 6, 5, 42, 4)
# Tempo totale: 5.3251s
# SIGNAL FILE n.78
# (1000, 6, 5, 42, 4)
# Tempo totale: 4.5223s
# SIGNAL FILE n.79
# (1000, 6, 5, 42, 4)
# Tempo totale: 6.3716s

# %%
nevents=1000
if(GEN):
    for f in frequences:
        for nfile in range(n_reco_files):
            print(f"\n--- Generazione file ricostruito {nfile} ==> noise rate = {f} kHz ---")
            df_noise = noiseOnly_dataset_optimized(cellmap,nevents=nevents, freq_kHz=f,time_window_ns=10)

            #time info added
            df_noise["time"] = df_noise["time"].astype(np.float32)
            timing_col = pd.DataFrame({'time': np.random.uniform(0, ten, len(df_noise["time"]))}, dtype=np.float32)
            df_noise.update(timing_col)

            output_filename = f"/content/drive/MyDrive/project_files/Noise_files/with_time/csv_reco/only_noise_reco_{nfile}_{f}kHz_10ns.csv"
            df_noise.to_csv(output_filename, index=False)
            print(f"Salvato in {output_filename}")

# %%
#input_signal_matrices = []
#input_nparticles_array = []
#
#
#for f in range(1,num_signal_ROOT_files-1):
#    print("SIGNAL FILE n.%d" % (f))
#    start = time.perf_counter()
#    #df_rec_signal     = pd.read_csv("/apotto/home1/aliens/apepic/work/rossi/drich_eic/csv/no_noise_events_Bkg_realistic_25_05/rec_hits.csv.%04d.csv" % (f+1), sep = ',')
#    df_rec_signal    = df_rec_signal_list[f]
#    df_sim_signal    = df_sim_signal_list[f]
#    df_rec_noise     = pd.read_csv(f"csv_reco/noise_reco_{f}_{FREQ}kHz_10ns.csv")
#
#    #ALCOR_gridmatrix_total, nparticles_array = grid_ALCOR_optimized_signalplusnoise_NOZEROS_nparticles(42, df_rec_noise, df_rec_signal, df_sim_signal)
#    #ALCOR_gridmatrix_total, nparticles_array = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_nparticles(42, df_rec_noise, df_rec_signal, df_sim_signal, binwidth,)
#    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_acceptancefiltered(42, df_rec_noise, df_rec_signal, df_sim_signal)
#    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware_acceptancefiltered(42, df_rec_noise, df_rec_signal, df_sim_signal, binwidth,)
#    #ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS_timingaware(42, df_rec_noise, df_rec_signal,binwidth)
#    ALCOR_gridmatrix_total = grid_ALCOR_optimized_signalplusnoise_NOZEROS(42, df_rec_noise, df_rec_signal)
#    print(ALCOR_gridmatrix_total.shape)
#    #print(nparticles_array.shape)
#    #ALCOR_gridmatrix_total = ALCOR_gridmatrix_total.reshape(ALCOR_gridmatrix_total.shape[0],6,5,42*int(10.16/binwidth))
#    ALCOR_gridmatrix_total = ALCOR_gridmatrix_total.reshape(ALCOR_gridmatrix_total.shape[0],6,5,42)
#
#    input_signal_matrices.append(ALCOR_gridmatrix_total)
#
#    #input_nparticles_array.append(nparticles_array)
#
#
#    end = time.perf_counter()
#    print(f"Tempo totale: {end - start:.4f}s")

# %%
input_noise_matrices = []
y_noise_training = []
for f in range(0,len(df_rec_signal_list)):
    print("NOISE FILE n.%d" % (f))
    start = time.perf_counter()
    df_rec_noise     = pd.read_csv(f"/content/drive/MyDrive/project_files/Noise_files/with_time/csv_reco/noise_reco_{f}_{FREQ}kHz_10ns.csv")
    #df_rec_noise     = pd.read_csv("../csv/2501_noise_events_300kHz_10ns/rec_hits.csv_%01d.csv" % (f+1), sep = ',')
    ALCOR_gridmatrix = grid_ALCOR_optimized_timingaware(42, df_rec_noise,binwidth)
    #ALCOR_gridmatrix = grid_ALCOR_optimized(42, df_rec_noise)
    #ALCOR_gridmatrix = ALCOR_gridmatrix.reshape(1000,6,5,42)
    ALCOR_gridmatrix = ALCOR_gridmatrix.reshape(1000,6,5,42*int(ten/binwidth)) #badile: era *20 invece che *4

    input_noise_matrices.append(ALCOR_gridmatrix)
    end = time.perf_counter()
    print(f"Tempo totale: {end - start:.4f}s")
# Out:
# NOISE FILE n.0
# Tempo totale: 1.2325s
# NOISE FILE n.1
# Tempo totale: 1.1586s
# NOISE FILE n.2
# Tempo totale: 1.1217s
# NOISE FILE n.3
# Tempo totale: 1.1600s
# NOISE FILE n.4
# Tempo totale: 1.1561s
# NOISE FILE n.5
# Tempo totale: 1.1206s
# NOISE FILE n.6
# Tempo totale: 1.1581s
# NOISE FILE n.7
# Tempo totale: 1.1611s
# NOISE FILE n.8
# Tempo totale: 1.4927s
# NOISE FILE n.9
# Tempo totale: 1.9103s
# NOISE FILE n.10
# Tempo totale: 1.7749s
# NOISE FILE n.11
# Tempo totale: 1.1333s
# NOISE FILE n.12
# Tempo totale: 1.1142s
# NOISE FILE n.13
# Tempo totale: 1.1400s
# NOISE FILE n.14
# Tempo totale: 1.1154s
# NOISE FILE n.15
# Tempo totale: 1.1679s
# NOISE FILE n.16
# Tempo totale: 1.1708s
# NOISE FILE n.17
# Tempo totale: 1.1573s
# NOISE FILE n.18
# Tempo totale: 1.2011s
# NOISE FILE n.19
# Tempo totale: 1.3949s
# NOISE FILE n.20
# Tempo totale: 1.8173s
# NOISE FILE n.21
# Tempo totale: 1.7071s
# NOISE FILE n.22
# Tempo totale: 1.1905s
# NOISE FILE n.23
# Tempo totale: 1.1350s
# NOISE FILE n.24
# Tempo totale: 1.1750s
# NOISE FILE n.25
# Tempo totale: 1.1126s
# NOISE FILE n.26
# Tempo totale: 1.1405s
# NOISE FILE n.27
# Tempo totale: 1.1267s
# NOISE FILE n.28
# Tempo totale: 1.1257s
# NOISE FILE n.29
# Tempo totale: 1.1098s
# NOISE FILE n.30
# Tempo totale: 1.4491s
# NOISE FILE n.31
# Tempo totale: 1.8872s
# NOISE FILE n.32
# Tempo totale: 1.8183s
# NOISE FILE n.33
# Tempo totale: 1.1088s
# NOISE FILE n.34
# Tempo totale: 1.1356s
# NOISE FILE n.35
# Tempo totale: 1.1646s
# NOISE FILE n.36
# Tempo totale: 1.1535s
# NOISE FILE n.37
# Tempo totale: 1.1063s
# NOISE FILE n.38
# Tempo totale: 1.1455s
# NOISE FILE n.39
# Tempo totale: 1.1236s
# NOISE FILE n.40
# Tempo totale: 1.1672s
# NOISE FILE n.41
# Tempo totale: 1.4465s
# NOISE FILE n.42
# Tempo totale: 1.9967s
# NOISE FILE n.43
# Tempo totale: 1.7617s
# NOISE FILE n.44
# Tempo totale: 1.1953s
# NOISE FILE n.45
# Tempo totale: 1.2256s
# NOISE FILE n.46
# Tempo totale: 1.1086s
# NOISE FILE n.47
# Tempo totale: 1.1467s
# NOISE FILE n.48
# Tempo totale: 1.1369s
# NOISE FILE n.49
# Tempo totale: 1.1884s
# NOISE FILE n.50
# Tempo totale: 1.1730s
# NOISE FILE n.51
# Tempo totale: 1.2116s
# NOISE FILE n.52
# Tempo totale: 1.5499s
# NOISE FILE n.53
# Tempo totale: 1.8775s
# NOISE FILE n.54
# Tempo totale: 1.6250s
# NOISE FILE n.55
# Tempo totale: 1.1826s
# NOISE FILE n.56
# Tempo totale: 1.1784s
# NOISE FILE n.57
# Tempo totale: 1.1859s
# NOISE FILE n.58
# Tempo totale: 1.1861s
# NOISE FILE n.59
# Tempo totale: 1.1704s
# NOISE FILE n.60
# Tempo totale: 1.1467s
# NOISE FILE n.61
# Tempo totale: 1.1336s
# NOISE FILE n.62
# Tempo totale: 1.1478s
# NOISE FILE n.63
# Tempo totale: 1.7098s
# NOISE FILE n.64
# Tempo totale: 1.9053s
# NOISE FILE n.65
# Tempo totale: 1.4688s
# NOISE FILE n.66
# Tempo totale: 1.1487s
# NOISE FILE n.67
# Tempo totale: 1.1800s
# NOISE FILE n.68
# Tempo totale: 1.2178s
# NOISE FILE n.69
# Tempo totale: 1.1239s
# NOISE FILE n.70
# Tempo totale: 1.1452s
# NOISE FILE n.71
# Tempo totale: 1.1524s
# NOISE FILE n.72
# Tempo totale: 1.1789s
# NOISE FILE n.73
# Tempo totale: 1.1829s
# NOISE FILE n.74
# Tempo totale: 1.7773s
# NOISE FILE n.75
# Tempo totale: 1.8459s
# NOISE FILE n.76
# Tempo totale: 1.3442s
# NOISE FILE n.77
# Tempo totale: 1.1612s
# NOISE FILE n.78
# Tempo totale: 1.1726s
# NOISE FILE n.79
# Tempo totale: 1.1811s
# NOISE FILE n.80
# Tempo totale: 1.1502s

# %%
cosa_inutile=False
if cosa_inutile==True:
 for f in range(0,num_signal_ROOT_files-1):
    expected = set(range(1000))
    present = set(df_rec_signal_list[f]["event"])

    missing = expected - present

    if len(missing) == 0:
        print("Tutti gli eventi da 0 a 999 sono presenti")
    else:
        print(f"Mancano {len(missing)} eventi:", sorted(missing))

# %%
X_signal = np.array(input_signal_matrices)
print(X_signal.shape)
X_signal = X_signal.reshape(X_signal.shape[0]*X_signal.shape[1],30, 42*int(ten/binwidth))
#X_signal = X_signal.reshape(X_signal.shape[0]*X_signal.shape[1],30,42)
print(X_signal.shape)
# Out:
# (79, 1000, 6, 5, 168)
# (79000, 30, 168)

# %%
X_noise = np.array(input_noise_matrices)
print(X_noise.shape)
X_noise = X_noise.reshape(X_noise.shape[0]*X_noise.shape[1],30, 42*int(ten/binwidth))#badile: qui era signal
#X_noise = X_noise.reshape(X_noise.shape[0]*X_noise.shape[1],30,42)
print(X_noise.shape)
# Out:
# (81, 1000, 6, 5, 168)
# (81000, 30, 168)

# %%
# Supponiamo che il padding sia 0
mask_not_empty = np.any(X_signal != 0, axis=(1,2))  # True se l'evento ha almeno un valore non zero

# Filtriamo solo gli eventi non vuoti
X_signal_not_empty = X_signal[mask_not_empty]

print(X_signal_not_empty.shape)
# Out:
# (79000, 30, 168)

# %%
nbins = 4
X_signal_4b = X_signal.reshape(X_signal.shape[0], 30, 42, nbins)
X_noise_4b  = X_noise.reshape(X_noise.shape[0], 30, 42, nbins)

def reduce_to_3_features(X):
    hits_total = X.sum(axis=-1, keepdims=True)   # équivalent au fichier "no_time" existant
    hits_bin0  = X[..., 0:1]                     # ~1 ns
    hits_bin1  = X[..., 1:2]                     # ~4 ns
    out = np.concatenate([hits_total, hits_bin0, hits_bin1], axis=-1)  # (N,30,42,3)
    return out.reshape(out.shape[0], out.shape[1], 42*3)

X_signal_reduced = reduce_to_3_features(X_signal_4b)
X_noise_reduced  = reduce_to_3_features(X_noise_4b)

print("Bins utilisés :", np.arange(0, 10.16+binwidth, binwidth))
print("Nombre de bins :", int(10.16/binwidth), "(attendu : 4)")
print("Somme totale de hits, tenseur brut vs hits_total reconstruit :",
      X_signal_4b.sum(), "vs", X_signal_reduced[...,0::3].sum())  # doivent être égaux
# Out:
# Bins utilisés : [ 0.    2.54  5.08  7.62 10.16]
# Nombre de bins : 4 (attendu : 4)
# Somme totale de hits, tenseur brut vs hits_total reconstruit : 47143713 vs 47143713

# %%
import os

#directory di destinazione
target_dir = "/content/drive/MyDrive/project_files/input_time_4bins/"

# Verifichimo che la cartella esista, altrimenti la creiamo
os.makedirs(target_dir, exist_ok=True)

# 3. Salvataggio dei file
with open(f"{target_dir}signal_data_{FREQ}kHz_timingaware.npy", "wb") as f:
    np.save(f, X_signal)

with open(f"{target_dir}noise_data_{FREQ}kHz_timingaware.npy", "wb") as f:
    np.save(f, X_noise)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6222/55791770.py in <cell line: 0>()
#       9 # 3. Salvataggio dei file
#      10 with open(f"{target_dir}signal_data_{FREQ}kHz_timingaware.npy", "wb") as f:
# ---> 11     np.save(f, X_signal)
#      12
#      13 with open(f"{target_dir}noise_data_{FREQ}kHz_timingaware.npy", "wb") as f:
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_npyio_impl.py in save(file, arr, allow_pickle, fix_imports)
#     585     with file_ctx as fid:
#     586         arr = np.asanyarray(arr)
# --> 587         format.write_array(fid, arr, allow_pickle=allow_pickle,
#     588                            pickle_kwargs=dict(fix_imports=fix_imports))
#     589
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/format.py in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     755     else:
#     756         if isfileobj(fp):
# --> 757             array.tofile(fp)
#     758         else:
#     759             for chunk in numpy.nditer(
#
# KeyboardInterrupt:

# %%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
